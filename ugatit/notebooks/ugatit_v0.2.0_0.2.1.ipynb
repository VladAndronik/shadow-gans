# %% [markdown]
# # Reproducing original implementation with changes
# 1. Explicit weights initialization
# 2. Queue of generated images
# 3. Activation to res net block
# 4. Add parameters to ADAILN layer
# 5. Label smoothing
#
# Providing the monitoring stage

# %%
import torch
from torch.nn import init
from torch import nn
import torch.nn.functional as F
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch.autograd import Variable
from torch import Tensor
from torch.utils.tensorboard import SummaryWriter
from torch.nn.parameter import Parameter
from torch.utils.tensorboard import SummaryWriter 

from skimage.filters import threshold_otsu
from PIL import Image
import cv2
import functools
import itertools
import numpy as np
import random

import os
import sys
import glob
from tqdm import tqdm_notebook
import re

import matplotlib.pyplot as plt
import pickle
import time
from scipy import misc

# %% [markdown]
# ### Networks

# %%
class ResnetGenerator(nn.Module):
    def __init__(self, input_nc, output_nc, ngf=64, n_blocks=6, img_size=256, light=False):
        assert(n_blocks >= 0)
        super(ResnetGenerator, self).__init__()
        self.input_nc = input_nc
        self.output_nc = output_nc
        self.ngf = ngf
        self.n_blocks = n_blocks
        self.img_size = img_size
        self.light = light

        DownBlock = []
        DownBlock += [nn.ReflectionPad2d(3),
                      nn.Conv2d(input_nc, ngf, kernel_size=7, stride=1, padding=0, bias=False),
                      nn.InstanceNorm2d(ngf),
                      nn.ReLU(True)]

        # Down-Sampling
        n_downsampling = 2
        for i in range(n_downsampling):
            mult = 2**i
            DownBlock += [nn.ReflectionPad2d(1),
                          nn.Conv2d(ngf * mult, ngf * mult * 2, kernel_size=3, stride=2, padding=0, bias=False),
                          nn.InstanceNorm2d(ngf * mult * 2),
                          nn.ReLU(True)]

        # Down-Sampling Bottleneck
        mult = 2**n_downsampling
        for i in range(n_blocks):
            DownBlock += [ResnetBlock(ngf * mult, use_bias=False)]

        # Class Activation Map
        self.gap_fc = nn.Linear(ngf * mult, 1, bias=False)
        self.gmp_fc = nn.Linear(ngf * mult, 1, bias=False)
        self.conv1x1 = nn.Conv2d(ngf * mult * 2, ngf * mult, kernel_size=1, stride=1, bias=True)
        self.relu = nn.ReLU(True)

        # Gamma, Beta block
        if self.light:
            # added more parameters from ngf * mult to:
            FC = [nn.Linear(ngf * mult, ngf * ngf, bias=False),
                  nn.ReLU(True),
                  nn.Linear(ngf * ngf, ngf * mult, bias=False),
                  nn.ReLU(True)]
        else:
            FC = [nn.Linear(img_size // mult * img_size // mult * ngf * mult, ngf * mult, bias=False),
                  nn.ReLU(True),
                  nn.Linear(ngf * mult, ngf * mult, bias=False),
                  nn.ReLU(True)]
        self.gamma = nn.Linear(ngf * mult, ngf * mult, bias=False)
        self.beta = nn.Linear(ngf * mult, ngf * mult, bias=False)

        # Up-Sampling Bottleneck
        for i in range(n_blocks):
            setattr(self, 'UpBlock1_' + str(i+1), ResnetAdaILNBlock(ngf * mult, use_bias=False))

        # Up-Sampling
        UpBlock2 = []
        for i in range(n_downsampling):
            mult = 2**(n_downsampling - i)
            UpBlock2 += [nn.Upsample(scale_factor=2, mode='nearest'),
                         nn.ReflectionPad2d(1),
                         nn.Conv2d(ngf * mult, int(ngf * mult / 2), kernel_size=3, stride=1, padding=0, bias=False),
                         ILN(int(ngf * mult / 2)),
                         nn.ReLU(True)]

        UpBlock2 += [nn.ReflectionPad2d(3),
                     nn.Conv2d(ngf, output_nc, kernel_size=7, stride=1, padding=0, bias=False),
                     nn.Tanh()]

        self.DownBlock = nn.Sequential(*DownBlock)
        self.FC = nn.Sequential(*FC)
        self.UpBlock2 = nn.Sequential(*UpBlock2)

    def forward(self, input):
        x = self.DownBlock(input)

        gap = torch.nn.functional.adaptive_avg_pool2d(x, 1)
        gap_logit = self.gap_fc(gap.view(x.shape[0], -1))
        gap_weight = list(self.gap_fc.parameters())[0]
        gap = x * gap_weight.unsqueeze(2).unsqueeze(3)

        gmp = torch.nn.functional.adaptive_max_pool2d(x, 1)
        gmp_logit = self.gmp_fc(gmp.view(x.shape[0], -1))
        gmp_weight = list(self.gmp_fc.parameters())[0]
        gmp = x * gmp_weight.unsqueeze(2).unsqueeze(3)

        cam_logit = torch.cat([gap_logit, gmp_logit], 1)
        x = torch.cat([gap, gmp], 1)
        x = self.relu(self.conv1x1(x))

        heatmap = torch.sum(x, dim=1, keepdim=True)

        if self.light:
            x_ = torch.nn.functional.adaptive_avg_pool2d(x, 1)
            x_ = self.FC(x_.view(x_.shape[0], -1))
        else:
            x_ = self.FC(x.view(x.shape[0], -1))
        gamma, beta = self.gamma(x_), self.beta(x_)


        for i in range(self.n_blocks):
            x = getattr(self, 'UpBlock1_' + str(i+1))(x, gamma, beta)
        out = self.UpBlock2(x)

        return out, cam_logit, heatmap


class ResnetBlock(nn.Module):
    def __init__(self, dim, use_bias):
        super(ResnetBlock, self).__init__()
        conv_block = []
        conv_block += [nn.ReflectionPad2d(1),
                       nn.Conv2d(dim, dim, kernel_size=3, stride=1, padding=0, bias=use_bias),
                       nn.InstanceNorm2d(dim),
                       nn.ReLU(True)]

        conv_block += [nn.ReflectionPad2d(1),
                       nn.Conv2d(dim, dim, kernel_size=3, stride=1, padding=0, bias=use_bias),
                       nn.InstanceNorm2d(dim),
                       nn.ReLU(True)]

        self.conv_block = nn.Sequential(*conv_block)

    def forward(self, x):
        out = x + self.conv_block(x)
        return out


class ResnetAdaILNBlock(nn.Module):
    def __init__(self, dim, use_bias):
        super(ResnetAdaILNBlock, self).__init__()
        self.pad1 = nn.ReflectionPad2d(1)
        self.conv1 = nn.Conv2d(dim, dim, kernel_size=3, stride=1, padding=0, bias=use_bias)
        self.norm1 = adaILN(dim)
        self.relu1 = nn.ReLU(True)

        self.pad2 = nn.ReflectionPad2d(1)
        self.conv2 = nn.Conv2d(dim, dim, kernel_size=3, stride=1, padding=0, bias=use_bias)
        self.norm2 = adaILN(dim)
        self.relu2 = nn.ReLU(True)

    def forward(self, x, gamma, beta):
        out = self.pad1(x)
        out = self.conv1(out)
        out = self.norm1(out, gamma, beta)
        out = self.relu1(out)
        out = self.pad2(out)
        out = self.conv2(out)
        out = self.norm2(out, gamma, beta)
        out = self.relu2(out)

        return out + x


class adaILN(nn.Module):
    def __init__(self, num_features, eps=1e-5):
        super(adaILN, self).__init__()
        self.eps = eps
        self.rho = Parameter(torch.Tensor(1, num_features, 1, 1))
        self.rho.data.fill_(0.9)

    def forward(self, input, gamma, beta):
        in_mean, in_var = torch.mean(input, dim=[2, 3], keepdim=True), torch.var(input, dim=[2, 3], keepdim=True)
        out_in = (input - in_mean) / torch.sqrt(in_var + self.eps)
        ln_mean, ln_var = torch.mean(input, dim=[1, 2, 3], keepdim=True), torch.var(input, dim=[1, 2, 3], keepdim=True)
        out_ln = (input - ln_mean) / torch.sqrt(ln_var + self.eps)
        out = self.rho.expand(input.shape[0], -1, -1, -1) * out_in + (1-self.rho.expand(input.shape[0], -1, -1, -1)) * out_ln
        out = out * gamma.unsqueeze(2).unsqueeze(3) + beta.unsqueeze(2).unsqueeze(3)

        return out


class ILN(nn.Module):
    def __init__(self, num_features, eps=1e-5):
        super(ILN, self).__init__()
        self.eps = eps
        self.rho = Parameter(torch.Tensor(1, num_features, 1, 1))
        self.gamma = Parameter(torch.Tensor(1, num_features, 1, 1))
        self.beta = Parameter(torch.Tensor(1, num_features, 1, 1))
        self.rho.data.fill_(0.0)
        self.gamma.data.fill_(1.0)
        self.beta.data.fill_(0.0)

    def forward(self, input):
        in_mean, in_var = torch.mean(input, dim=[2, 3], keepdim=True), torch.var(input, dim=[2, 3], keepdim=True)
        out_in = (input - in_mean) / torch.sqrt(in_var + self.eps)
        ln_mean, ln_var = torch.mean(input, dim=[1, 2, 3], keepdim=True), torch.var(input, dim=[1, 2, 3], keepdim=True)
        out_ln = (input - ln_mean) / torch.sqrt(ln_var + self.eps)
        out = self.rho.expand(input.shape[0], -1, -1, -1) * out_in + (1-self.rho.expand(input.shape[0], -1, -1, -1)) * out_ln
        out = out * self.gamma.expand(input.shape[0], -1, -1, -1) + self.beta.expand(input.shape[0], -1, -1, -1)

        return out


class Discriminator(nn.Module):
    def __init__(self, input_nc, ndf=64, n_layers=5):
        super(Discriminator, self).__init__()
        model = [nn.ReflectionPad2d(1),
                 nn.utils.spectral_norm(
                 nn.Conv2d(input_nc, ndf, kernel_size=4, stride=2, padding=0, bias=True)),
                 nn.LeakyReLU(0.2, True)]

        for i in range(1, n_layers - 2):
            mult = 2 ** (i - 1)
            model += [nn.ReflectionPad2d(1),
                      nn.utils.spectral_norm(
                      nn.Conv2d(ndf * mult, ndf * mult * 2, kernel_size=4, stride=2, padding=0, bias=True)),
                      nn.LeakyReLU(0.2, True)]

        mult = 2 ** (n_layers - 2 - 1)
        model += [nn.ReflectionPad2d(1),
                  nn.utils.spectral_norm(
                  nn.Conv2d(ndf * mult, ndf * mult * 2, kernel_size=4, stride=1, padding=0, bias=True)),
                  nn.LeakyReLU(0.2, True)]

        # Class Activation Map
        mult = 2 ** (n_layers - 2)
        self.gap_fc = nn.utils.spectral_norm(nn.Linear(ndf * mult, 1, bias=False))
        self.gmp_fc = nn.utils.spectral_norm(nn.Linear(ndf * mult, 1, bias=False))
        self.conv1x1 = nn.Conv2d(ndf * mult * 2, ndf * mult, kernel_size=1, stride=1, bias=True)
        self.leaky_relu = nn.LeakyReLU(0.2, True)

        self.pad = nn.ReflectionPad2d(1)
        self.conv = nn.utils.spectral_norm(
            nn.Conv2d(ndf * mult, 1, kernel_size=4, stride=1, padding=0, bias=False))

        self.model = nn.Sequential(*model)

    def forward(self, input):
        x = self.model(input)

        gap = torch.nn.functional.adaptive_avg_pool2d(x, 1)
        gap_logit = self.gap_fc(gap.view(x.shape[0], -1))
        gap_weight = list(self.gap_fc.parameters())[0]
        gap = x * gap_weight.unsqueeze(2).unsqueeze(3)

        gmp = torch.nn.functional.adaptive_max_pool2d(x, 1)
        gmp_logit = self.gmp_fc(gmp.view(x.shape[0], -1))
        gmp_weight = list(self.gmp_fc.parameters())[0]
        gmp = x * gmp_weight.unsqueeze(2).unsqueeze(3)

        cam_logit = torch.cat([gap_logit, gmp_logit], 1)
        x = torch.cat([gap, gmp], 1)
        x = self.leaky_relu(self.conv1x1(x))

        heatmap = torch.sum(x, dim=1, keepdim=True)

        x = self.pad(x)
        out = self.conv(x)

        return out, cam_logit, heatmap


class RhoClipper(object):

    def __init__(self, min, max):
        self.clip_min = min
        self.clip_max = max
        assert min < max

    def __call__(self, module):

        if hasattr(module, 'rho'):
            w = module.rho.data
            w = w.clamp(self.clip_min, self.clip_max)
            module.rho.data = w

# %%
# summary of the models
def num_params(model):
  model_parameters = filter(lambda p: p.requires_grad, model.parameters())
  params = sum([np.prod(p.size()) for p in model_parameters])
  return params

dL = Discriminator(3, n_layers=5)
dG = Discriminator(3, n_layers=7)
g_light = ResnetGenerator(3,3, light=True)
g_hard = ResnetGenerator(3,3, light=False)

dL_num = round(num_params(dL) * 2 / 1e6, 3)
dG_num = round(num_params(dG) * 2 / 1e6, 3)
g_light_num = round(num_params(g_light) * 2 / 1e6, 3)
g_hard_num = round(num_params(g_hard) * 2 / 1e6, 3)
overall_light = round(dL_num + dG_num + g_light_num, 3)
overall_hard = round(dL_num + dG_num + g_hard_num, 3)

print('---- Summary models ----')
print("Number of parameters (in millions):")
print("{:10}{:10}{:10}{:10}{:20}{:10}".format("D_L", 'D_G', "G_LIGHT", "G_HARD","Overall_LIGHT", "Overall_HARD"))
print("{:10}{:10}{:10}{:10}{:20}{:10}".format(str(dL_num), str(dG_num), str(g_light_num), 
                                    str(g_hard_num), str(overall_light), str(overall_hard)))
# Out:
# ---- Summary models ----
# Number of parameters (in millions):
# D_L       D_G       G_LIGHT   G_HARD    Overall_LIGHT       Overall_HARD
# 6.581     106.26    34.551    567.359   147.392             680.2

# %% [markdown]
# ### Utils

# %%
def load_test_data(image_path, size=256):
    img = misc.imread(image_path, mode='RGB')
    img = misc.imresize(img, [size, size])
    img = np.expand_dims(img, axis=0)
    img = preprocessing(img)

    return img

def preprocessing(x):
    x = x/127.5 - 1 # -1 ~ 1
    return x

def save_images(images, size, image_path):
    return imsave(inverse_transform(images), size, image_path)

def inverse_transform(images):
    return (images+1.) / 2

def imsave(images, size, path):
    return misc.imsave(path, merge(images, size))

def merge(images, size):
    h, w = images.shape[1], images.shape[2]
    img = np.zeros((h * size[0], w * size[1], 3))
    for idx, image in enumerate(images):
        i = idx % size[1]
        j = idx // size[1]
        img[h*j:h*(j+1), w*i:w*(i+1), :] = image

    return img

def check_folder(log_dir):
    if not os.path.exists(log_dir):
        os.makedirs(log_dir)
    return log_dir

def str2bool(x):
    return x.lower() in ('true')

def cam(x, size = 256):
    x = x - np.min(x)
    cam_img = x / np.max(x)
    cam_img = np.uint8(255 * cam_img)
    cam_img = cv2.resize(cam_img, (size, size))
    cam_img = cv2.applyColorMap(cam_img, cv2.COLORMAP_JET)
    return cam_img / 255.0

def imagenet_norm(x):
    mean = [0.485, 0.456, 0.406]
    std = [0.299, 0.224, 0.225]
    mean = torch.FloatTensor(mean).unsqueeze(0).unsqueeze(2).unsqueeze(3).to(x.device)
    std = torch.FloatTensor(std).unsqueeze(0).unsqueeze(2).unsqueeze(3).to(x.device)
    return (x - mean) / std

def denorm(x):
    return x * 0.5 + 0.5

def tensor2numpy(x):
    return x.detach().cpu().numpy().transpose(1,2,0)

def RGB2BGR(x):
    return cv2.cvtColor(x, cv2.COLOR_RGB2BGR)


# weights initialization
def init_weights(net, stddev=.02):

  def weights_initializer(m):
    classname = m.__class__.__name__
    if hasattr(m, 'weight') and (classname.find('Conv') != -1 or classname.find('Linear') != -1):
      init.normal_(m.weight.data, mean=0.0, std=stddev)

      if hasattr(m, 'bias') and m.bias is not None:
        init.constant_(m.bias.data, 0.0)

  net.apply(weights_initializer)
  return net


def init_net(net, device, stddev=0.02):
  net.to(device)
  init_weights(net, stddev=stddev)
  return net


def ground_truth_tensor(tensor, label):
  return torch.ones_like(tensor) * label

# %% [markdown]
# ### Dataset and Images Queue

# %%
def read_pil_image(path):
  with open(path, 'rb') as f:
    img = Image.open(f)
    return img.convert("RGB")


class DatasetFolder(torch.utils.data.Dataset):
  def __init__(self, root, extension, transform=None):
    self.img_paths = glob.glob(os.path.join(root, '*.{}'.format(extension)))
    self.img_len = len(self.img_paths)
    assert self.img_len > 0, 'Found 0 images in {}'.format(root)
    self.transform = transform


  def __getitem__(self, index):
    img = read_pil_image(self.img_paths[index % self.img_len])
    img = self.transform(img)
    return img


  def __len__(self):
    return self.img_len


class ImageFolder(DatasetFolder):
  def __init__(self, root, extension, transform):
    super(ImageFolder, self).__init__(root=root, 
                                      extension=extension, 
                                      transform=transform)

# %%
class ImagePool():
  def __init__(self, pool_size):
    self.pool_size=pool_size
    self.images = []

  def sample(self, image_data):
    if len(self.images) < self.pool_size:
      self.images.append(image_data)
      return image_data
    
    p = random.random()
    if p > 0.5:
      idx = random.randrange(0, self.pool_size)
      tmp_data = self.images[idx].clone()
      self.images[idx] = image_data.clone()
      return tmp_data

    return image_data

# %% [markdown]
# ### Model

# %%
checkpoint_dir = 'ugatit/output/checkpoints/checkpoints_v0.2.1/'
images_dir = 'ugatit/output/images/images_v0.2.1/'
summary_dir = 'ugatit/output/summary/summary_v0.2.1/'
os.makedirs(checkpoint_dir, exist_ok=True)
os.makedirs(images_dir, exist_ok=True)
os.makedirs(summary_dir, exist_ok=True)


A_dir = 'data/shadow_USR/shadow_train/'
B_dir = 'data/shadow_USR/shadow_free/'
A_test_dir = 'data/shadow_USR/shadow_test/'



load_model = False
batch_size=1
image_size=256
ngf=64
ndf=64
light = True

weight_adv = 1
weight_cyc = 10
weight_idt = 10
# it helps only generator to get attended, while discriminator does not use distinct cam loss
weight_cam = 1000  


learning_rate=2e-4
beta1=.5
pool_size=50
mask_queue_size=50
n_blocks=4
slope=0.2
stddev=0.02
weight_decay=0.0001
pool_size=50

input_nc=3
output_nc=3
device=torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
real_label=0.9

n_steps = int(3e5)
decay_start = n_steps // 2
decay_flag=True
print_freq = 10
save_freq = 5000
test_freq = 100

# %%
def get_step(filename):
  match = re.findall('(\d+).pt', filename)[0]
  return int(match)
  
def latest_checkpoint_files(check_dir, f):
  return max(map(f, os.listdir(check_dir)))

# %%
class UGATIT(object):
  def __init__(self):
    self.img_size=image_size
    self.batch_size=batch_size
    self.device=device
    self.n_res=n_blocks
    self.ch = ngf
    self.light=light
    self.lr = learning_rate
    self.weight_decay = weight_decay

    self.adv_weight = weight_adv
    self.cycle_weight = weight_cyc
    self.identity_weight = weight_idt
    self.cam_weight = weight_cam


  def build_model(self):
    """ DataLoader """
    train_transform = transforms.Compose([
        transforms.RandomHorizontalFlip(),
        transforms.Resize((self.img_size + 30, self.img_size+30)),
        transforms.RandomCrop(self.img_size),
        transforms.ToTensor(),
        transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
    ])
    test_transform = transforms.Compose([
        transforms.Resize((self.img_size, self.img_size)),
        transforms.ToTensor(),
        transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
    ])

    self.trainA = ImageFolder(A_dir, 'jpg', train_transform)
    self.trainB = ImageFolder(B_dir, 'jpg', train_transform)
    self.trainA_loader = DataLoader(self.trainA, batch_size=self.batch_size, shuffle=True)
    self.trainB_loader = DataLoader(self.trainB, batch_size=self.batch_size, shuffle=True)

    """ Define Generator, Discriminator """
    self.genA2B = ResnetGenerator(input_nc=3, output_nc=3, ngf=self.ch, 
                                  n_blocks=self.n_res, img_size=self.img_size, 
                                  light=self.light)
    self.genB2A = ResnetGenerator(input_nc=3, output_nc=3, 
                                  ngf=self.ch, n_blocks=self.n_res, 
                                  img_size=self.img_size, light=self.light)
    self.disGA = Discriminator(input_nc=3, ndf=self.ch, n_layers=7)
    self.disGB = Discriminator(input_nc=3, ndf=self.ch, n_layers=7)
    self.disLA = Discriminator(input_nc=3, ndf=self.ch, n_layers=5)
    self.disLB = Discriminator(input_nc=3, ndf=self.ch, n_layers=5)

    # Adding the initialization step
    init_net(self.genA2B, self.device, stddev=stddev)
    init_net(self.genB2A, self.device, stddev=stddev)
    init_net(self.disGA, self.device, stddev=stddev)
    init_net(self.disGB, self.device, stddev=stddev)
    init_net(self.disLA, self.device, stddev=stddev)
    init_net(self.disLB, self.device, stddev=stddev)

    """ Define Loss """
    self.L1_loss = nn.L1Loss().to(self.device)
    self.MSE_loss = nn.MSELoss().to(self.device)
    self.BCE_loss = nn.BCEWithLogitsLoss().to(self.device)

    """ Trainer """
    self.G_optim = torch.optim.Adam(itertools.chain(self.genA2B.parameters(), self.genB2A.parameters()), 
                                    lr=self.lr, betas=(0.5, 0.999), weight_decay=self.weight_decay)
    self.D_optim = torch.optim.Adam(itertools.chain(self.disGA.parameters(), self.disGB.parameters(), 
                                                    self.disLA.parameters(), self.disLB.parameters()), 
                                    lr=self.lr, betas=(0.5, 0.999), weight_decay=self.weight_decay)

    """ Define Rho clipper to constraint the value of rho in AdaILN and ILN"""
    self.Rho_clipper = RhoClipper(0, 1)

    """Images buffer for fake updates of discriminators so they can obtain the history"""
    self.fake_A_buffer = ImagePool(pool_size=pool_size)
    self.fake_B_buffer = ImagePool(pool_size=pool_size)

    """Summary writing to tensorboard"""
    self.writer = SummaryWriter(log_dir=summary_dir)


  def train(self):
    self.genA2B.train(), self.genB2A.train(), self.disGA.train(), self.disGB.train(), self.disLA.train(), self.disLB.train()

    start_iter = 1
    if load_model:
      print("---- Loading the model ----".upper())
      model_list = glob.glob(os.path.join(checkpoint_dir, '*.pt'))
      if len(model_list) > 0:
        start_iter = latest_checkpoint_files(checkpoint_dir, get_step)
        print('Load the model from {}'.format(start_iter))
        self.load(checkpoint_dir, start_iter)
        if decay_flag and start_iter > decay_start:
          self.G_optim.param_groups[0]['lr'] -= (lr / decay_start) * (start_iter - decay_start)
          self.D_optim.param_groups[0]['lr'] -= (lr / decay_start) * (start_iter - decay_start)
        start_iter += 1  # for not repeating the start_iter step

    # training loop
    try:
      print('training start !')
      start_time = time.time()
      counter=start_iter
      for step in tqdm_notebook(range(start_iter, n_steps + 1), total=n_steps-start_iter):
        if decay_flag and step > (n_steps // 2):
            self.G_optim.param_groups[0]['lr'] -= (self.lr / (n_steps // 2))
            self.D_optim.param_groups[0]['lr'] -= (self.lr / (n_steps // 2))

        try:
            real_A = trainA_iter.next()
        except:
            trainA_iter = iter(self.trainA_loader)
            real_A = trainA_iter.next()

        try:
            real_B = trainB_iter.next()
        except:
            trainB_iter = iter(self.trainB_loader)
            real_B = trainB_iter.next()

        real_A, real_B = real_A.to(self.device), real_B.to(self.device)

        # Update G
        self.G_optim.zero_grad()

        fake_A2B, fake_A2B_cam_logit, _ = self.genA2B(real_A)
        fake_B2A, fake_B2A_cam_logit, _ = self.genB2A(real_B)

        fake_A2B2A, _, _ = self.genB2A(fake_A2B)
        fake_B2A2B, _, _ = self.genA2B(fake_B2A)

        fake_A2A, fake_A2A_cam_logit, _ = self.genB2A(real_A)
        fake_B2B, fake_B2B_cam_logit, _ = self.genA2B(real_B)

        fake_GA_logit, fake_GA_cam_logit, _ = self.disGA(fake_B2A)
        fake_LA_logit, fake_LA_cam_logit, _ = self.disLA(fake_B2A)
        fake_GB_logit, fake_GB_cam_logit, _ = self.disGB(fake_A2B)
        fake_LB_logit, fake_LB_cam_logit, _ = self.disLB(fake_A2B)

        G_ad_loss_GA = self.MSE_loss(fake_GA_logit, ground_truth_tensor(fake_GA_logit, real_label))
        G_ad_cam_loss_GA = self.MSE_loss(fake_GA_cam_logit, ground_truth_tensor(fake_GA_cam_logit, real_label))
        G_ad_loss_LA = self.MSE_loss(fake_LA_logit, ground_truth_tensor(fake_LA_logit, real_label))
        G_ad_cam_loss_LA = self.MSE_loss(fake_LA_cam_logit, ground_truth_tensor(fake_LA_cam_logit, real_label))
        G_ad_loss_GB = self.MSE_loss(fake_GB_logit, ground_truth_tensor(fake_GB_logit, real_label))
        G_ad_cam_loss_GB = self.MSE_loss(fake_GB_cam_logit, ground_truth_tensor(fake_GB_cam_logit, real_label))
        G_ad_loss_LB = self.MSE_loss(fake_LB_logit, ground_truth_tensor(fake_LB_logit, real_label))
        G_ad_cam_loss_LB = self.MSE_loss(fake_LB_cam_logit, ground_truth_tensor(fake_LB_cam_logit, real_label))

        # Cycle loss
        G_recon_loss_A = self.L1_loss(fake_A2B2A, real_A)
        G_recon_loss_B = self.L1_loss(fake_B2A2B, real_B)

        # Identity loss
        G_identity_loss_A = self.L1_loss(fake_A2A, real_A)
        G_identity_loss_B = self.L1_loss(fake_B2B, real_B)

        # CAM loss
        G_cam_loss_A = self.BCE_loss(fake_B2A_cam_logit, torch.ones_like(fake_B2A_cam_logit).to(self.device)) + self.BCE_loss(fake_A2A_cam_logit, torch.zeros_like(fake_A2A_cam_logit).to(self.device))
        G_cam_loss_B = self.BCE_loss(fake_A2B_cam_logit, torch.ones_like(fake_A2B_cam_logit).to(self.device)) + self.BCE_loss(fake_B2B_cam_logit, torch.zeros_like(fake_B2B_cam_logit).to(self.device))

        # Combine all losses together
        G_loss_A =  self.adv_weight * (G_ad_loss_GA + G_ad_cam_loss_GA + G_ad_loss_LA + G_ad_cam_loss_LA) + self.cycle_weight * G_recon_loss_A + self.identity_weight * G_identity_loss_A + self.cam_weight * G_cam_loss_A
        G_loss_B = self.adv_weight * (G_ad_loss_GB + G_ad_cam_loss_GB + G_ad_loss_LB + G_ad_cam_loss_LB) + self.cycle_weight * G_recon_loss_B + self.identity_weight * G_identity_loss_B + self.cam_weight * G_cam_loss_B

        Generator_loss = G_loss_A + G_loss_B
        Generator_loss.backward()
        self.G_optim.step()

        # Update D
        self.D_optim.zero_grad()

        # update discriminators on the history of the generated samples
        fake_A2B = self.fake_B_buffer.sample(fake_A2B)
        fake_B2A = self.fake_A_buffer.sample(fake_B2A)

        real_GA_logit, real_GA_cam_logit, _ = self.disGA(real_A)
        real_LA_logit, real_LA_cam_logit, _ = self.disLA(real_A)
        real_GB_logit, real_GB_cam_logit, _ = self.disGB(real_B)
        real_LB_logit, real_LB_cam_logit, _ = self.disLB(real_B)

        fake_GA_logit, fake_GA_cam_logit, _ = self.disGA(fake_B2A.detach())
        fake_LA_logit, fake_LA_cam_logit, _ = self.disLA(fake_B2A.detach())
        fake_GB_logit, fake_GB_cam_logit, _ = self.disGB(fake_A2B.detach())
        fake_LB_logit, fake_LB_cam_logit, _ = self.disLB(fake_A2B.detach())

        D_ad_loss_GA = self.MSE_loss(real_GA_logit, ground_truth_tensor(real_GA_logit, real_label).to(self.device)) + \
          self.MSE_loss(fake_GA_logit, torch.zeros_like(fake_GA_logit).to(self.device))

        D_ad_cam_loss_GA = self.MSE_loss(real_GA_cam_logit, ground_truth_tensor(real_GA_cam_logit, real_label).to(self.device)) + \
          self.MSE_loss(fake_GA_cam_logit, torch.zeros_like(fake_GA_cam_logit).to(self.device))

        D_ad_loss_LA = self.MSE_loss(real_LA_logit, ground_truth_tensor(real_LA_logit, real_label)) + \
          self.MSE_loss(fake_LA_logit, torch.zeros_like(fake_LA_logit).to(self.device))

        D_ad_cam_loss_LA = self.MSE_loss(real_LA_cam_logit, ground_truth_tensor(real_LA_cam_logit, real_label)) + \
          self.MSE_loss(fake_LA_cam_logit, torch.zeros_like(fake_LA_cam_logit).to(self.device))

        D_ad_loss_GB = self.MSE_loss(real_GB_logit, ground_truth_tensor(real_GB_logit, real_label)) + \
          self.MSE_loss(fake_GB_logit, torch.zeros_like(fake_GB_logit).to(self.device))

        D_ad_cam_loss_GB = self.MSE_loss(real_GB_cam_logit, ground_truth_tensor(real_GB_cam_logit, real_label)) + \
          self.MSE_loss(fake_GB_cam_logit, torch.zeros_like(fake_GB_cam_logit).to(self.device))

        D_ad_loss_LB = self.MSE_loss(real_LB_logit, ground_truth_tensor(real_LB_logit, real_label)) + \
          self.MSE_loss(fake_LB_logit, torch.zeros_like(fake_LB_logit).to(self.device))

        D_ad_cam_loss_LB = self.MSE_loss(real_LB_cam_logit, ground_truth_tensor(real_LB_cam_logit, real_label)) + \
          self.MSE_loss(fake_LB_cam_logit, torch.zeros_like(fake_LB_cam_logit).to(self.device))

        D_loss_A = self.adv_weight * (D_ad_loss_GA + D_ad_cam_loss_GA + D_ad_loss_LA + D_ad_cam_loss_LA)
        D_loss_B = self.adv_weight * (D_ad_loss_GB + D_ad_cam_loss_GB + D_ad_loss_LB + D_ad_cam_loss_LB)

        Discriminator_loss = D_loss_A + D_loss_B
        Discriminator_loss.backward()
        self.D_optim.step()


        # clip parameter of AdaILN and ILN, applied after optimizer step
        self.genA2B.apply(self.Rho_clipper)
        self.genB2A.apply(self.Rho_clipper)

        if step % print_freq == 0:
          time_spent = time.time() - start_time
          h = time_spent // 3600
          m = (time_spent - h * 3600) // 60
          s = int(time_spent - h * 3600 - m * 60)
          print("[{}/{}]\nD_loss : {:.4f}\nG_loss: {:.4f}".format(step, n_steps, Discriminator_loss, Generator_loss))
          print("Time: {}:{}:{}".format(h, m, s))

          # Summary writing
          G_adv_loss_A = (G_ad_loss_GA + G_ad_cam_loss_GA + G_ad_loss_LA + G_ad_cam_loss_LA)
          G_adv_loss_B = (G_ad_loss_GB + G_ad_cam_loss_GB + G_ad_loss_LB + G_ad_cam_loss_LB)
          print(("loss_G_AB: {:.3f}\nloss_G_AB_GAN: {:.3f}\nloss_G_AB_identity: {:.3f}\n" + 
                "loss_G_AB_cycle: {:.3f}\nloss_G_AB_cam: {:.3f}\nloss_G_BA: {:.3f}\nloss_G_BA_GAN: {:.3f}\n" + 
                "loss_G_BA_identity: {:.3f}\nloss_G_BA_cycle: {:.3f}\nloss_G_BA_cam: {:.3f}\n").format(
                    G_loss_B, G_adv_loss_B, G_identity_loss_B, G_recon_loss_B, G_cam_loss_B, 
                    G_loss_A, G_adv_loss_A, G_identity_loss_A, G_recon_loss_A, G_cam_loss_A
                ))
          self.writer.add_scalar('G/G_AB', G_loss_B, global_step=step)
          self.writer.add_scalar('G/G_AB_GAN', G_adv_loss_B, global_step=step)
          self.writer.add_scalar('G/G_AB_identity', G_identity_loss_B, global_step=step)
          self.writer.add_scalar('G/G_AB_cycle', G_recon_loss_B, global_step=step)
          self.writer.add_scalar('G/G_AB_cam', G_cam_loss_B, global_step=step)

          self.writer.add_scalar('G/G_BA', G_loss_A, global_step=step)
          self.writer.add_scalar('G/G_BA_GAN', G_adv_loss_A, global_step=step)
          self.writer.add_scalar('G/G_BA_identity', G_identity_loss_A, global_step=step)
          self.writer.add_scalar('G/G_BA_cycle', G_recon_loss_A, global_step=step)
          self.writer.add_scalar('G/G_BA_cam', G_cam_loss_A, global_step=step)

          # Discriminator monitoring
          D_LA = D_ad_loss_LA + D_ad_cam_loss_LA
          D_GA = D_ad_loss_GA + D_ad_cam_loss_GA
          
          D_LB = D_ad_loss_LB + D_ad_cam_loss_LB
          D_GB = D_ad_loss_GB + D_ad_cam_loss_GB
          print(("loss_D_LA: {:.3f}\nloss_D_LA_GAN: {:.3f}\nloss_D_LA_cam: {:.3f}\n" + 
                "loss_D_GA: {:.3f}\nloss_D_GA_GAN: {:.3f}\nloss_D_GA_cam: {:.3f}\n" + 
                "loss_D_LB: {:.3f}\nloss_D_LB_GAN: {:.3f}\nloss_D_LB_cam: {:.3f}\n" +
                "loss_D_GB: {:.3f}\nloss_D_GB_GAN: {:.3f}\nloss_D_GB_cam: {:.3f}\n").format(
                    D_LA, D_ad_loss_LA, D_ad_cam_loss_LA, D_GA, D_ad_loss_GA, D_ad_cam_loss_GA,
                    D_LB, D_ad_loss_LB, D_ad_cam_loss_LB, D_GB, D_ad_loss_GB, D_ad_cam_loss_GB
                ))
          self.writer.add_scalar("D/D_LA", D_LA, global_step=step)
          self.writer.add_scalar("D/D_LA_GAN", D_ad_loss_LA, global_step=step)
          self.writer.add_scalar("D/D_LA_cam", D_ad_cam_loss_LA, global_step=step)
          self.writer.add_scalar("D/D_GA", D_GA, global_step=step)
          self.writer.add_scalar("D/D_GA_GAN", D_ad_loss_GA, global_step=step)
          self.writer.add_scalar("D/D_GA_cam", D_ad_cam_loss_GA, global_step=step)
          self.writer.add_scalar("D/D_LB", D_LB, global_step=step)
          self.writer.add_scalar("D/D_LB_GAN", D_ad_loss_LB, global_step=step)
          self.writer.add_scalar("D/D_LB_cam", D_ad_cam_loss_LB, global_step=step)
          self.writer.add_scalar("D/D_GB", D_GB, global_step=step)
          self.writer.add_scalar("D/D_GB_GAN", D_ad_loss_GB, global_step=step)
          self.writer.add_scalar("D/D_GB_cam", D_ad_cam_loss_GB, global_step=step)
          
        if step % save_freq == 0:
          print("Save the checkpoint : ", step)
          self.save(checkpoint_dir, step)

        if step % test_freq == 0:
        # copied from original implementation
          train_sample_num = 5

          A2B = np.zeros((image_size * 4, 0, 3))
          B2A = np.zeros((image_size * 4, 0, 3))

          self.genA2B.eval(), self.genB2A.eval(), self.disGA.eval(), self.disGB.eval(), self.disLA.eval(), self.disLB.eval()
          
          for _ in range(train_sample_num):
            try:
                real_A = trainA_iter.next()
            except:
                trainA_iter = iter(self.trainA_loader)
                real_A = trainA_iter.next()

            try:
                real_B = trainB_iter.next()
            except:
                trainB_iter = iter(self.trainB_loader)
                real_B = trainB_iter.next()
            real_A, real_B = real_A.to(device), real_B.to(device)

            fake_A2B, _, fake_A2B_heatmap = self.genA2B(real_A)
            fake_B2A, _, fake_B2A_heatmap = self.genB2A(real_B)

            fake_A2B2A, _, fake_A2B2A_heatmap = self.genB2A(fake_A2B)
            fake_B2A2B, _, fake_B2A2B_heatmap = self.genA2B(fake_B2A)

            fake_A2A, _, fake_A2A_heatmap = self.genB2A(real_A)
            fake_B2B, _, fake_B2B_heatmap = self.genA2B(real_B)

            A2B = np.concatenate((A2B, np.concatenate((RGB2BGR(tensor2numpy(denorm(real_A[0]))),
                                                        cam(tensor2numpy(fake_A2B_heatmap[0]), image_size),
                                                        RGB2BGR(tensor2numpy(denorm(fake_A2B[0]))),
                                                        RGB2BGR(tensor2numpy(denorm(fake_A2B2A[0])))), 0)), 1)

            B2A = np.concatenate((B2A, np.concatenate((RGB2BGR(tensor2numpy(denorm(real_B[0]))),
                                                        cam(tensor2numpy(fake_B2A_heatmap[0]), image_size),
                                                        RGB2BGR(tensor2numpy(denorm(fake_B2A[0]))),
                                                        RGB2BGR(tensor2numpy(denorm(fake_B2A2B[0])))), 0)), 1)
          cv2.imwrite(os.path.join(images_dir,'A2B_%07d.png' % step), A2B * 255.0)
          cv2.imwrite(os.path.join(images_dir,'B2A_%07d.png' % step), B2A * 255.0)
          self.genA2B.train(), self.genB2A.train(), self.disLA.train(), self.disLB.train(), self.disGA.train(), self.disGB.train()
        counter += 1
    except Exception as e:
      raise e
    finally:
      print("---- Save the checkpoint ----")
      self.save(checkpoint_dir, counter)
      print("---- Finished ----".upper())



  def load(self, path, step):
    params = torch.load(os.path.join(path, 'params_{}.pt'.format(step)))
    self.genA2B.load_state_dict(params['genA2B'])
    self.genB2A.load_state_dict(params['genB2A'])
    self.disGA.load_state_dict(params['disGA'])
    self.disGB.load_state_dict(params['disGB'])
    self.disLA.load_state_dict(params['disLA'])
    self.disLB.load_state_dict(params['disLB'])

  def save(self, path, step):
    params = {}
    params['genA2B'] = self.genA2B.state_dict()
    params['genB2A'] = self.genB2A.state_dict()
    params['disGA'] = self.disGA.state_dict()
    params['disGB'] = self.disGB.state_dict()
    params['disLA'] = self.disLA.state_dict()
    params['disLB'] = self.disLB.state_dict()
    torch.save(params, os.path.join(path, 'params_{}.pt'.format(step)))

# %%
model = UGATIT()
model.build_model()
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
model.train()
# Out:
# training start !
# HBox(children=(IntProgress(value=0, max=299999), HTML(value='')))
# [10/300000]
# D_loss : 4.7980
# G_loss: 2725.9902
# Time: 0.0:0.0:16
# loss_G_AB: 1578.548
# loss_G_AB_GAN: 2.423
# loss_G_AB_identity: 0.599
# loss_G_AB_cycle: 0.588
# loss_G_AB_cam: 1.564
# loss_G_BA: 1147.442
# loss_G_BA_GAN: 2.719
# loss_G_BA_identity: 0.402
# loss_G_BA_cycle: 0.437
# loss_G_BA_cam: 1.136
#
# loss_D_LA: 0.968
# loss_D_LA_GAN: 0.695
# loss_D_LA_cam: 0.273
# loss_D_GA: 1.112
# loss_D_GA_GAN: 0.578
# loss_D_GA_cam: 0.533
# loss_D_LB: 1.325
# loss_D_LB_GAN: 0.713
# loss_D_LB_cam: 0.612
# loss_D_GB: 1.393
# loss_D_GB_GAN: 0.582
# loss_D_GB_cam: 0.811
#
# [20/300000]
# D_loss : 3.6381
# G_loss: 1448.8079
# Time: 0.0:0.0:33
# loss_G_AB: 729.986
# loss_G_AB_GAN: 1.858
# loss_G_AB_identity: 0.172
# loss_G_AB_cycle: 0.180
# loss_G_AB_cam: 0.725
# loss_G_BA: 718.822
# loss_G_BA_GAN: 1.393
# loss_G_BA_identity: 0.373
# loss_G_BA_cycle: 0.408
# loss_G_BA_cam: 0.710
#
# loss_D_LA: 0.654
# loss_D_LA_GAN: 0.323
# loss_D_LA_cam: 0.332
# loss_D_GA: 0.880
# loss_D_GA_GAN: 0.401
# loss_D_GA_cam: 0.479
# loss_D_LB: 0.935
# loss_D_LB_GAN: 0.479
# loss_D_LB_cam: 0.456
# loss_D_GB: 1.169
# loss_D_GB_GAN: 0.406
# loss_D_GB_cam: 0.762
#
# [30/300000]
# D_loss : 3.4161
# G_loss: 2042.4656
# Time: 0.0:0.0:49
# loss_G_AB: 878.656
# loss_G_AB_GAN: 1.340
# loss_G_AB_identity: 0.268
# loss_G_AB_cycle: 0.278
# loss_G_AB_cam: 0.872
# loss_G_BA: 1163.809
# loss_G_BA_GAN: 1.231
# loss_G_BA_identity: 0.376
# loss_G_BA_cycle: 0.356
# loss_G_BA_cam: 1.155
#
# loss_D_LA: 0.597
# loss_D_LA_GAN: 0.355
# loss_D_LA_cam: 0.242
# loss_D_GA: 0.895
# loss_D_GA_GAN: 0.398
# loss_D_GA_cam: 0.497
# loss_D_LB: 0.966
# loss_D_LB_GAN: 0.447
# loss_D_LB_cam: 0.519
# loss_D_GB: 0.959
# loss_D_GB_GAN: 0.406
# loss_D_GB_cam: 0.553
#
# [40/300000]
# D_loss : 3.7068
# G_loss: 4496.6260
# Time: 0.0:1.0:6
# loss_G_AB: 2301.191
# loss_G_AB_GAN: 1.852
# loss_G_AB_identity: 0.169
# loss_G_AB_cycle: 0.180
# loss_G_AB_cam: 2.296
# loss_G_BA: 2195.435
# loss_G_BA_GAN: 0.810
# loss_G_BA_identity: 0.300
# loss_G_BA_cycle: 0.265
# loss_G_BA_cam: 2.189
#
# loss_D_LA: 0.962
# loss_D_LA_GAN: 0.461
# loss_D_LA_cam: 0.501
# loss_D_GA: 1.076
# loss_D_GA_GAN: 0.451
# loss_D_GA_cam: 0.624
# loss_D_LB: 0.700
# loss_D_LB_GAN: 0.378
# loss_D_LB_cam: 0.322
# loss_D_GB: 0.970
# loss_D_GB_GAN: 0.407
# loss_D_GB_cam: 0.563
#
# [50/300000]
# D_loss : 3.0526
# G_loss: 1471.4183
# Time: 0.0:1.0:22
# loss_G_AB: 761.683
# loss_G_AB_GAN: 0.936
# loss_G_AB_identity: 0.274
# loss_G_AB_cycle: 0.278
# loss_G_AB_cam: 0.755
# loss_G_BA: 709.735
# loss_G_BA_GAN: 1.042
# loss_G_BA_identity: 0.286
# loss_G_BA_cycle: 0.418
# loss_G_BA_cam: 0.702
#
# loss_D_LA: 1.028
# loss_D_LA_GAN: 0.436
# loss_D_LA_cam: 0.591
# loss_D_GA: 0.753
# loss_D_GA_GAN: 0.392
# loss_D_GA_cam: 0.361
# loss_D_LB: 0.545
# loss_D_LB_GAN: 0.330
# loss_D_LB_cam: 0.216
# loss_D_GB: 0.726
# loss_D_GB_GAN: 0.397
# loss_D_GB_cam: 0.329
#
# [60/300000]
# D_loss : 2.8010
# G_loss: 2395.8003
# Time: 0.0:1.0:42
# loss_G_AB: 984.212
# loss_G_AB_GAN: 1.004
# loss_G_AB_identity: 0.345
# loss_G_AB_cycle: 0.369
# loss_G_AB_cam: 0.976
# loss_G_BA: 1411.589
# loss_G_BA_GAN: 1.434
# loss_G_BA_identity: 0.281
# loss_G_BA_cycle: 0.328
# loss_G_BA_cam: 1.404
#
# loss_D_LA: 0.763
# loss_D_LA_GAN: 0.368
# loss_D_LA_cam: 0.395
# loss_D_GA: 0.973
# loss_D_GA_GAN: 0.406
# loss_D_GA_cam: 0.567
# loss_D_LB: 0.374
# loss_D_LB_GAN: 0.251
# loss_D_LB_cam: 0.124
# loss_D_GB: 0.691
# loss_D_GB_GAN: 0.382
# loss_D_GB_cam: 0.309
#
# [70/300000]
# D_loss : 2.4177
# G_loss: 2522.3867
# Time: 0.0:1.0:58
# loss_G_AB: 898.804
# loss_G_AB_GAN: 1.036
# loss_G_AB_identity: 0.299
# loss_G_AB_cycle: 0.311
# loss_G_AB_cam: 0.892
# loss_G_BA: 1623.582
# loss_G_BA_GAN: 1.062
# loss_G_BA_identity: 0.236
# loss_G_BA_cycle: 0.332
# loss_G_BA_cam: 1.617
#
# loss_D_LA: 0.639
# loss_D_LA_GAN: 0.353
# loss_D_LA_cam: 0.286
# loss_D_GA: 0.747
# loss_D_GA_GAN: 0.392
# loss_D_GA_cam: 0.355
# loss_D_LB: 0.486
# loss_D_LB_GAN: 0.323
# loss_D_LB_cam: 0.164
# loss_D_GB: 0.545
# loss_D_GB_GAN: 0.365
# loss_D_GB_cam: 0.181
#
# [80/300000]
# D_loss : 3.5215
# G_loss: 1887.2260
# Time: 0.0:2.0:14
# loss_G_AB: 1134.325
# loss_G_AB_GAN: 1.365
# loss_G_AB_identity: 0.138
# loss_G_AB_cycle: 0.154
# loss_G_AB_cam: 1.130
# loss_G_BA: 752.901
# loss_G_BA_GAN: 0.504
# loss_G_BA_identity: 0.318
# loss_G_BA_cycle: 0.341
# loss_G_BA_cam: 0.746
#
# loss_D_LA: 1.292
# loss_D_LA_GAN: 0.541
# loss_D_LA_cam: 0.751
# loss_D_GA: 1.055
# loss_D_GA_GAN: 0.419
# loss_D_GA_cam: 0.635
# loss_D_LB: 0.510
# loss_D_LB_GAN: 0.310
# loss_D_LB_cam: 0.200
# loss_D_GB: 0.664
# loss_D_GB_GAN: 0.377
# loss_D_GB_cam: 0.287
#
# [90/300000]
# D_loss : 3.5310
# G_loss: 2155.0415
# Time: 0.0:2.0:31
# loss_G_AB: 1084.834
# loss_G_AB_GAN: 1.842
# loss_G_AB_identity: 0.155
# loss_G_AB_cycle: 0.164
# loss_G_AB_cam: 1.080
# loss_G_BA: 1070.208
# loss_G_BA_GAN: 0.973
# loss_G_BA_identity: 0.329
# loss_G_BA_cycle: 0.414
# loss_G_BA_cam: 1.062
#
# loss_D_LA: 0.528
# loss_D_LA_GAN: 0.331
# loss_D_LA_cam: 0.197
# loss_D_GA: 0.690
# loss_D_GA_GAN: 0.367
# loss_D_GA_cam: 0.322
# loss_D_LB: 1.199
# loss_D_LB_GAN: 0.446
# loss_D_LB_cam: 0.754
# loss_D_GB: 1.114
# loss_D_GB_GAN: 0.411
# loss_D_GB_cam: 0.702
#
# [100/300000]
# D_loss : 3.1696
# G_loss: 4521.0732
# Time: 0.0:2.0:47
# loss_G_AB: 2268.388
# loss_G_AB_GAN: 1.395
# loss_G_AB_identity: 0.178
# loss_G_AB_cycle: 0.175
# loss_G_AB_cam: 2.263
# loss_G_BA: 2252.685
# loss_G_BA_GAN: 1.112
# loss_G_BA_identity: 0.251
# loss_G_BA_cycle: 0.278
# loss_G_BA_cam: 2.246
#
# loss_D_LA: 0.381
# loss_D_LA_GAN: 0.292
# loss_D_LA_cam: 0.089
# loss_D_GA: 0.727
# loss_D_GA_GAN: 0.394
# loss_D_GA_cam: 0.333
# loss_D_LB: 1.005
# loss_D_LB_GAN: 0.404
# loss_D_LB_cam: 0.600
# loss_D_GB: 1.057
# loss_D_GB_GAN: 0.405
# loss_D_GB_cam: 0.652
#
# [110/300000]
# D_loss : 2.9223
# G_loss: 1504.6277
# Time: 0.0:3.0:8
# loss_G_AB: 796.334
# loss_G_AB_GAN: 1.146
# loss_G_AB_identity: 0.280
# loss_G_AB_cycle: 0.294
# loss_G_AB_cam: 0.789
# loss_G_BA: 708.293
# loss_G_BA_GAN: 0.908
# loss_G_BA_identity: 0.196
# loss_G_BA_cycle: 0.234
# loss_G_BA_cam: 0.703
#
# loss_D_LA: 0.653
# loss_D_LA_GAN: 0.361
# loss_D_LA_cam: 0.291
# loss_D_GA: 0.725
# loss_D_GA_GAN: 0.386
# loss_D_GA_cam: 0.339
# loss_D_LB: 0.535
# loss_D_LB_GAN: 0.312
# loss_D_LB_cam: 0.223
# loss_D_GB: 1.010
# loss_D_GB_GAN: 0.405
# loss_D_GB_cam: 0.605
#
# [120/300000]
# D_loss : 3.5675
# G_loss: 5439.3613
# Time: 0.0:3.0:25
# loss_G_AB: 2243.306
# loss_G_AB_GAN: 1.221
# loss_G_AB_identity: 0.177
# loss_G_AB_cycle: 0.182
# loss_G_AB_cam: 2.238
# loss_G_BA: 3196.055
# loss_G_BA_GAN: 1.053
# loss_G_BA_identity: 0.200
# loss_G_BA_cycle: 0.191
# loss_G_BA_cam: 3.191
#
# loss_D_LA: 0.908
# loss_D_LA_GAN: 0.444
# loss_D_LA_cam: 0.465
# loss_D_GA: 0.919
# loss_D_GA_GAN: 0.415
# loss_D_GA_cam: 0.504
# loss_D_LB: 0.778
# loss_D_LB_GAN: 0.381
# loss_D_LB_cam: 0.397
# loss_D_GB: 0.962
# loss_D_GB_GAN: 0.405
# loss_D_GB_cam: 0.557
#
# [130/300000]
# D_loss : 3.9443
# G_loss: 4480.6592
# Time: 0.0:3.0:42
# loss_G_AB: 2059.607
# loss_G_AB_GAN: 0.860
# loss_G_AB_identity: 0.163
# loss_G_AB_cycle: 0.162
# loss_G_AB_cam: 2.056
# loss_G_BA: 2421.052
# loss_G_BA_GAN: 1.433
# loss_G_BA_identity: 0.230
# loss_G_BA_cycle: 0.253
# loss_G_BA_cam: 2.415
#
# loss_D_LA: 0.764
# loss_D_LA_GAN: 0.412
# loss_D_LA_cam: 0.352
# loss_D_GA: 1.124
# loss_D_GA_GAN: 0.426
# loss_D_GA_cam: 0.698
# loss_D_LB: 1.172
# loss_D_LB_GAN: 0.495
# loss_D_LB_cam: 0.678
# loss_D_GB: 0.884
# loss_D_GB_GAN: 0.404
# loss_D_GB_cam: 0.479
#
# [140/300000]
# D_loss : 2.6206
# G_loss: 2047.8472
# Time: 0.0:3.0:58
# loss_G_AB: 972.575
# loss_G_AB_GAN: 1.223
# loss_G_AB_identity: 0.225
# loss_G_AB_cycle: 0.245
# loss_G_AB_cam: 0.967
# loss_G_BA: 1075.272
# loss_G_BA_GAN: 1.071
# loss_G_BA_identity: 0.222
# loss_G_BA_cycle: 0.235
# loss_G_BA_cam: 1.070
#
# loss_D_LA: 0.713
# loss_D_LA_GAN: 0.386
# loss_D_LA_cam: 0.328
# loss_D_GA: 0.804
# loss_D_GA_GAN: 0.391
# loss_D_GA_cam: 0.413
# loss_D_LB: 0.220
# loss_D_LB_GAN: 0.157
# loss_D_LB_cam: 0.063
# loss_D_GB: 0.884
# loss_D_GB_GAN: 0.409
# loss_D_GB_cam: 0.474
#
# [150/300000]
# D_loss : 2.3538
# G_loss: 1923.4988
# Time: 0.0:4.0:14
# loss_G_AB: 1048.140
# loss_G_AB_GAN: 1.031
# loss_G_AB_identity: 0.349
# loss_G_AB_cycle: 0.380
# loss_G_AB_cam: 1.040
# loss_G_BA: 875.359
# loss_G_BA_GAN: 1.185
# loss_G_BA_identity: 0.209
# loss_G_BA_cycle: 0.251
# loss_G_BA_cam: 0.870
#
# loss_D_LA: 0.568
# loss_D_LA_GAN: 0.327
# loss_D_LA_cam: 0.241
# loss_D_GA: 0.702
# loss_D_GA_GAN: 0.365
# loss_D_GA_cam: 0.337
# loss_D_LB: 0.331
# loss_D_LB_GAN: 0.205
# loss_D_LB_cam: 0.126
# loss_D_GB: 0.753
# loss_D_GB_GAN: 0.400
# loss_D_GB_cam: 0.353
#
# [160/300000]
# D_loss : 6.4207
# G_loss: 1351.3781
# Time: 0.0:4.0:32
# loss_G_AB: 677.859
# loss_G_AB_GAN: 0.985
# loss_G_AB_identity: 0.435
# loss_G_AB_cycle: 0.450
# loss_G_AB_cam: 0.668
# loss_G_BA: 673.519
# loss_G_BA_GAN: 0.597
# loss_G_BA_identity: 0.256
# loss_G_BA_cycle: 0.298
# loss_G_BA_cam: 0.667
#
# loss_D_LA: 0.561
# loss_D_LA_GAN: 0.331
# loss_D_LA_cam: 0.230
# loss_D_GA: 0.518
# loss_D_GA_GAN: 0.316
# loss_D_GA_cam: 0.203
# loss_D_LB: 4.470
# loss_D_LB_GAN: 1.797
# loss_D_LB_cam: 2.673
# loss_D_GB: 0.872
# loss_D_GB_GAN: 0.409
# loss_D_GB_cam: 0.463
#
# [170/300000]
# D_loss : 2.9957
# G_loss: 1401.5986
# Time: 0.0:4.0:49
# loss_G_AB: 708.025
# loss_G_AB_GAN: 0.971
# loss_G_AB_identity: 0.387
# loss_G_AB_cycle: 0.419
# loss_G_AB_cam: 0.699
# loss_G_BA: 693.574
# loss_G_BA_GAN: 0.980
# loss_G_BA_identity: 0.190
# loss_G_BA_cycle: 0.290
# loss_G_BA_cam: 0.688
#
# loss_D_LA: 0.707
# loss_D_LA_GAN: 0.362
# loss_D_LA_cam: 0.344
# loss_D_GA: 0.916
# loss_D_GA_GAN: 0.432
# loss_D_GA_cam: 0.484
# loss_D_LB: 0.487
# loss_D_LB_GAN: 0.240
# loss_D_LB_cam: 0.247
# loss_D_GB: 0.887
# loss_D_GB_GAN: 0.408
# loss_D_GB_cam: 0.479
#
# [180/300000]
# D_loss : 2.5026
# G_loss: 4021.7314
# Time: 0.0:5.0:5
# loss_G_AB: 2036.513
# loss_G_AB_GAN: 0.888
# loss_G_AB_identity: 0.345
# loss_G_AB_cycle: 0.354
# loss_G_AB_cam: 2.029
# loss_G_BA: 1985.218
# loss_G_BA_GAN: 1.101
# loss_G_BA_identity: 0.257
# loss_G_BA_cycle: 0.298
# loss_G_BA_cam: 1.979
#
# loss_D_LA: 0.547
# loss_D_LA_GAN: 0.314
# loss_D_LA_cam: 0.233
# loss_D_GA: 0.732
# loss_D_GA_GAN: 0.374
# loss_D_GA_cam: 0.358
# loss_D_LB: 0.362
# loss_D_LB_GAN: 0.223
# loss_D_LB_cam: 0.139
# loss_D_GB: 0.862
# loss_D_GB_GAN: 0.404
# loss_D_GB_cam: 0.458
#
# [190/300000]
# D_loss : 2.0873
# G_loss: 2451.5845
# Time: 0.0:5.0:22
# loss_G_AB: 1266.460
# loss_G_AB_GAN: 1.275
# loss_G_AB_identity: 0.335
# loss_G_AB_cycle: 0.343
# loss_G_AB_cam: 1.258
# loss_G_BA: 1185.125
# loss_G_BA_GAN: 0.824
# loss_G_BA_identity: 0.190
# loss_G_BA_cycle: 0.200
# loss_G_BA_cam: 1.180
#
# loss_D_LA: 0.390
# loss_D_LA_GAN: 0.245
# loss_D_LA_cam: 0.145
# loss_D_GA: 0.662
# loss_D_GA_GAN: 0.358
# loss_D_GA_cam: 0.304
# loss_D_LB: 0.326
# loss_D_LB_GAN: 0.177
# loss_D_LB_cam: 0.149
# loss_D_GB: 0.709
# loss_D_GB_GAN: 0.392
# loss_D_GB_cam: 0.318
#
# [200/300000]
# D_loss : 2.8394
# G_loss: 1797.5312
# Time: 0.0:5.0:38
# loss_G_AB: 811.168
# loss_G_AB_GAN: 1.031
# loss_G_AB_identity: 0.293
# loss_G_AB_cycle: 0.291
# loss_G_AB_cam: 0.804
# loss_G_BA: 986.363
# loss_G_BA_GAN: 0.796
# loss_G_BA_identity: 0.156
# loss_G_BA_cycle: 0.164
# loss_G_BA_cam: 0.982
#
# loss_D_LA: 0.711
# loss_D_LA_GAN: 0.382
# loss_D_LA_cam: 0.329
# loss_D_GA: 0.638
# loss_D_GA_GAN: 0.345
# loss_D_GA_cam: 0.294
# loss_D_LB: 0.716
# loss_D_LB_GAN: 0.404
# loss_D_LB_cam: 0.312
# loss_D_GB: 0.774
# loss_D_GB_GAN: 0.394
# loss_D_GB_cam: 0.380
#
# [210/300000]
# D_loss : 2.7100
# G_loss: 3161.2261
# Time: 0.0:6.0:0
# loss_G_AB: 1387.398
# loss_G_AB_GAN: 1.183
# loss_G_AB_identity: 0.162
# loss_G_AB_cycle: 0.175
# loss_G_AB_cam: 1.383
# loss_G_BA: 1773.828
# loss_G_BA_GAN: 0.956
# loss_G_BA_identity: 0.256
# loss_G_BA_cycle: 0.246
# loss_G_BA_cam: 1.768
#
# loss_D_LA: 0.496
# loss_D_LA_GAN: 0.321
# loss_D_LA_cam: 0.176
# loss_D_GA: 0.854
# loss_D_GA_GAN: 0.418
# loss_D_GA_cam: 0.436
# loss_D_LB: 0.512
# loss_D_LB_GAN: 0.308
# loss_D_LB_cam: 0.204
# loss_D_GB: 0.847
# loss_D_GB_GAN: 0.410
# loss_D_GB_cam: 0.437
#
# [220/300000]
# D_loss : 3.6779
# G_loss: 3143.4480
# Time: 0.0:6.0:16
# loss_G_AB: 1348.669
# loss_G_AB_GAN: 1.538
# loss_G_AB_identity: 0.307
# loss_G_AB_cycle: 0.319
# loss_G_AB_cam: 1.341
# loss_G_BA: 1794.779
# loss_G_BA_GAN: 1.684
# loss_G_BA_identity: 0.369
# loss_G_BA_cycle: 0.344
# loss_G_BA_cam: 1.786
#
# loss_D_LA: 0.686
# loss_D_LA_GAN: 0.414
# loss_D_LA_cam: 0.272
# loss_D_GA: 1.104
# loss_D_GA_GAN: 0.490
# loss_D_GA_cam: 0.614
# loss_D_LB: 1.030
# loss_D_LB_GAN: 0.475
# loss_D_LB_cam: 0.555
# loss_D_GB: 0.859
# loss_D_GB_GAN: 0.403
# loss_D_GB_cam: 0.456
#
# [230/300000]
# D_loss : 3.6440
# G_loss: 1404.3972
# Time: 0.0:6.0:33
# loss_G_AB: 691.483
# loss_G_AB_GAN: 1.211
# loss_G_AB_identity: 0.324
# loss_G_AB_cycle: 0.332
# loss_G_AB_cam: 0.684
# loss_G_BA: 712.915
# loss_G_BA_GAN: 1.265
# loss_G_BA_identity: 0.286
# loss_G_BA_cycle: 0.290
# loss_G_BA_cam: 0.706
#
# loss_D_LA: 0.611
# loss_D_LA_GAN: 0.235
# loss_D_LA_cam: 0.376
# loss_D_GA: 0.802
# loss_D_GA_GAN: 0.394
# loss_D_GA_cam: 0.408
# loss_D_LB: 1.178
# loss_D_LB_GAN: 0.576
# loss_D_LB_cam: 0.602
# loss_D_GB: 1.052
# loss_D_GB_GAN: 0.457
# loss_D_GB_cam: 0.594
#
# [240/300000]
# D_loss : 2.0421
# G_loss: 1936.6764
# Time: 0.0:6.0:50
# loss_G_AB: 863.967
# loss_G_AB_GAN: 1.175
# loss_G_AB_identity: 0.381
# loss_G_AB_cycle: 0.377
# loss_G_AB_cam: 0.855
# loss_G_BA: 1072.709
# loss_G_BA_GAN: 0.899
# loss_G_BA_identity: 0.227
# loss_G_BA_cycle: 0.226
# loss_G_BA_cam: 1.067
#
# loss_D_LA: 0.237
# loss_D_LA_GAN: 0.170
# loss_D_LA_cam: 0.067
# loss_D_GA: 0.604
# loss_D_GA_GAN: 0.329
# loss_D_GA_cam: 0.275
# loss_D_LB: 0.661
# loss_D_LB_GAN: 0.363
# loss_D_LB_cam: 0.298
# loss_D_GB: 0.540
# loss_D_GB_GAN: 0.319
# loss_D_GB_cam: 0.221
#
# [250/300000]
# D_loss : 2.1771
# G_loss: 1638.6779
# Time: 0.0:7.0:6
# loss_G_AB: 883.711
# loss_G_AB_GAN: 1.561
# loss_G_AB_identity: 0.198
# loss_G_AB_cycle: 0.204
# loss_G_AB_cam: 0.878
# loss_G_BA: 754.967
# loss_G_BA_GAN: 1.085
# loss_G_BA_identity: 0.353
# loss_G_BA_cycle: 0.358
# loss_G_BA_cam: 0.747
#
# loss_D_LA: 0.837
# loss_D_LA_GAN: 0.443
# loss_D_LA_cam: 0.394
# loss_D_GA: 0.806
# loss_D_GA_GAN: 0.398
# loss_D_GA_cam: 0.407
# loss_D_LB: 0.249
# loss_D_LB_GAN: 0.166
# loss_D_LB_cam: 0.084
# loss_D_GB: 0.285
# loss_D_GB_GAN: 0.183
# loss_D_GB_cam: 0.102
#
# [260/300000]
# D_loss : 3.4846
# G_loss: 1354.1501
# Time: 0.0:7.0:23
# loss_G_AB: 681.525
# loss_G_AB_GAN: 1.673
# loss_G_AB_identity: 0.203
# loss_G_AB_cycle: 0.185
# loss_G_AB_cam: 0.676
# loss_G_BA: 672.625
# loss_G_BA_GAN: 1.314
# loss_G_BA_identity: 0.313
# loss_G_BA_cycle: 0.347
# loss_G_BA_cam: 0.665
#
# loss_D_LA: 0.958
# loss_D_LA_GAN: 0.458
# loss_D_LA_cam: 0.500
# loss_D_GA: 1.092
# loss_D_GA_GAN: 0.516
# loss_D_GA_cam: 0.577
# loss_D_LB: 0.480
# loss_D_LB_GAN: 0.280
# loss_D_LB_cam: 0.200
# loss_D_GB: 0.955
# loss_D_GB_GAN: 0.469
# loss_D_GB_cam: 0.486
#
# [270/300000]
# D_loss : 2.9448
# G_loss: 1370.6321
# Time: 0.0:7.0:40
# loss_G_AB: 663.242
# loss_G_AB_GAN: 1.020
# loss_G_AB_identity: 0.267
# loss_G_AB_cycle: 0.270
# loss_G_AB_cam: 0.657
# loss_G_BA: 707.390
# loss_G_BA_GAN: 1.417
# loss_G_BA_identity: 0.168
# loss_G_BA_cycle: 0.210
# loss_G_BA_cam: 0.702
#
# loss_D_LA: 0.459
# loss_D_LA_GAN: 0.311
# loss_D_LA_cam: 0.148
# loss_D_GA: 0.995
# loss_D_GA_GAN: 0.408
# loss_D_GA_cam: 0.588
# loss_D_LB: 0.724
# loss_D_LB_GAN: 0.385
# loss_D_LB_cam: 0.339
# loss_D_GB: 0.766
# loss_D_GB_GAN: 0.380
# loss_D_GB_cam: 0.385
#
# [280/300000]
# D_loss : 2.1732
# G_loss: 1288.3654
# Time: 0.0:7.0:57
# loss_G_AB: 621.852
# loss_G_AB_GAN: 1.222
# loss_G_AB_identity: 0.142
# loss_G_AB_cycle: 0.177
# loss_G_AB_cam: 0.617
# loss_G_BA: 666.514
# loss_G_BA_GAN: 1.337
# loss_G_BA_identity: 0.185
# loss_G_BA_cycle: 0.217
# loss_G_BA_cam: 0.661
#
# loss_D_LA: 0.448
# loss_D_LA_GAN: 0.299
# loss_D_LA_cam: 0.149
# loss_D_GA: 0.927
# loss_D_GA_GAN: 0.404
# loss_D_GA_cam: 0.522
# loss_D_LB: 0.402
# loss_D_LB_GAN: 0.237
# loss_D_LB_cam: 0.165
# loss_D_GB: 0.396
# loss_D_GB_GAN: 0.206
# loss_D_GB_cam: 0.190
#
# [290/300000]
# D_loss : 2.4319
# G_loss: 1790.4181
# Time: 0.0:8.0:14
# loss_G_AB: 955.641
# loss_G_AB_GAN: 1.539
# loss_G_AB_identity: 0.189
# loss_G_AB_cycle: 0.175
# loss_G_AB_cam: 0.950
# loss_G_BA: 834.777
# loss_G_BA_GAN: 1.209
# loss_G_BA_identity: 0.246
# loss_G_BA_cycle: 0.250
# loss_G_BA_cam: 0.829
#
# loss_D_LA: 0.458
# loss_D_LA_GAN: 0.300
# loss_D_LA_cam: 0.157
# loss_D_GA: 0.872
# loss_D_GA_GAN: 0.406
# loss_D_GA_cam: 0.466
# loss_D_LB: 0.484
# loss_D_LB_GAN: 0.284
# loss_D_LB_cam: 0.200
# loss_D_GB: 0.619
# loss_D_GB_GAN: 0.315
# loss_D_GB_cam: 0.304
#
# [300/300000]
# D_loss : 2.8962
# G_loss: 1730.7076
# Time: 0.0:8.0:31
# loss_G_AB: 771.106
# loss_G_AB_GAN: 1.740
# loss_G_AB_identity: 0.153
# loss_G_AB_cycle: 0.165
# loss_G_AB_cam: 0.766
# loss_G_BA: 959.602
# loss_G_BA_GAN: 1.329
# loss_G_BA_identity: 0.341
# loss_G_BA_cycle: 0.338
# loss_G_BA_cam: 0.951
#
# loss_D_LA: 0.374
# loss_D_LA_GAN: 0.292
# loss_D_LA_cam: 0.082
# loss_D_GA: 0.818
# loss_D_GA_GAN: 0.401
# loss_D_GA_cam: 0.417
# loss_D_LB: 0.716
# loss_D_LB_GAN: 0.457
# loss_D_LB_cam: 0.258
# loss_D_GB: 0.988
# loss_D_GB_GAN: 0.489
# loss_D_GB_cam: 0.499
#
# [310/300000]
# D_loss : 2.8506
# G_loss: 1615.7659
# Time: 0.0:8.0:52
# loss_G_AB: 811.294
# loss_G_AB_GAN: 1.416
# loss_G_AB_identity: 0.277
# loss_G_AB_cycle: 0.284
# loss_G_AB_cam: 0.804
# loss_G_BA: 804.472
# loss_G_BA_GAN: 0.967
# loss_G_BA_identity: 0.218
# loss_G_BA_cycle: 0.257
# loss_G_BA_cam: 0.799
#
# loss_D_LA: 0.457
# loss_D_LA_GAN: 0.304
# loss_D_LA_cam: 0.153
# loss_D_GA: 0.681
# loss_D_GA_GAN: 0.383
# loss_D_GA_cam: 0.298
# loss_D_LB: 0.789
# loss_D_LB_GAN: 0.403
# loss_D_LB_cam: 0.385
# loss_D_GB: 0.924
# loss_D_GB_GAN: 0.462
# loss_D_GB_cam: 0.462
#
# [320/300000]
# D_loss : 2.6091
# G_loss: 1554.6420
# Time: 0.0:9.0:9
# loss_G_AB: 763.343
# loss_G_AB_GAN: 1.331
# loss_G_AB_identity: 0.188
# loss_G_AB_cycle: 0.204
# loss_G_AB_cam: 0.758
# loss_G_BA: 791.299
# loss_G_BA_GAN: 1.159
# loss_G_BA_identity: 0.291
# loss_G_BA_cycle: 0.300
# loss_G_BA_cam: 0.784
#
# loss_D_LA: 0.365
# loss_D_LA_GAN: 0.214
# loss_D_LA_cam: 0.152
# loss_D_GA: 0.879
# loss_D_GA_GAN: 0.415
# loss_D_GA_cam: 0.464
# loss_D_LB: 0.542
# loss_D_LB_GAN: 0.284
# loss_D_LB_cam: 0.258
# loss_D_GB: 0.823
# loss_D_GB_GAN: 0.392
# loss_D_GB_cam: 0.431
#
# [330/300000]
# D_loss : 2.9472
# G_loss: 2691.6904
# Time: 0.0:9.0:26
# loss_G_AB: 1259.427
# loss_G_AB_GAN: 1.319
# loss_G_AB_identity: 0.294
# loss_G_AB_cycle: 0.312
# loss_G_AB_cam: 1.252
# loss_G_BA: 1432.263
# loss_G_BA_GAN: 1.181
# loss_G_BA_identity: 0.179
# loss_G_BA_cycle: 0.191
# loss_G_BA_cam: 1.427
#
# loss_D_LA: 0.851
# loss_D_LA_GAN: 0.421
# loss_D_LA_cam: 0.430
# loss_D_GA: 0.815
# loss_D_GA_GAN: 0.405
# loss_D_GA_cam: 0.410
# loss_D_LB: 0.709
# loss_D_LB_GAN: 0.359
# loss_D_LB_cam: 0.350
# loss_D_GB: 0.573
# loss_D_GB_GAN: 0.307
# loss_D_GB_cam: 0.266
#
# [340/300000]
# D_loss : 2.6654
# G_loss: 2288.4495
# Time: 0.0:9.0:43
# loss_G_AB: 1200.798
# loss_G_AB_GAN: 0.634
# loss_G_AB_identity: 0.382
# loss_G_AB_cycle: 0.383
# loss_G_AB_cam: 1.193
# loss_G_BA: 1087.651
# loss_G_BA_GAN: 0.935
# loss_G_BA_identity: 0.407
# loss_G_BA_cycle: 0.391
# loss_G_BA_cam: 1.079
#
# loss_D_LA: 0.939
# loss_D_LA_GAN: 0.427
# loss_D_LA_cam: 0.512
# loss_D_GA: 0.750
# loss_D_GA_GAN: 0.394
# loss_D_GA_cam: 0.356
# loss_D_LB: 0.451
# loss_D_LB_GAN: 0.266
# loss_D_LB_cam: 0.185
# loss_D_GB: 0.525
# loss_D_GB_GAN: 0.290
# loss_D_GB_cam: 0.236
#
# [350/300000]
# D_loss : 1.9193
# G_loss: 1282.8618
# Time: 0.0:10.0:0
# loss_G_AB: 624.802
# loss_G_AB_GAN: 1.383
# loss_G_AB_identity: 0.237
# loss_G_AB_cycle: 0.240
# loss_G_AB_cam: 0.619
# loss_G_BA: 658.060
# loss_G_BA_GAN: 0.741
# loss_G_BA_identity: 0.203
# loss_G_BA_cycle: 0.211
# loss_G_BA_cam: 0.653
#
# loss_D_LA: 0.602
# loss_D_LA_GAN: 0.324
# loss_D_LA_cam: 0.277
# loss_D_GA: 0.852
# loss_D_GA_GAN: 0.412
# loss_D_GA_cam: 0.440
# loss_D_LB: 0.241
# loss_D_LB_GAN: 0.099
# loss_D_LB_cam: 0.143
# loss_D_GB: 0.225
# loss_D_GB_GAN: 0.121
# loss_D_GB_cam: 0.104
#
# [360/300000]
# D_loss : 2.8993
# G_loss: 2847.9226
# Time: 0.0:10.0:17
# loss_G_AB: 1027.352
# loss_G_AB_GAN: 0.444
# loss_G_AB_identity: 0.259
# loss_G_AB_cycle: 0.265
# loss_G_AB_cam: 1.022
# loss_G_BA: 1820.571
# loss_G_BA_GAN: 0.563
# loss_G_BA_identity: 0.159
# loss_G_BA_cycle: 0.176
# loss_G_BA_cam: 1.817
#
# loss_D_LA: 0.931
# loss_D_LA_GAN: 0.400
# loss_D_LA_cam: 0.531
# loss_D_GA: 0.710
# loss_D_GA_GAN: 0.375
# loss_D_GA_cam: 0.335
# loss_D_LB: 0.580
# loss_D_LB_GAN: 0.319
# loss_D_LB_cam: 0.260
# loss_D_GB: 0.679
# loss_D_GB_GAN: 0.346
# loss_D_GB_cam: 0.333
#
# [370/300000]
# D_loss : 2.5880
# G_loss: 4227.5083
# Time: 0.0:10.0:34
# loss_G_AB: 2364.720
# loss_G_AB_GAN: 0.195
# loss_G_AB_identity: 0.378
# loss_G_AB_cycle: 0.365
# loss_G_AB_cam: 2.357
# loss_G_BA: 1862.789
# loss_G_BA_GAN: 0.865
# loss_G_BA_identity: 0.257
# loss_G_BA_cycle: 0.256
# loss_G_BA_cam: 1.857
#
# loss_D_LA: 0.786
# loss_D_LA_GAN: 0.403
# loss_D_LA_cam: 0.383
# loss_D_GA: 0.728
# loss_D_GA_GAN: 0.386
# loss_D_GA_cam: 0.342
# loss_D_LB: 0.513
# loss_D_LB_GAN: 0.342
# loss_D_LB_cam: 0.170
# loss_D_GB: 0.562
# loss_D_GB_GAN: 0.287
# loss_D_GB_cam: 0.275
#
# [380/300000]
# D_loss : 3.4198
# G_loss: 3067.7842
# Time: 0.0:10.0:50
# loss_G_AB: 1727.384
# loss_G_AB_GAN: 1.402
# loss_G_AB_identity: 0.215
# loss_G_AB_cycle: 0.167
# loss_G_AB_cam: 1.722
# loss_G_BA: 1340.401
# loss_G_BA_GAN: 0.779
# loss_G_BA_identity: 0.177
# loss_G_BA_cycle: 0.164
# loss_G_BA_cam: 1.336
#
# loss_D_LA: 0.949
# loss_D_LA_GAN: 0.460
# loss_D_LA_cam: 0.489
# loss_D_GA: 0.850
# loss_D_GA_GAN: 0.412
# loss_D_GA_cam: 0.437
# loss_D_LB: 0.811
# loss_D_LB_GAN: 0.429
# loss_D_LB_cam: 0.382
# loss_D_GB: 0.810
# loss_D_GB_GAN: 0.406
# loss_D_GB_cam: 0.404
#
# [390/300000]
# D_loss : 2.4708
# G_loss: 1480.0793
# Time: 0.0:11.0:6
# loss_G_AB: 687.081
# loss_G_AB_GAN: 0.459
# loss_G_AB_identity: 0.129
# loss_G_AB_cycle: 0.143
# loss_G_AB_cam: 0.684
# loss_G_BA: 792.999
# loss_G_BA_GAN: 1.040
# loss_G_BA_identity: 0.232
# loss_G_BA_cycle: 0.231
# loss_G_BA_cam: 0.787
#
# loss_D_LA: 0.528
# loss_D_LA_GAN: 0.316
# loss_D_LA_cam: 0.212
# loss_D_GA: 0.899
# loss_D_GA_GAN: 0.423
# loss_D_GA_cam: 0.476
# loss_D_LB: 0.576
# loss_D_LB_GAN: 0.326
# loss_D_LB_cam: 0.250
# loss_D_GB: 0.468
# loss_D_GB_GAN: 0.247
# loss_D_GB_cam: 0.220
#
# [400/300000]
# D_loss : 3.2470
# G_loss: 2035.2506
# Time: 0.0:11.0:23
# loss_G_AB: 655.956
# loss_G_AB_GAN: 0.709
# loss_G_AB_identity: 0.202
# loss_G_AB_cycle: 0.206
# loss_G_AB_cam: 0.651
# loss_G_BA: 1379.294
# loss_G_BA_GAN: 0.749
# loss_G_BA_identity: 0.263
# loss_G_BA_cycle: 0.258
# loss_G_BA_cam: 1.373
#
# loss_D_LA: 0.422
# loss_D_LA_GAN: 0.258
# loss_D_LA_cam: 0.164
# loss_D_GA: 0.842
# loss_D_GA_GAN: 0.421
# loss_D_GA_cam: 0.420
# loss_D_LB: 1.112
# loss_D_LB_GAN: 0.551
# loss_D_LB_cam: 0.561
# loss_D_GB: 0.871
# loss_D_GB_GAN: 0.433
# loss_D_GB_cam: 0.438
#
# [410/300000]
# D_loss : 2.2671
# G_loss: 3133.8760
# Time: 0.0:11.0:44
# loss_G_AB: 1345.255
# loss_G_AB_GAN: 0.318
# loss_G_AB_identity: 0.310
# loss_G_AB_cycle: 0.299
# loss_G_AB_cam: 1.339
# loss_G_BA: 1788.621
# loss_G_BA_GAN: 1.177
# loss_G_BA_identity: 0.173
# loss_G_BA_cycle: 0.182
# loss_G_BA_cam: 1.784
#
# loss_D_LA: 0.635
# loss_D_LA_GAN: 0.345
# loss_D_LA_cam: 0.290
# loss_D_GA: 0.844
# loss_D_GA_GAN: 0.415
# loss_D_GA_cam: 0.429
# loss_D_LB: 0.400
# loss_D_LB_GAN: 0.215
# loss_D_LB_cam: 0.186
# loss_D_GB: 0.387
# loss_D_GB_GAN: 0.202
# loss_D_GB_cam: 0.186
#
# [420/300000]
# D_loss : 2.2074
# G_loss: 1420.8279
# Time: 0.0:12.0:1
# loss_G_AB: 706.391
# loss_G_AB_GAN: 1.305
# loss_G_AB_identity: 0.222
# loss_G_AB_cycle: 0.220
# loss_G_AB_cam: 0.701
# loss_G_BA: 714.437
# loss_G_BA_GAN: 0.908
# loss_G_BA_identity: 0.146
# loss_G_BA_cycle: 0.176
# loss_G_BA_cam: 0.710
#
# loss_D_LA: 0.675
# loss_D_LA_GAN: 0.379
# loss_D_LA_cam: 0.296
# loss_D_GA: 0.831
# loss_D_GA_GAN: 0.409
# loss_D_GA_cam: 0.422
# loss_D_LB: 0.520
# loss_D_LB_GAN: 0.290
# loss_D_LB_cam: 0.231
# loss_D_GB: 0.182
# loss_D_GB_GAN: 0.093
# loss_D_GB_cam: 0.089
#
# [430/300000]
# D_loss : 3.7413
# G_loss: 1159.3958
# Time: 0.0:12.0:18
# loss_G_AB: 563.400
# loss_G_AB_GAN: 2.038
# loss_G_AB_identity: 0.176
# loss_G_AB_cycle: 0.177
# loss_G_AB_cam: 0.558
# loss_G_BA: 595.996
# loss_G_BA_GAN: 0.438
# loss_G_BA_identity: 0.199
# loss_G_BA_cycle: 0.193
# loss_G_BA_cam: 0.592
#
# loss_D_LA: 0.853
# loss_D_LA_GAN: 0.473
# loss_D_LA_cam: 0.380
# loss_D_GA: 0.912
# loss_D_GA_GAN: 0.441
# loss_D_GA_cam: 0.471
# loss_D_LB: 0.835
# loss_D_LB_GAN: 0.422
# loss_D_LB_cam: 0.413
# loss_D_GB: 1.141
# loss_D_GB_GAN: 0.606
# loss_D_GB_cam: 0.536
#
# [440/300000]
# D_loss : 3.3671
# G_loss: 1806.5234
# Time: 0.0:12.0:37
# loss_G_AB: 768.732
# loss_G_AB_GAN: 1.158
# loss_G_AB_identity: 0.387
# loss_G_AB_cycle: 0.387
# loss_G_AB_cam: 0.760
# loss_G_BA: 1037.792
# loss_G_BA_GAN: 1.238
# loss_G_BA_identity: 0.310
# loss_G_BA_cycle: 0.285
# loss_G_BA_cam: 1.031
#
# loss_D_LA: 0.523
# loss_D_LA_GAN: 0.326
# loss_D_LA_cam: 0.197
# loss_D_GA: 0.838
# loss_D_GA_GAN: 0.402
# loss_D_GA_cam: 0.437
# loss_D_LB: 1.107
# loss_D_LB_GAN: 0.527
# loss_D_LB_cam: 0.580
# loss_D_GB: 0.899
# loss_D_GB_GAN: 0.409
# loss_D_GB_cam: 0.490
#
# [450/300000]
# D_loss : 3.5709
# G_loss: 2173.0869
# Time: 0.0:12.0:53
# loss_G_AB: 1068.962
# loss_G_AB_GAN: 1.383
# loss_G_AB_identity: 0.260
# loss_G_AB_cycle: 0.296
# loss_G_AB_cam: 1.062
# loss_G_BA: 1104.125
# loss_G_BA_GAN: 0.860
# loss_G_BA_identity: 0.210
# loss_G_BA_cycle: 0.271
# loss_G_BA_cam: 1.098
#
# loss_D_LA: 1.088
# loss_D_LA_GAN: 0.473
# loss_D_LA_cam: 0.615
# loss_D_GA: 0.798
# loss_D_GA_GAN: 0.408
# loss_D_GA_cam: 0.390
# loss_D_LB: 0.824
# loss_D_LB_GAN: 0.389
# loss_D_LB_cam: 0.436
# loss_D_GB: 0.861
# loss_D_GB_GAN: 0.405
# loss_D_GB_cam: 0.456
#
# [460/300000]
# D_loss : 2.5883
# G_loss: 1133.2397
# Time: 0.0:13.0:10
# loss_G_AB: 534.456
# loss_G_AB_GAN: 0.946
# loss_G_AB_identity: 0.213
# loss_G_AB_cycle: 0.217
# loss_G_AB_cam: 0.529
# loss_G_BA: 598.784
# loss_G_BA_GAN: 0.926
# loss_G_BA_identity: 0.209
# loss_G_BA_cycle: 0.215
# loss_G_BA_cam: 0.594
#
# loss_D_LA: 0.266
# loss_D_LA_GAN: 0.207
# loss_D_LA_cam: 0.059
# loss_D_GA: 0.890
# loss_D_GA_GAN: 0.397
# loss_D_GA_cam: 0.493
# loss_D_LB: 0.599
# loss_D_LB_GAN: 0.343
# loss_D_LB_cam: 0.256
# loss_D_GB: 0.833
# loss_D_GB_GAN: 0.405
# loss_D_GB_cam: 0.428
#
# [470/300000]
# D_loss : 2.2271
# G_loss: 1930.4147
# Time: 0.0:13.0:26
# loss_G_AB: 1100.452
# loss_G_AB_GAN: 1.131
# loss_G_AB_identity: 0.229
# loss_G_AB_cycle: 0.222
# loss_G_AB_cam: 1.095
# loss_G_BA: 829.963
# loss_G_BA_GAN: 0.946
# loss_G_BA_identity: 0.274
# loss_G_BA_cycle: 0.276
# loss_G_BA_cam: 0.824
#
# loss_D_LA: 0.245
# loss_D_LA_GAN: 0.152
# loss_D_LA_cam: 0.093
# loss_D_GA: 0.922
# loss_D_GA_GAN: 0.443
# loss_D_GA_cam: 0.479
# loss_D_LB: 0.243
# loss_D_LB_GAN: 0.170
# loss_D_LB_cam: 0.073
# loss_D_GB: 0.817
# loss_D_GB_GAN: 0.405
# loss_D_GB_cam: 0.412
#
# [480/300000]
# D_loss : 3.2524
# G_loss: 1082.3635
# Time: 0.0:13.0:49
# loss_G_AB: 516.640
# loss_G_AB_GAN: 1.253
# loss_G_AB_identity: 0.116
# loss_G_AB_cycle: 0.132
# loss_G_AB_cam: 0.513
# loss_G_BA: 565.724
# loss_G_BA_GAN: 1.538
# loss_G_BA_identity: 0.314
# loss_G_BA_cycle: 0.323
# loss_G_BA_cam: 0.558
#
# loss_D_LA: 0.975
# loss_D_LA_GAN: 0.511
# loss_D_LA_cam: 0.464
# loss_D_GA: 0.824
# loss_D_GA_GAN: 0.406
# loss_D_GA_cam: 0.417
# loss_D_LB: 0.629
# loss_D_LB_GAN: 0.336
# loss_D_LB_cam: 0.292
# loss_D_GB: 0.825
# loss_D_GB_GAN: 0.406
# loss_D_GB_cam: 0.419
#
# [490/300000]
# D_loss : 2.6555
# G_loss: 1970.3662
# Time: 0.0:14.0:5
# loss_G_AB: 702.175
# loss_G_AB_GAN: 1.075
# loss_G_AB_identity: 0.186
# loss_G_AB_cycle: 0.197
# loss_G_AB_cam: 0.697
# loss_G_BA: 1268.191
# loss_G_BA_GAN: 1.634
# loss_G_BA_identity: 0.164
# loss_G_BA_cycle: 0.168
# loss_G_BA_cam: 1.263
#
# loss_D_LA: 0.444
# loss_D_LA_GAN: 0.286
# loss_D_LA_cam: 0.157
# loss_D_GA: 0.812
# loss_D_GA_GAN: 0.405
# loss_D_GA_cam: 0.407
# loss_D_LB: 0.581
# loss_D_LB_GAN: 0.316
# loss_D_LB_cam: 0.265
# loss_D_GB: 0.819
# loss_D_GB_GAN: 0.405
# loss_D_GB_cam: 0.414
#
# [500/300000]
# D_loss : 2.9335
# G_loss: 1927.2800
# Time: 0.0:14.0:22
# loss_G_AB: 1119.061
# loss_G_AB_GAN: 0.995
# loss_G_AB_identity: 0.197
# loss_G_AB_cycle: 0.241
# loss_G_AB_cam: 1.114
# loss_G_BA: 808.219
# loss_G_BA_GAN: 1.184
# loss_G_BA_identity: 0.242
# loss_G_BA_cycle: 0.238
# loss_G_BA_cam: 0.802
#
# loss_D_LA: 0.332
# loss_D_LA_GAN: 0.220
# loss_D_LA_cam: 0.112
# loss_D_GA: 0.868
# loss_D_GA_GAN: 0.426
# loss_D_GA_cam: 0.442
# loss_D_LB: 0.915
# loss_D_LB_GAN: 0.429
# loss_D_LB_cam: 0.487
# loss_D_GB: 0.818
# loss_D_GB_GAN: 0.405
# loss_D_GB_cam: 0.412
#
# [510/300000]
# D_loss : 3.1402
# G_loss: 6400.6279
# Time: 0.0:14.0:48
# loss_G_AB: 2170.126
# loss_G_AB_GAN: 1.185
# loss_G_AB_identity: 0.147
# loss_G_AB_cycle: 0.158
# loss_G_AB_cam: 2.166
# loss_G_BA: 4230.502
# loss_G_BA_GAN: 1.547
# loss_G_BA_identity: 0.332
# loss_G_BA_cycle: 0.331
# loss_G_BA_cam: 4.222
#
# loss_D_LA: 1.250
# loss_D_LA_GAN: 0.525
# loss_D_LA_cam: 0.725
# loss_D_GA: 0.611
# loss_D_GA_GAN: 0.321
# loss_D_GA_cam: 0.290
# loss_D_LB: 0.465
# loss_D_LB_GAN: 0.242
# loss_D_LB_cam: 0.223
# loss_D_GB: 0.814
# loss_D_GB_GAN: 0.405
# loss_D_GB_cam: 0.409
#
# [520/300000]
# D_loss : 2.4025
# G_loss: 4308.5757
# Time: 0.0:15.0:5
# loss_G_AB: 1955.303
# loss_G_AB_GAN: 1.085
# loss_G_AB_identity: 0.130
# loss_G_AB_cycle: 0.141
# loss_G_AB_cam: 1.952
# loss_G_BA: 2353.273
# loss_G_BA_GAN: 1.594
# loss_G_BA_identity: 0.324
# loss_G_BA_cycle: 0.321
# loss_G_BA_cam: 2.345
#
# loss_D_LA: 0.473
# loss_D_LA_GAN: 0.236
# loss_D_LA_cam: 0.237
# loss_D_GA: 0.546
# loss_D_GA_GAN: 0.294
# loss_D_GA_cam: 0.252
# loss_D_LB: 0.572
# loss_D_LB_GAN: 0.298
# loss_D_LB_cam: 0.274
# loss_D_GB: 0.811
# loss_D_GB_GAN: 0.405
# loss_D_GB_cam: 0.406
#
# [530/300000]
# D_loss : 2.4516
# G_loss: 1306.3750
# Time: 0.0:15.0:22
# loss_G_AB: 642.751
# loss_G_AB_GAN: 0.930
# loss_G_AB_identity: 0.288
# loss_G_AB_cycle: 0.298
# loss_G_AB_cam: 0.636
# loss_G_BA: 663.624
# loss_G_BA_GAN: 0.931
# loss_G_BA_identity: 0.187
# loss_G_BA_cycle: 0.190
# loss_G_BA_cam: 0.659
#
# loss_D_LA: 0.315
# loss_D_LA_GAN: 0.186
# loss_D_LA_cam: 0.129
# loss_D_GA: 0.677
# loss_D_GA_GAN: 0.355
# loss_D_GA_cam: 0.322
# loss_D_LB: 0.646
# loss_D_LB_GAN: 0.334
# loss_D_LB_cam: 0.313
# loss_D_GB: 0.813
# loss_D_GB_GAN: 0.405
# loss_D_GB_cam: 0.408
#
# [540/300000]
# D_loss : 2.5807
# G_loss: 1485.6482
# Time: 0.0:15.0:39
# loss_G_AB: 738.620
# loss_G_AB_GAN: 0.904
# loss_G_AB_identity: 0.339
# loss_G_AB_cycle: 0.323
# loss_G_AB_cam: 0.731
# loss_G_BA: 747.028
# loss_G_BA_GAN: 0.745
# loss_G_BA_identity: 0.183
# loss_G_BA_cycle: 0.192
# loss_G_BA_cam: 0.743
#
# loss_D_LA: 0.549
# loss_D_LA_GAN: 0.325
# loss_D_LA_cam: 0.224
# loss_D_GA: 0.737
# loss_D_GA_GAN: 0.375
# loss_D_GA_cam: 0.362
# loss_D_LB: 0.488
# loss_D_LB_GAN: 0.277
# loss_D_LB_cam: 0.210
# loss_D_GB: 0.807
# loss_D_GB_GAN: 0.405
# loss_D_GB_cam: 0.402
#
# [550/300000]
# D_loss : 2.0658
# G_loss: 1269.6914
# Time: 0.0:15.0:55
# loss_G_AB: 625.157
# loss_G_AB_GAN: 0.957
# loss_G_AB_identity: 0.200
# loss_G_AB_cycle: 0.218
# loss_G_AB_cam: 0.620
# loss_G_BA: 644.534
# loss_G_BA_GAN: 1.311
# loss_G_BA_identity: 0.137
# loss_G_BA_cycle: 0.166
# loss_G_BA_cam: 0.640
#
# loss_D_LA: 0.355
# loss_D_LA_GAN: 0.226
# loss_D_LA_cam: 0.128
# loss_D_GA: 0.439
# loss_D_GA_GAN: 0.243
# loss_D_GA_cam: 0.196
# loss_D_LB: 0.458
# loss_D_LB_GAN: 0.254
# loss_D_LB_cam: 0.204
# loss_D_GB: 0.814
# loss_D_GB_GAN: 0.405
# loss_D_GB_cam: 0.409
#
# [560/300000]
# D_loss : 2.4671
# G_loss: 4619.6182
# Time: 0.0:16.0:13
# loss_G_AB: 2322.709
# loss_G_AB_GAN: 1.112
# loss_G_AB_identity: 0.310
# loss_G_AB_cycle: 0.321
# loss_G_AB_cam: 2.315
# loss_G_BA: 2296.909
# loss_G_BA_GAN: 1.088
# loss_G_BA_identity: 0.174
# loss_G_BA_cycle: 0.175
# loss_G_BA_cam: 2.292
#
# loss_D_LA: 0.580
# loss_D_LA_GAN: 0.345
# loss_D_LA_cam: 0.235
# loss_D_GA: 0.860
# loss_D_GA_GAN: 0.407
# loss_D_GA_cam: 0.453
# loss_D_LB: 0.220
# loss_D_LB_GAN: 0.119
# loss_D_LB_cam: 0.101
# loss_D_GB: 0.807
# loss_D_GB_GAN: 0.405
# loss_D_GB_cam: 0.403
#
# [570/300000]
# D_loss : 2.7981
# G_loss: 1303.2937
# Time: 0.0:16.0:29
# loss_G_AB: 616.924
# loss_G_AB_GAN: 0.700
# loss_G_AB_identity: 0.267
# loss_G_AB_cycle: 0.243
# loss_G_AB_cam: 0.611
# loss_G_BA: 686.369
# loss_G_BA_GAN: 1.014
# loss_G_BA_identity: 0.153
# loss_G_BA_cycle: 0.164
# loss_G_BA_cam: 0.682
#
# loss_D_LA: 0.590
# loss_D_LA_GAN: 0.315
# loss_D_LA_cam: 0.275
# loss_D_GA: 0.831
# loss_D_GA_GAN: 0.405
# loss_D_GA_cam: 0.426
# loss_D_LB: 0.566
# loss_D_LB_GAN: 0.311
# loss_D_LB_cam: 0.255
# loss_D_GB: 0.811
# loss_D_GB_GAN: 0.405
# loss_D_GB_cam: 0.406
#
# [580/300000]
# D_loss : 2.9475
# G_loss: 1477.3944
# Time: 0.0:16.0:45
# loss_G_AB: 679.380
# loss_G_AB_GAN: 0.962
# loss_G_AB_identity: 0.216
# loss_G_AB_cycle: 0.208
# loss_G_AB_cam: 0.674
# loss_G_BA: 798.014
# loss_G_BA_GAN: 0.747
# loss_G_BA_identity: 0.197
# loss_G_BA_cycle: 0.215
# loss_G_BA_cam: 0.793
#
# loss_D_LA: 0.790
# loss_D_LA_GAN: 0.435
# loss_D_LA_cam: 0.355
# loss_D_GA: 0.828
# loss_D_GA_GAN: 0.407
# loss_D_GA_cam: 0.421
# loss_D_LB: 0.521
# loss_D_LB_GAN: 0.287
# loss_D_LB_cam: 0.234
# loss_D_GB: 0.809
# loss_D_GB_GAN: 0.405
# loss_D_GB_cam: 0.404
#
# [590/300000]
# D_loss : 2.2766
# G_loss: 1163.0847
# Time: 0.0:17.0:2
# loss_G_AB: 557.750
# loss_G_AB_GAN: 1.074
# loss_G_AB_identity: 0.226
# loss_G_AB_cycle: 0.234
# loss_G_AB_cam: 0.552
# loss_G_BA: 605.335
# loss_G_BA_GAN: 1.151
# loss_G_BA_identity: 0.236
# loss_G_BA_cycle: 0.267
# loss_G_BA_cam: 0.599
#
# loss_D_LA: 0.484
# loss_D_LA_GAN: 0.294
# loss_D_LA_cam: 0.190
# loss_D_GA: 0.811
# loss_D_GA_GAN: 0.405
# loss_D_GA_cam: 0.406
# loss_D_LB: 0.173
# loss_D_LB_GAN: 0.108
# loss_D_LB_cam: 0.065
# loss_D_GB: 0.809
# loss_D_GB_GAN: 0.405
# loss_D_GB_cam: 0.404
#
# [600/300000]
# D_loss : 2.5257
# G_loss: 4701.5034
# Time: 0.0:17.0:18
# loss_G_AB: 3133.319
# loss_G_AB_GAN: 0.957
# loss_G_AB_identity: 0.261
# loss_G_AB_cycle: 0.273
# loss_G_AB_cam: 3.127
# loss_G_BA: 1568.185
# loss_G_BA_GAN: 1.216
# loss_G_BA_identity: 0.272
# loss_G_BA_cycle: 0.288
# loss_G_BA_cam: 1.561
#
# loss_D_LA: 0.649
# loss_D_LA_GAN: 0.341
# loss_D_LA_cam: 0.308
# loss_D_GA: 0.803
# loss_D_GA_GAN: 0.403
# loss_D_GA_cam: 0.400
# loss_D_LB: 0.274
# loss_D_LB_GAN: 0.182
# loss_D_LB_cam: 0.092
# loss_D_GB: 0.800
# loss_D_GB_GAN: 0.404
# loss_D_GB_cam: 0.395
#
# [610/300000]
# D_loss : 2.6462
# G_loss: 1231.1584
# Time: 0.0:17.0:39
# loss_G_AB: 606.322
# loss_G_AB_GAN: 0.772
# loss_G_AB_identity: 0.208
# loss_G_AB_cycle: 0.206
# loss_G_AB_cam: 0.601
# loss_G_BA: 624.837
# loss_G_BA_GAN: 1.158
# loss_G_BA_identity: 0.161
# loss_G_BA_cycle: 0.176
# loss_G_BA_cam: 0.620
#
# loss_D_LA: 0.350
# loss_D_LA_GAN: 0.225
# loss_D_LA_cam: 0.125
# loss_D_GA: 0.807
# loss_D_GA_GAN: 0.404
# loss_D_GA_cam: 0.404
# loss_D_LB: 0.678
# loss_D_LB_GAN: 0.364
# loss_D_LB_cam: 0.314
# loss_D_GB: 0.811
# loss_D_GB_GAN: 0.405
# loss_D_GB_cam: 0.406
#
# [620/300000]
# D_loss : 2.9460
# G_loss: 1228.2295
# Time: 0.0:17.0:56
# loss_G_AB: 631.318
# loss_G_AB_GAN: 1.018
# loss_G_AB_identity: 0.212
# loss_G_AB_cycle: 0.219
# loss_G_AB_cam: 0.626
# loss_G_BA: 596.911
# loss_G_BA_GAN: 0.743
# loss_G_BA_identity: 0.166
# loss_G_BA_cycle: 0.218
# loss_G_BA_cam: 0.592
#
# loss_D_LA: 0.774
# loss_D_LA_GAN: 0.425
# loss_D_LA_cam: 0.349
# loss_D_GA: 0.800
# loss_D_GA_GAN: 0.403
# loss_D_GA_cam: 0.397
# loss_D_LB: 0.564
# loss_D_LB_GAN: 0.287
# loss_D_LB_cam: 0.277
# loss_D_GB: 0.808
# loss_D_GB_GAN: 0.405
# loss_D_GB_cam: 0.403
#
# [630/300000]
# D_loss : 3.0149
# G_loss: 1185.8301
# Time: 0.0:18.0:12
# loss_G_AB: 579.466
# loss_G_AB_GAN: 1.094
# loss_G_AB_identity: 0.467
# loss_G_AB_cycle: 0.460
# loss_G_AB_cam: 0.569
# loss_G_BA: 606.364
# loss_G_BA_GAN: 1.385
# loss_G_BA_identity: 0.231
# loss_G_BA_cycle: 0.224
# loss_G_BA_cam: 0.600
#
# loss_D_LA: 0.644
# loss_D_LA_GAN: 0.391
# loss_D_LA_cam: 0.253
# loss_D_GA: 0.808
# loss_D_GA_GAN: 0.405
# loss_D_GA_cam: 0.403
# loss_D_LB: 0.750
# loss_D_LB_GAN: 0.400
# loss_D_LB_cam: 0.351
# loss_D_GB: 0.812
# loss_D_GB_GAN: 0.405
# loss_D_GB_cam: 0.407
#
# [640/300000]
# D_loss : 3.4971
# G_loss: 1318.9824
# Time: 0.0:18.0:36
# loss_G_AB: 596.684
# loss_G_AB_GAN: 0.580
# loss_G_AB_identity: 0.277
# loss_G_AB_cycle: 0.271
# loss_G_AB_cam: 0.591
# loss_G_BA: 722.299
# loss_G_BA_GAN: 0.854
# loss_G_BA_identity: 0.192
# loss_G_BA_cycle: 0.196
# loss_G_BA_cam: 0.718
#
# loss_D_LA: 0.465
# loss_D_LA_GAN: 0.253
# loss_D_LA_cam: 0.212
# loss_D_GA: 0.818
# loss_D_GA_GAN: 0.407
# loss_D_GA_cam: 0.411
# loss_D_LB: 1.387
# loss_D_LB_GAN: 0.672
# loss_D_LB_cam: 0.715
# loss_D_GB: 0.827
# loss_D_GB_GAN: 0.406
# loss_D_GB_cam: 0.421
#
# [650/300000]
# D_loss : 2.3020
# G_loss: 1842.5891
# Time: 0.0:18.0:52
# loss_G_AB: 948.432
# loss_G_AB_GAN: 0.991
# loss_G_AB_identity: 0.158
# loss_G_AB_cycle: 0.172
# loss_G_AB_cam: 0.944
# loss_G_BA: 894.157
# loss_G_BA_GAN: 0.687
# loss_G_BA_identity: 0.219
# loss_G_BA_cycle: 0.211
# loss_G_BA_cam: 0.889
#
# loss_D_LA: 0.212
# loss_D_LA_GAN: 0.162
# loss_D_LA_cam: 0.050
# loss_D_GA: 0.813
# loss_D_GA_GAN: 0.406
# loss_D_GA_cam: 0.407
# loss_D_LB: 0.463
# loss_D_LB_GAN: 0.237
# loss_D_LB_cam: 0.225
# loss_D_GB: 0.814
# loss_D_GB_GAN: 0.405
# loss_D_GB_cam: 0.409
#
# [660/300000]
# D_loss : 2.7712
# G_loss: 1343.0107
# Time: 0.0:19.0:9
# loss_G_AB: 694.350
# loss_G_AB_GAN: 0.772
# loss_G_AB_identity: 0.431
# loss_G_AB_cycle: 0.426
# loss_G_AB_cam: 0.685
# loss_G_BA: 648.661
# loss_G_BA_GAN: 0.666
# loss_G_BA_identity: 0.193
# loss_G_BA_cycle: 0.215
# loss_G_BA_cam: 0.644
#
# loss_D_LA: 0.886
# loss_D_LA_GAN: 0.440
# loss_D_LA_cam: 0.447
# loss_D_GA: 0.813
# loss_D_GA_GAN: 0.404
# loss_D_GA_cam: 0.408
# loss_D_LB: 0.280
# loss_D_LB_GAN: 0.130
# loss_D_LB_cam: 0.150
# loss_D_GB: 0.792
# loss_D_GB_GAN: 0.403
# loss_D_GB_cam: 0.389
#
# [670/300000]
# D_loss : 2.7411
# G_loss: 1428.0139
# Time: 0.0:19.0:26
# loss_G_AB: 707.606
# loss_G_AB_GAN: 1.392
# loss_G_AB_identity: 0.183
# loss_G_AB_cycle: 0.207
# loss_G_AB_cam: 0.702
# loss_G_BA: 720.408
# loss_G_BA_GAN: 1.360
# loss_G_BA_identity: 0.282
# loss_G_BA_cycle: 0.301
# loss_G_BA_cam: 0.713
#
# loss_D_LA: 0.216
# loss_D_LA_GAN: 0.164
# loss_D_LA_cam: 0.053
# loss_D_GA: 0.817
# loss_D_GA_GAN: 0.408
# loss_D_GA_cam: 0.409
# loss_D_LB: 0.896
# loss_D_LB_GAN: 0.445
# loss_D_LB_cam: 0.452
# loss_D_GB: 0.812
# loss_D_GB_GAN: 0.405
# loss_D_GB_cam: 0.406
#
# [680/300000]
# D_loss : 2.2890
# G_loss: 2268.3784
# Time: 0.0:19.0:43
# loss_G_AB: 1076.228
# loss_G_AB_GAN: 0.999
# loss_G_AB_identity: 0.192
# loss_G_AB_cycle: 0.201
# loss_G_AB_cam: 1.071
# loss_G_BA: 1192.151
# loss_G_BA_GAN: 0.751
# loss_G_BA_identity: 0.166
# loss_G_BA_cycle: 0.174
# loss_G_BA_cam: 1.188
#
# loss_D_LA: 0.417
# loss_D_LA_GAN: 0.259
# loss_D_LA_cam: 0.158
# loss_D_GA: 0.832
# loss_D_GA_GAN: 0.409
# loss_D_GA_cam: 0.422
# loss_D_LB: 0.240
# loss_D_LB_GAN: 0.138
# loss_D_LB_cam: 0.103
# loss_D_GB: 0.800
# loss_D_GB_GAN: 0.404
# loss_D_GB_cam: 0.396
#
# [690/300000]
# D_loss : 2.7809
# G_loss: 3153.2864
# Time: 0.0:20.0:2
# loss_G_AB: 1637.380
# loss_G_AB_GAN: 1.220
# loss_G_AB_identity: 0.297
# loss_G_AB_cycle: 0.299
# loss_G_AB_cam: 1.630
# loss_G_BA: 1515.907
# loss_G_BA_GAN: 1.079
# loss_G_BA_identity: 0.214
# loss_G_BA_cycle: 0.229
# loss_G_BA_cam: 1.510
#
# loss_D_LA: 0.637
# loss_D_LA_GAN: 0.423
# loss_D_LA_cam: 0.214
# loss_D_GA: 0.809
# loss_D_GA_GAN: 0.405
# loss_D_GA_cam: 0.403
# loss_D_LB: 0.519
# loss_D_LB_GAN: 0.278
# loss_D_LB_cam: 0.242
# loss_D_GB: 0.815
# loss_D_GB_GAN: 0.405
# loss_D_GB_cam: 0.410
#
# [700/300000]
# D_loss : 2.4361
# G_loss: 1250.4570
# Time: 0.0:20.0:19
# loss_G_AB: 662.295
# loss_G_AB_GAN: 1.059
# loss_G_AB_identity: 0.224
# loss_G_AB_cycle: 0.226
# loss_G_AB_cam: 0.657
# loss_G_BA: 588.162
# loss_G_BA_GAN: 1.506
# loss_G_BA_identity: 0.349
# loss_G_BA_cycle: 0.377
# loss_G_BA_cam: 0.579
#
# loss_D_LA: 0.632
# loss_D_LA_GAN: 0.373
# loss_D_LA_cam: 0.259
# loss_D_GA: 0.736
# loss_D_GA_GAN: 0.383
# loss_D_GA_cam: 0.353
# loss_D_LB: 0.255
# loss_D_LB_GAN: 0.170
# loss_D_LB_cam: 0.085
# loss_D_GB: 0.813
# loss_D_GB_GAN: 0.405
# loss_D_GB_cam: 0.408
#
# [710/300000]
# D_loss : 2.2093
# G_loss: 3647.5598
# Time: 0.0:20.0:39
# loss_G_AB: 1845.698
# loss_G_AB_GAN: 0.535
# loss_G_AB_identity: 0.177
# loss_G_AB_cycle: 0.187
# loss_G_AB_cam: 1.842
# loss_G_BA: 1801.862
# loss_G_BA_GAN: 1.145
# loss_G_BA_identity: 0.234
# loss_G_BA_cycle: 0.253
# loss_G_BA_cam: 1.796
#
# loss_D_LA: 0.229
# loss_D_LA_GAN: 0.175
# loss_D_LA_cam: 0.053
# loss_D_GA: 0.801
# loss_D_GA_GAN: 0.401
# loss_D_GA_cam: 0.400
# loss_D_LB: 0.368
# loss_D_LB_GAN: 0.242
# loss_D_LB_cam: 0.126
# loss_D_GB: 0.811
# loss_D_GB_GAN: 0.405
# loss_D_GB_cam: 0.406
#
# [720/300000]
# D_loss : 4.0558
# G_loss: 1185.7437
# Time: 0.0:20.0:56
# loss_G_AB: 596.724
# loss_G_AB_GAN: 0.576
# loss_G_AB_identity: 0.324
# loss_G_AB_cycle: 0.319
# loss_G_AB_cam: 0.590
# loss_G_BA: 589.019
# loss_G_BA_GAN: 0.632
# loss_G_BA_identity: 0.306
# loss_G_BA_cycle: 0.311
# loss_G_BA_cam: 0.582
#
# loss_D_LA: 1.466
# loss_D_LA_GAN: 0.678
# loss_D_LA_cam: 0.788
# loss_D_GA: 0.847
# loss_D_GA_GAN: 0.416
# loss_D_GA_cam: 0.431
# loss_D_LB: 0.957
# loss_D_LB_GAN: 0.520
# loss_D_LB_cam: 0.437
# loss_D_GB: 0.786
# loss_D_GB_GAN: 0.403
# loss_D_GB_cam: 0.383
#
# [730/300000]
# D_loss : 2.9647
# G_loss: 1278.9857
# Time: 0.0:21.0:15
# loss_G_AB: 652.134
# loss_G_AB_GAN: 1.081
# loss_G_AB_identity: 0.242
# loss_G_AB_cycle: 0.243
# loss_G_AB_cam: 0.646
# loss_G_BA: 626.852
# loss_G_BA_GAN: 1.056
# loss_G_BA_identity: 0.138
# loss_G_BA_cycle: 0.142
# loss_G_BA_cam: 0.623
#
# loss_D_LA: 0.938
# loss_D_LA_GAN: 0.461
# loss_D_LA_cam: 0.477
# loss_D_GA: 0.813
# loss_D_GA_GAN: 0.405
# loss_D_GA_cam: 0.409
# loss_D_LB: 0.425
# loss_D_LB_GAN: 0.264
# loss_D_LB_cam: 0.161
# loss_D_GB: 0.788
# loss_D_GB_GAN: 0.403
# loss_D_GB_cam: 0.386
#
# [740/300000]
# D_loss : 2.4709
# G_loss: 1222.0093
# Time: 0.0:21.0:31
# loss_G_AB: 569.897
# loss_G_AB_GAN: 1.155
# loss_G_AB_identity: 0.228
# loss_G_AB_cycle: 0.240
# loss_G_AB_cam: 0.564
# loss_G_BA: 652.112
# loss_G_BA_GAN: 0.892
# loss_G_BA_identity: 0.210
# loss_G_BA_cycle: 0.230
# loss_G_BA_cam: 0.647
#
# loss_D_LA: 0.585
# loss_D_LA_GAN: 0.319
# loss_D_LA_cam: 0.267
# loss_D_GA: 0.800
# loss_D_GA_GAN: 0.401
# loss_D_GA_cam: 0.399
# loss_D_LB: 0.259
# loss_D_LB_GAN: 0.173
# loss_D_LB_cam: 0.085
# loss_D_GB: 0.827
# loss_D_GB_GAN: 0.404
# loss_D_GB_cam: 0.424
#
# [750/300000]
# D_loss : 2.3330
# G_loss: 2803.2837
# Time: 0.0:21.0:48
# loss_G_AB: 1301.397
# loss_G_AB_GAN: 1.195
# loss_G_AB_identity: 0.275
# loss_G_AB_cycle: 0.279
# loss_G_AB_cam: 1.295
# loss_G_BA: 1501.887
# loss_G_BA_GAN: 0.803
# loss_G_BA_identity: 0.225
# loss_G_BA_cycle: 0.242
# loss_G_BA_cam: 1.496
#
# loss_D_LA: 0.328
# loss_D_LA_GAN: 0.225
# loss_D_LA_cam: 0.104
# loss_D_GA: 0.750
# loss_D_GA_GAN: 0.382
# loss_D_GA_cam: 0.368
# loss_D_LB: 0.495
# loss_D_LB_GAN: 0.265
# loss_D_LB_cam: 0.229
# loss_D_GB: 0.760
# loss_D_GB_GAN: 0.398
# loss_D_GB_cam: 0.363
#
# [760/300000]
# D_loss : 1.9332
# G_loss: 2859.3284
# Time: 0.0:22.0:12
# loss_G_AB: 1440.453
# loss_G_AB_GAN: 1.039
# loss_G_AB_identity: 0.270
# loss_G_AB_cycle: 0.297
# loss_G_AB_cam: 1.434
# loss_G_BA: 1418.875
# loss_G_BA_GAN: 0.621
# loss_G_BA_identity: 0.176
# loss_G_BA_cycle: 0.185
# loss_G_BA_cam: 1.415
#
# loss_D_LA: 0.187
# loss_D_LA_GAN: 0.154
# loss_D_LA_cam: 0.033
# loss_D_GA: 0.721
# loss_D_GA_GAN: 0.373
# loss_D_GA_cam: 0.349
# loss_D_LB: 0.244
# loss_D_LB_GAN: 0.137
# loss_D_LB_cam: 0.108
# loss_D_GB: 0.780
# loss_D_GB_GAN: 0.401
# loss_D_GB_cam: 0.380
#
# [770/300000]
# D_loss : 1.8031
# G_loss: 1849.8063
# Time: 0.0:22.0:28
# loss_G_AB: 952.548
# loss_G_AB_GAN: 1.205
# loss_G_AB_identity: 0.312
# loss_G_AB_cycle: 0.357
# loss_G_AB_cam: 0.945
# loss_G_BA: 897.259
# loss_G_BA_GAN: 0.588
# loss_G_BA_identity: 0.255
# loss_G_BA_cycle: 0.252
# loss_G_BA_cam: 0.892
#
# loss_D_LA: 0.256
# loss_D_LA_GAN: 0.147
# loss_D_LA_cam: 0.108
# loss_D_GA: 0.625
# loss_D_GA_GAN: 0.338
# loss_D_GA_cam: 0.286
# loss_D_LB: 0.183
# loss_D_LB_GAN: 0.100
# loss_D_LB_cam: 0.083
# loss_D_GB: 0.740
# loss_D_GB_GAN: 0.396
# loss_D_GB_cam: 0.344
#
# [780/300000]
# D_loss : 2.7562
# G_loss: 1283.6674
# Time: 0.0:22.0:46
# loss_G_AB: 603.996
# loss_G_AB_GAN: 0.829
# loss_G_AB_identity: 0.229
# loss_G_AB_cycle: 0.230
# loss_G_AB_cam: 0.599
# loss_G_BA: 679.671
# loss_G_BA_GAN: 0.677
# loss_G_BA_identity: 0.238
# loss_G_BA_cycle: 0.244
# loss_G_BA_cam: 0.674
#
# loss_D_LA: 0.378
# loss_D_LA_GAN: 0.221
# loss_D_LA_cam: 0.157
# loss_D_GA: 0.826
# loss_D_GA_GAN: 0.407
# loss_D_GA_cam: 0.419
# loss_D_LB: 0.753
# loss_D_LB_GAN: 0.395
# loss_D_LB_cam: 0.358
# loss_D_GB: 0.799
# loss_D_GB_GAN: 0.402
# loss_D_GB_cam: 0.397
#
# [790/300000]
# D_loss : 2.4028
# G_loss: 1421.3821
# Time: 0.0:23.0:2
# loss_G_AB: 646.037
# loss_G_AB_GAN: 1.097
# loss_G_AB_identity: 0.177
# loss_G_AB_cycle: 0.176
# loss_G_AB_cam: 0.641
# loss_G_BA: 775.345
# loss_G_BA_GAN: 0.567
# loss_G_BA_identity: 0.227
# loss_G_BA_cycle: 0.233
# loss_G_BA_cam: 0.770
#
# loss_D_LA: 0.653
# loss_D_LA_GAN: 0.351
# loss_D_LA_cam: 0.302
# loss_D_GA: 0.851
# loss_D_GA_GAN: 0.418
# loss_D_GA_cam: 0.433
# loss_D_LB: 0.150
# loss_D_LB_GAN: 0.103
# loss_D_LB_cam: 0.047
# loss_D_GB: 0.748
# loss_D_GB_GAN: 0.394
# loss_D_GB_cam: 0.354
#
# [800/300000]
# D_loss : 2.8893
# G_loss: 1511.7291
# Time: 0.0:23.0:19
# loss_G_AB: 600.552
# loss_G_AB_GAN: 1.096
# loss_G_AB_identity: 0.266
# loss_G_AB_cycle: 0.273
# loss_G_AB_cam: 0.594
# loss_G_BA: 911.177
# loss_G_BA_GAN: 0.965
# loss_G_BA_identity: 0.174
# loss_G_BA_cycle: 0.178
# loss_G_BA_cam: 0.907
#
# loss_D_LA: 0.704
# loss_D_LA_GAN: 0.383
# loss_D_LA_cam: 0.321
# loss_D_GA: 0.792
# loss_D_GA_GAN: 0.400
# loss_D_GA_cam: 0.392
# loss_D_LB: 0.718
# loss_D_LB_GAN: 0.364
# loss_D_LB_cam: 0.354
# loss_D_GB: 0.675
# loss_D_GB_GAN: 0.375
# loss_D_GB_cam: 0.300
#
# [810/300000]
# D_loss : 2.3418
# G_loss: 930.9594
# Time: 0.0:23.0:40
# loss_G_AB: 420.436
# loss_G_AB_GAN: 1.051
# loss_G_AB_identity: 0.273
# loss_G_AB_cycle: 0.288
# loss_G_AB_cam: 0.414
# loss_G_BA: 510.523
# loss_G_BA_GAN: 1.315
# loss_G_BA_identity: 0.155
# loss_G_BA_cycle: 0.183
# loss_G_BA_cam: 0.506
#
# loss_D_LA: 0.591
# loss_D_LA_GAN: 0.289
# loss_D_LA_cam: 0.302
# loss_D_GA: 0.764
# loss_D_GA_GAN: 0.390
# loss_D_GA_cam: 0.374
# loss_D_LB: 0.330
# loss_D_LB_GAN: 0.192
# loss_D_LB_cam: 0.138
# loss_D_GB: 0.656
# loss_D_GB_GAN: 0.361
# loss_D_GB_cam: 0.295
#
# [820/300000]
# D_loss : 2.5926
# G_loss: 3133.0142
# Time: 0.0:23.0:56
# loss_G_AB: 1951.182
# loss_G_AB_GAN: 0.970
# loss_G_AB_identity: 0.507
# loss_G_AB_cycle: 0.555
# loss_G_AB_cam: 1.940
# loss_G_BA: 1181.832
# loss_G_BA_GAN: 1.272
# loss_G_BA_identity: 0.148
# loss_G_BA_cycle: 0.156
# loss_G_BA_cam: 1.178
#
# loss_D_LA: 0.458
# loss_D_LA_GAN: 0.273
# loss_D_LA_cam: 0.185
# loss_D_GA: 0.770
# loss_D_GA_GAN: 0.392
# loss_D_GA_cam: 0.378
# loss_D_LB: 0.864
# loss_D_LB_GAN: 0.376
# loss_D_LB_cam: 0.487
# loss_D_GB: 0.501
# loss_D_GB_GAN: 0.297
# loss_D_GB_cam: 0.203
#
# [830/300000]
# D_loss : 2.0259
# G_loss: 1661.3906
# Time: 0.0:24.0:14
# loss_G_AB: 859.332
# loss_G_AB_GAN: 1.091
# loss_G_AB_identity: 0.168
# loss_G_AB_cycle: 0.174
# loss_G_AB_cam: 0.855
# loss_G_BA: 802.058
# loss_G_BA_GAN: 0.951
# loss_G_BA_identity: 0.417
# loss_G_BA_cycle: 0.416
# loss_G_BA_cam: 0.793
#
# loss_D_LA: 0.557
# loss_D_LA_GAN: 0.321
# loss_D_LA_cam: 0.237
# loss_D_GA: 0.738
# loss_D_GA_GAN: 0.377
# loss_D_GA_cam: 0.361
# loss_D_LB: 0.208
# loss_D_LB_GAN: 0.096
# loss_D_LB_cam: 0.112
# loss_D_GB: 0.522
# loss_D_GB_GAN: 0.273
# loss_D_GB_cam: 0.249
#
# [840/300000]
# D_loss : 2.9436
# G_loss: 1847.7246
# Time: 0.0:24.0:30
# loss_G_AB: 1200.730
# loss_G_AB_GAN: 1.957
# loss_G_AB_identity: 0.240
# loss_G_AB_cycle: 0.255
# loss_G_AB_cam: 1.194
# loss_G_BA: 646.995
# loss_G_BA_GAN: 1.108
# loss_G_BA_identity: 0.274
# loss_G_BA_cycle: 0.277
# loss_G_BA_cam: 0.640
#
# loss_D_LA: 0.636
# loss_D_LA_GAN: 0.371
# loss_D_LA_cam: 0.265
# loss_D_GA: 0.874
# loss_D_GA_GAN: 0.425
# loss_D_GA_cam: 0.449
# loss_D_LB: 0.448
# loss_D_LB_GAN: 0.265
# loss_D_LB_cam: 0.184
# loss_D_GB: 0.985
# loss_D_GB_GAN: 0.502
# loss_D_GB_cam: 0.483
#
# [850/300000]
# D_loss : 2.2884
# G_loss: 4839.4824
# Time: 0.0:24.0:47
# loss_G_AB: 2729.960
# loss_G_AB_GAN: 1.116
# loss_G_AB_identity: 0.413
# loss_G_AB_cycle: 0.391
# loss_G_AB_cam: 2.721
# loss_G_BA: 2109.523
# loss_G_BA_GAN: 0.935
# loss_G_BA_identity: 0.161
# loss_G_BA_cycle: 0.170
# loss_G_BA_cam: 2.105
#
# loss_D_LA: 0.633
# loss_D_LA_GAN: 0.357
# loss_D_LA_cam: 0.276
# loss_D_GA: 0.843
# loss_D_GA_GAN: 0.420
# loss_D_GA_cam: 0.423
# loss_D_LB: 0.217
# loss_D_LB_GAN: 0.128
# loss_D_LB_cam: 0.089
# loss_D_GB: 0.595
# loss_D_GB_GAN: 0.311
# loss_D_GB_cam: 0.284
#
# [860/300000]
# D_loss : 5.5777
# G_loss: 868.8056
# Time: 0.0:25.0:3
# loss_G_AB: 417.191
# loss_G_AB_GAN: 0.468
# loss_G_AB_identity: 0.246
# loss_G_AB_cycle: 0.266
# loss_G_AB_cam: 0.412
# loss_G_BA: 451.615
# loss_G_BA_GAN: 0.836
# loss_G_BA_identity: 0.256
# loss_G_BA_cycle: 0.297
# loss_G_BA_cam: 0.445
#
# loss_D_LA: 0.231
# loss_D_LA_GAN: 0.181
# loss_D_LA_cam: 0.049
# loss_D_GA: 0.856
# loss_D_GA_GAN: 0.422
# loss_D_GA_cam: 0.434
# loss_D_LB: 1.088
# loss_D_LB_GAN: 0.650
# loss_D_LB_cam: 0.438
# loss_D_GB: 3.404
# loss_D_GB_GAN: 1.546
# loss_D_GB_cam: 1.858
#
# [870/300000]
# D_loss : 3.4423
# G_loss: 925.4504
# Time: 0.0:25.0:20
# loss_G_AB: 456.288
# loss_G_AB_GAN: 0.873
# loss_G_AB_identity: 0.231
# loss_G_AB_cycle: 0.223
# loss_G_AB_cam: 0.451
# loss_G_BA: 469.162
# loss_G_BA_GAN: 0.862
# loss_G_BA_identity: 0.183
# loss_G_BA_cycle: 0.186
# loss_G_BA_cam: 0.465
#
# loss_D_LA: 0.723
# loss_D_LA_GAN: 0.411
# loss_D_LA_cam: 0.312
# loss_D_GA: 0.835
# loss_D_GA_GAN: 0.417
# loss_D_GA_cam: 0.418
# loss_D_LB: 0.998
# loss_D_LB_GAN: 0.541
# loss_D_LB_cam: 0.457
# loss_D_GB: 0.886
# loss_D_GB_GAN: 0.415
# loss_D_GB_cam: 0.471
#
# [880/300000]
# D_loss : 2.9653
# G_loss: 1632.4846
# Time: 0.0:25.0:36
# loss_G_AB: 748.069
# loss_G_AB_GAN: 1.863
# loss_G_AB_identity: 0.131
# loss_G_AB_cycle: 0.144
# loss_G_AB_cam: 0.743
# loss_G_BA: 884.415
# loss_G_BA_GAN: 0.850
# loss_G_BA_identity: 0.256
# loss_G_BA_cycle: 0.261
# loss_G_BA_cam: 0.878
#
# loss_D_LA: 0.448
# loss_D_LA_GAN: 0.199
# loss_D_LA_cam: 0.248
# loss_D_GA: 0.796
# loss_D_GA_GAN: 0.403
# loss_D_GA_cam: 0.393
# loss_D_LB: 0.879
# loss_D_LB_GAN: 0.439
# loss_D_LB_cam: 0.440
# loss_D_GB: 0.843
# loss_D_GB_GAN: 0.404
# loss_D_GB_cam: 0.438
#
# [890/300000]
# D_loss : 2.7985
# G_loss: 1164.3618
# Time: 0.0:25.0:52
# loss_G_AB: 487.523
# loss_G_AB_GAN: 0.852
# loss_G_AB_identity: 0.223
# loss_G_AB_cycle: 0.214
# loss_G_AB_cam: 0.482
# loss_G_BA: 676.839
# loss_G_BA_GAN: 0.886
# loss_G_BA_identity: 0.157
# loss_G_BA_cycle: 0.172
# loss_G_BA_cam: 0.673
#
# loss_D_LA: 0.547
# loss_D_LA_GAN: 0.320
# loss_D_LA_cam: 0.227
# loss_D_GA: 0.839
# loss_D_GA_GAN: 0.411
# loss_D_GA_cam: 0.428
# loss_D_LB: 0.586
# loss_D_LB_GAN: 0.330
# loss_D_LB_cam: 0.255
# loss_D_GB: 0.827
# loss_D_GB_GAN: 0.405
# loss_D_GB_cam: 0.421
#
# [900/300000]
# D_loss : 2.3256
# G_loss: 941.9272
# Time: 0.0:26.0:16
# loss_G_AB: 448.340
# loss_G_AB_GAN: 0.865
# loss_G_AB_identity: 0.244
# loss_G_AB_cycle: 0.249
# loss_G_AB_cam: 0.443
# loss_G_BA: 493.587
# loss_G_BA_GAN: 1.161
# loss_G_BA_identity: 0.145
# loss_G_BA_cycle: 0.180
# loss_G_BA_cam: 0.489
#
# loss_D_LA: 0.523
# loss_D_LA_GAN: 0.315
# loss_D_LA_cam: 0.208
# loss_D_GA: 0.795
# loss_D_GA_GAN: 0.401
# loss_D_GA_cam: 0.394
# loss_D_LB: 0.213
# loss_D_LB_GAN: 0.134
# loss_D_LB_cam: 0.079
# loss_D_GB: 0.794
# loss_D_GB_GAN: 0.395
# loss_D_GB_cam: 0.399
#
# [910/300000]
# D_loss : 2.3245
# G_loss: 908.3773
# Time: 0.0:26.0:37
# loss_G_AB: 437.208
# loss_G_AB_GAN: 1.000
# loss_G_AB_identity: 0.179
# loss_G_AB_cycle: 0.184
# loss_G_AB_cam: 0.433
# loss_G_BA: 471.169
# loss_G_BA_GAN: 1.479
# loss_G_BA_identity: 0.188
# loss_G_BA_cycle: 0.189
# loss_G_BA_cam: 0.466
#
# loss_D_LA: 0.392
# loss_D_LA_GAN: 0.257
# loss_D_LA_cam: 0.135
# loss_D_GA: 0.808
# loss_D_GA_GAN: 0.405
# loss_D_GA_cam: 0.403
# loss_D_LB: 0.311
# loss_D_LB_GAN: 0.192
# loss_D_LB_cam: 0.119
# loss_D_GB: 0.814
# loss_D_GB_GAN: 0.405
# loss_D_GB_cam: 0.409
#
# [920/300000]
# D_loss : 2.3945
# G_loss: 2802.2197
# Time: 0.0:26.0:53
# loss_G_AB: 1333.836
# loss_G_AB_GAN: 1.283
# loss_G_AB_identity: 0.173
# loss_G_AB_cycle: 0.187
# loss_G_AB_cam: 1.329
# loss_G_BA: 1468.384
# loss_G_BA_GAN: 1.643
# loss_G_BA_identity: 0.199
# loss_G_BA_cycle: 0.209
# loss_G_BA_cam: 1.463
#
# loss_D_LA: 0.439
# ...
# loss_G_BA_identity: 0.128
# loss_G_BA_cycle: 0.168
# loss_G_BA_cam: 0.018
#
# loss_D_LA: 0.624
# loss_D_LA_GAN: 0.360
# loss_D_LA_cam: 0.264
# loss_D_GA: 1.059
# loss_D_GA_GAN: 0.520
# loss_D_GA_cam: 0.539
# loss_D_LB: 0.641
# loss_D_LB_GAN: 0.365
# loss_D_LB_cam: 0.276
# loss_D_GB: 0.944
# loss_D_GB_GAN: 0.415
# loss_D_GB_cam: 0.529
#
# [29760/300000]
# D_loss : 2.6111
# G_loss: 213.8505
# Time: 9.0:48.0:15
# loss_G_AB: 163.917
# loss_G_AB_GAN: 1.041
# loss_G_AB_identity: 0.094
# loss_G_AB_cycle: 0.162
# loss_G_AB_cam: 0.160
# loss_G_BA: 49.934
# loss_G_BA_GAN: 1.041
# loss_G_BA_identity: 0.075
# loss_G_BA_cycle: 0.119
# loss_G_BA_cam: 0.047
#
# loss_D_LA: 0.824
# loss_D_LA_GAN: 0.477
# loss_D_LA_cam: 0.346
# loss_D_GA: 0.668
# loss_D_GA_GAN: 0.319
# loss_D_GA_cam: 0.350
# loss_D_LB: 0.554
# loss_D_LB_GAN: 0.326
# loss_D_LB_cam: 0.228
# loss_D_GB: 0.565
# loss_D_GB_GAN: 0.228
# loss_D_GB_cam: 0.337
#
# [29770/300000]
# D_loss : 2.7303
# G_loss: 49.8988
# Time: 9.0:48.0:26
# loss_G_AB: 25.552
# loss_G_AB_GAN: 0.591
# loss_G_AB_identity: 0.153
# loss_G_AB_cycle: 0.138
# loss_G_AB_cam: 0.022
# loss_G_BA: 24.347
# loss_G_BA_GAN: 0.936
# loss_G_BA_identity: 0.126
# loss_G_BA_cycle: 0.129
# loss_G_BA_cam: 0.021
#
# loss_D_LA: 0.483
# loss_D_LA_GAN: 0.323
# loss_D_LA_cam: 0.159
# loss_D_GA: 0.904
# loss_D_GA_GAN: 0.433
# loss_D_GA_cam: 0.471
# loss_D_LB: 0.722
# loss_D_LB_GAN: 0.460
# loss_D_LB_cam: 0.262
# loss_D_GB: 0.622
# loss_D_GB_GAN: 0.341
# loss_D_GB_cam: 0.281
#
# [29780/300000]
# D_loss : 3.0217
# G_loss: 102.0387
# Time: 9.0:48.0:38
# loss_G_AB: 47.037
# loss_G_AB_GAN: 0.688
# loss_G_AB_identity: 0.180
# loss_G_AB_cycle: 0.242
# loss_G_AB_cam: 0.042
# loss_G_BA: 55.002
# loss_G_BA_GAN: 1.176
# loss_G_BA_identity: 0.199
# loss_G_BA_cycle: 0.204
# loss_G_BA_cam: 0.050
#
# loss_D_LA: 0.865
# loss_D_LA_GAN: 0.484
# loss_D_LA_cam: 0.381
# loss_D_GA: 0.522
# loss_D_GA_GAN: 0.289
# loss_D_GA_cam: 0.233
# loss_D_LB: 0.558
# loss_D_LB_GAN: 0.215
# loss_D_LB_cam: 0.343
# loss_D_GB: 1.077
# loss_D_GB_GAN: 0.502
# loss_D_GB_cam: 0.576
#
# [29790/300000]
# D_loss : 2.9671
# G_loss: 23.5945
# Time: 9.0:48.0:49
# loss_G_AB: 12.830
# loss_G_AB_GAN: 0.557
# loss_G_AB_identity: 0.157
# loss_G_AB_cycle: 0.160
# loss_G_AB_cam: 0.009
# loss_G_BA: 10.765
# loss_G_BA_GAN: 0.688
# loss_G_BA_identity: 0.149
# loss_G_BA_cycle: 0.191
# loss_G_BA_cam: 0.007
#
# loss_D_LA: 0.633
# loss_D_LA_GAN: 0.362
# loss_D_LA_cam: 0.270
# loss_D_GA: 1.091
# loss_D_GA_GAN: 0.652
# loss_D_GA_cam: 0.438
# loss_D_LB: 0.137
# loss_D_LB_GAN: 0.065
# loss_D_LB_cam: 0.071
# loss_D_GB: 1.107
# loss_D_GB_GAN: 0.480
# loss_D_GB_cam: 0.626
#
# [29800/300000]
# D_loss : 3.2741
# G_loss: 337.0569
# Time: 9.0:49.0:0
# loss_G_AB: 184.351
# loss_G_AB_GAN: 1.372
# loss_G_AB_identity: 0.077
# loss_G_AB_cycle: 0.092
# loss_G_AB_cam: 0.181
# loss_G_BA: 152.706
# loss_G_BA_GAN: 1.160
# loss_G_BA_identity: 0.133
# loss_G_BA_cycle: 0.171
# loss_G_BA_cam: 0.149
#
# loss_D_LA: 0.848
# loss_D_LA_GAN: 0.501
# loss_D_LA_cam: 0.347
# loss_D_GA: 0.824
# loss_D_GA_GAN: 0.426
# loss_D_GA_cam: 0.398
# loss_D_LB: 0.681
# loss_D_LB_GAN: 0.411
# loss_D_LB_cam: 0.269
# loss_D_GB: 0.921
# loss_D_GB_GAN: 0.380
# loss_D_GB_cam: 0.541
#
# [29810/300000]
# D_loss : 2.8190
# G_loss: 25.1740
# Time: 9.0:49.0:13
# loss_G_AB: 12.838
# loss_G_AB_GAN: 0.666
# loss_G_AB_identity: 0.140
# loss_G_AB_cycle: 0.113
# loss_G_AB_cam: 0.010
# loss_G_BA: 12.336
# loss_G_BA_GAN: 0.996
# loss_G_BA_identity: 0.175
# loss_G_BA_cycle: 0.156
# loss_G_BA_cam: 0.008
#
# loss_D_LA: 0.929
# loss_D_LA_GAN: 0.527
# loss_D_LA_cam: 0.402
# loss_D_GA: 0.831
# loss_D_GA_GAN: 0.458
# loss_D_GA_cam: 0.373
# loss_D_LB: 0.462
# loss_D_LB_GAN: 0.312
# loss_D_LB_cam: 0.151
# loss_D_GB: 0.597
# loss_D_GB_GAN: 0.318
# loss_D_GB_cam: 0.280
#
# [29820/300000]
# D_loss : 2.4523
# G_loss: 365.1101
# Time: 9.0:49.0:25
# loss_G_AB: 220.853
# loss_G_AB_GAN: 1.094
# loss_G_AB_identity: 0.125
# loss_G_AB_cycle: 0.228
# loss_G_AB_cam: 0.216
# loss_G_BA: 144.257
# loss_G_BA_GAN: 1.286
# loss_G_BA_identity: 0.255
# loss_G_BA_cycle: 0.270
# loss_G_BA_cam: 0.138
#
# loss_D_LA: 0.302
# loss_D_LA_GAN: 0.217
# loss_D_LA_cam: 0.085
# loss_D_GA: 0.615
# loss_D_GA_GAN: 0.333
# loss_D_GA_cam: 0.282
# loss_D_LB: 0.599
# loss_D_LB_GAN: 0.381
# loss_D_LB_cam: 0.218
# loss_D_GB: 0.937
# loss_D_GB_GAN: 0.473
# loss_D_GB_cam: 0.464
#
# [29830/300000]
# D_loss : 3.3036
# G_loss: 1746.2410
# Time: 9.0:49.0:36
# loss_G_AB: 1046.040
# loss_G_AB_GAN: 0.614
# loss_G_AB_identity: 0.190
# loss_G_AB_cycle: 0.173
# loss_G_AB_cam: 1.042
# loss_G_BA: 700.201
# loss_G_BA_GAN: 1.986
# loss_G_BA_identity: 0.123
# loss_G_BA_cycle: 0.144
# loss_G_BA_cam: 0.696
#
# loss_D_LA: 0.399
# loss_D_LA_GAN: 0.282
# loss_D_LA_cam: 0.116
# loss_D_GA: 0.698
# loss_D_GA_GAN: 0.371
# loss_D_GA_cam: 0.327
# loss_D_LB: 0.851
# loss_D_LB_GAN: 0.431
# loss_D_LB_cam: 0.420
# loss_D_GB: 1.356
# loss_D_GB_GAN: 0.714
# loss_D_GB_cam: 0.642
#
# [29840/300000]
# D_loss : 2.1494
# G_loss: 33.5562
# Time: 9.0:49.0:47
# loss_G_AB: 17.546
# loss_G_AB_GAN: 1.156
# loss_G_AB_identity: 0.174
# loss_G_AB_cycle: 0.201
# loss_G_AB_cam: 0.013
# loss_G_BA: 16.011
# loss_G_BA_GAN: 1.169
# loss_G_BA_identity: 0.098
# loss_G_BA_cycle: 0.145
# loss_G_BA_cam: 0.012
#
# loss_D_LA: 0.457
# loss_D_LA_GAN: 0.320
# loss_D_LA_cam: 0.137
# loss_D_GA: 0.700
# loss_D_GA_GAN: 0.389
# loss_D_GA_cam: 0.311
# loss_D_LB: 0.606
# loss_D_LB_GAN: 0.325
# loss_D_LB_cam: 0.281
# loss_D_GB: 0.386
# loss_D_GB_GAN: 0.246
# loss_D_GB_cam: 0.140
#
# [29850/300000]
# D_loss : 2.1735
# G_loss: 4568.9512
# Time: 9.0:49.0:58
# loss_G_AB: 2424.951
# loss_G_AB_GAN: 1.388
# loss_G_AB_identity: 0.170
# loss_G_AB_cycle: 0.178
# loss_G_AB_cam: 2.420
# loss_G_BA: 2144.000
# loss_G_BA_GAN: 1.262
# loss_G_BA_identity: 0.067
# loss_G_BA_cycle: 0.094
# loss_G_BA_cam: 2.141
#
# loss_D_LA: 0.365
# loss_D_LA_GAN: 0.204
# loss_D_LA_cam: 0.161
# loss_D_GA: 0.418
# loss_D_GA_GAN: 0.214
# loss_D_GA_cam: 0.204
# loss_D_LB: 1.009
# loss_D_LB_GAN: 0.374
# loss_D_LB_cam: 0.635
# loss_D_GB: 0.382
# loss_D_GB_GAN: 0.201
# loss_D_GB_cam: 0.181
#
# [29860/300000]
# D_loss : 2.7869
# G_loss: 42.5945
# Time: 9.0:50.0:10
# loss_G_AB: 23.923
# loss_G_AB_GAN: 1.184
# loss_G_AB_identity: 0.137
# loss_G_AB_cycle: 0.168
# loss_G_AB_cam: 0.020
# loss_G_BA: 18.672
# loss_G_BA_GAN: 1.732
# loss_G_BA_identity: 0.157
# loss_G_BA_cycle: 0.179
# loss_G_BA_cam: 0.014
#
# loss_D_LA: 0.781
# loss_D_LA_GAN: 0.387
# loss_D_LA_cam: 0.393
# loss_D_GA: 0.594
# loss_D_GA_GAN: 0.332
# loss_D_GA_cam: 0.262
# loss_D_LB: 0.669
# loss_D_LB_GAN: 0.407
# loss_D_LB_cam: 0.262
# loss_D_GB: 0.743
# loss_D_GB_GAN: 0.467
# loss_D_GB_cam: 0.277
#
# [29870/300000]
# D_loss : 2.9083
# G_loss: 271.3540
# Time: 9.0:50.0:21
# loss_G_AB: 63.760
# loss_G_AB_GAN: 0.548
# loss_G_AB_identity: 0.107
# loss_G_AB_cycle: 0.134
# loss_G_AB_cam: 0.061
# loss_G_BA: 207.594
# loss_G_BA_GAN: 1.930
# loss_G_BA_identity: 0.186
# loss_G_BA_cycle: 0.174
# loss_G_BA_cam: 0.202
#
# loss_D_LA: 0.643
# loss_D_LA_GAN: 0.411
# loss_D_LA_cam: 0.232
# loss_D_GA: 0.335
# loss_D_GA_GAN: 0.253
# loss_D_GA_cam: 0.083
# loss_D_LB: 0.775
# loss_D_LB_GAN: 0.471
# loss_D_LB_cam: 0.304
# loss_D_GB: 1.155
# loss_D_GB_GAN: 0.642
# loss_D_GB_cam: 0.513
#
# [29880/300000]
# D_loss : 1.8948
# G_loss: 37.5787
# Time: 9.0:50.0:32
# loss_G_AB: 17.838
# loss_G_AB_GAN: 0.698
# loss_G_AB_identity: 0.065
# loss_G_AB_cycle: 0.086
# loss_G_AB_cam: 0.016
# loss_G_BA: 19.741
# loss_G_BA_GAN: 0.972
# loss_G_BA_identity: 0.181
# loss_G_BA_cycle: 0.235
# loss_G_BA_cam: 0.015
#
# loss_D_LA: 0.415
# loss_D_LA_GAN: 0.270
# loss_D_LA_cam: 0.144
# loss_D_GA: 0.374
# loss_D_GA_GAN: 0.254
# loss_D_GA_cam: 0.119
# loss_D_LB: 0.536
# loss_D_LB_GAN: 0.290
# loss_D_LB_cam: 0.247
# loss_D_GB: 0.570
# loss_D_GB_GAN: 0.271
# loss_D_GB_cam: 0.299
#
# [29890/300000]
# D_loss : 2.2800
# G_loss: 151.4866
# Time: 9.0:50.0:44
# loss_G_AB: 39.178
# loss_G_AB_GAN: 0.871
# loss_G_AB_identity: 0.159
# loss_G_AB_cycle: 0.190
# loss_G_AB_cam: 0.035
# loss_G_BA: 112.309
# loss_G_BA_GAN: 1.413
# loss_G_BA_identity: 0.190
# loss_G_BA_cycle: 0.201
# loss_G_BA_cam: 0.107
#
# loss_D_LA: 0.368
# loss_D_LA_GAN: 0.207
# loss_D_LA_cam: 0.161
# loss_D_GA: 0.731
# loss_D_GA_GAN: 0.366
# loss_D_GA_cam: 0.365
# loss_D_LB: 0.525
# loss_D_LB_GAN: 0.324
# loss_D_LB_cam: 0.201
# loss_D_GB: 0.656
# loss_D_GB_GAN: 0.334
# loss_D_GB_cam: 0.321
#
# [29900/300000]
# D_loss : 3.2542
# G_loss: 61.4307
# Time: 9.0:50.0:55
# loss_G_AB: 35.329
# loss_G_AB_GAN: 0.944
# loss_G_AB_identity: 0.084
# loss_G_AB_cycle: 0.092
# loss_G_AB_cam: 0.033
# loss_G_BA: 26.102
# loss_G_BA_GAN: 1.085
# loss_G_BA_identity: 0.220
# loss_G_BA_cycle: 0.242
# loss_G_BA_cam: 0.020
#
# loss_D_LA: 0.889
# loss_D_LA_GAN: 0.494
# loss_D_LA_cam: 0.395
# loss_D_GA: 0.893
# loss_D_GA_GAN: 0.468
# loss_D_GA_cam: 0.424
# loss_D_LB: 0.803
# loss_D_LB_GAN: 0.424
# loss_D_LB_cam: 0.379
# loss_D_GB: 0.669
# loss_D_GB_GAN: 0.416
# loss_D_GB_cam: 0.253
#
# [29910/300000]
# D_loss : 2.6509
# G_loss: 49.3606
# Time: 9.0:51.0:8
# loss_G_AB: 26.491
# loss_G_AB_GAN: 0.787
# loss_G_AB_identity: 0.199
# loss_G_AB_cycle: 0.237
# loss_G_AB_cam: 0.021
# loss_G_BA: 22.870
# loss_G_BA_GAN: 1.577
# loss_G_BA_identity: 0.095
# loss_G_BA_cycle: 0.135
# loss_G_BA_cam: 0.019
#
# loss_D_LA: 0.343
# loss_D_LA_GAN: 0.232
# loss_D_LA_cam: 0.111
# loss_D_GA: 0.834
# loss_D_GA_GAN: 0.424
# loss_D_GA_cam: 0.410
# loss_D_LB: 0.742
# loss_D_LB_GAN: 0.475
# loss_D_LB_cam: 0.267
# loss_D_GB: 0.731
# loss_D_GB_GAN: 0.351
# loss_D_GB_cam: 0.380
#
# [29920/300000]
# D_loss : 1.3346
# G_loss: 27.7466
# Time: 9.0:51.0:19
# loss_G_AB: 12.481
# loss_G_AB_GAN: 1.315
# loss_G_AB_identity: 0.119
# loss_G_AB_cycle: 0.212
# loss_G_AB_cam: 0.008
# loss_G_BA: 15.266
# loss_G_BA_GAN: 1.280
# loss_G_BA_identity: 0.126
# loss_G_BA_cycle: 0.161
# loss_G_BA_cam: 0.011
#
# loss_D_LA: 0.303
# loss_D_LA_GAN: 0.211
# loss_D_LA_cam: 0.092
# loss_D_GA: 0.350
# loss_D_GA_GAN: 0.219
# loss_D_GA_cam: 0.131
# loss_D_LB: 0.353
# loss_D_LB_GAN: 0.248
# loss_D_LB_cam: 0.105
# loss_D_GB: 0.329
# loss_D_GB_GAN: 0.209
# loss_D_GB_cam: 0.120
#
# [29930/300000]
# D_loss : 3.6193
# G_loss: 172.8150
# Time: 9.0:51.0:31
# loss_G_AB: 103.301
# loss_G_AB_GAN: 0.509
# loss_G_AB_identity: 0.141
# loss_G_AB_cycle: 0.160
# loss_G_AB_cam: 0.100
# loss_G_BA: 69.514
# loss_G_BA_GAN: 0.590
# loss_G_BA_identity: 0.108
# loss_G_BA_cycle: 0.168
# loss_G_BA_cam: 0.066
#
# loss_D_LA: 0.822
# loss_D_LA_GAN: 0.499
# loss_D_LA_cam: 0.323
# loss_D_GA: 0.904
# loss_D_GA_GAN: 0.414
# loss_D_GA_cam: 0.490
# loss_D_LB: 1.005
# loss_D_LB_GAN: 0.530
# loss_D_LB_cam: 0.475
# loss_D_GB: 0.888
# loss_D_GB_GAN: 0.455
# loss_D_GB_cam: 0.433
#
# [29940/300000]
# D_loss : 2.3568
# G_loss: 91.9583
# Time: 9.0:51.0:42
# loss_G_AB: 50.020
# loss_G_AB_GAN: 0.328
# loss_G_AB_identity: 0.179
# loss_G_AB_cycle: 0.255
# loss_G_AB_cam: 0.045
# loss_G_BA: 41.938
# loss_G_BA_GAN: 1.062
# loss_G_BA_identity: 0.178
# loss_G_BA_cycle: 0.176
# loss_G_BA_cam: 0.037
#
# loss_D_LA: 0.692
# loss_D_LA_GAN: 0.411
# loss_D_LA_cam: 0.281
# loss_D_GA: 0.659
# loss_D_GA_GAN: 0.348
# loss_D_GA_cam: 0.311
# loss_D_LB: 0.450
# loss_D_LB_GAN: 0.283
# loss_D_LB_cam: 0.167
# loss_D_GB: 0.556
# loss_D_GB_GAN: 0.357
# loss_D_GB_cam: 0.199
#
# [29950/300000]
# D_loss : 3.9796
# G_loss: 53.8182
# Time: 9.0:51.0:53
# loss_G_AB: 25.921
# loss_G_AB_GAN: 0.770
# loss_G_AB_identity: 0.229
# loss_G_AB_cycle: 0.249
# loss_G_AB_cam: 0.020
# loss_G_BA: 27.897
# loss_G_BA_GAN: 1.311
# loss_G_BA_identity: 0.135
# loss_G_BA_cycle: 0.131
# loss_G_BA_cam: 0.024
#
# loss_D_LA: 0.796
# loss_D_LA_GAN: 0.429
# loss_D_LA_cam: 0.367
# loss_D_GA: 0.695
# loss_D_GA_GAN: 0.305
# loss_D_GA_cam: 0.390
# loss_D_LB: 1.406
# loss_D_LB_GAN: 0.788
# loss_D_LB_cam: 0.618
# loss_D_GB: 1.082
# loss_D_GB_GAN: 0.471
# loss_D_GB_cam: 0.611
#
# [29960/300000]
# D_loss : 2.7375
# G_loss: 333.0329
# Time: 9.0:52.0:5
# loss_G_AB: 91.908
# loss_G_AB_GAN: 1.392
# loss_G_AB_identity: 0.340
# loss_G_AB_cycle: 0.344
# loss_G_AB_cam: 0.084
# loss_G_BA: 241.125
# loss_G_BA_GAN: 1.039
# loss_G_BA_identity: 0.221
# loss_G_BA_cycle: 0.216
# loss_G_BA_cam: 0.236
#
# loss_D_LA: 0.689
# loss_D_LA_GAN: 0.361
# loss_D_LA_cam: 0.327
# loss_D_GA: 1.090
# loss_D_GA_GAN: 0.611
# loss_D_GA_cam: 0.479
# loss_D_LB: 0.385
# loss_D_LB_GAN: 0.210
# loss_D_LB_cam: 0.175
# loss_D_GB: 0.573
# loss_D_GB_GAN: 0.381
# loss_D_GB_cam: 0.192
#
# [29970/300000]
# D_loss : 2.6100
# G_loss: 19.4426
# Time: 9.0:52.0:16
# loss_G_AB: 10.868
# loss_G_AB_GAN: 0.791
# loss_G_AB_identity: 0.143
# loss_G_AB_cycle: 0.198
# loss_G_AB_cam: 0.007
# loss_G_BA: 8.574
# loss_G_BA_GAN: 1.271
# loss_G_BA_identity: 0.125
# loss_G_BA_cycle: 0.187
# loss_G_BA_cam: 0.004
#
# loss_D_LA: 0.508
# loss_D_LA_GAN: 0.289
# loss_D_LA_cam: 0.219
# loss_D_GA: 0.450
# loss_D_GA_GAN: 0.216
# loss_D_GA_cam: 0.234
# loss_D_LB: 0.656
# loss_D_LB_GAN: 0.370
# loss_D_LB_cam: 0.286
# loss_D_GB: 0.996
# loss_D_GB_GAN: 0.526
# loss_D_GB_cam: 0.469
#
# [29980/300000]
# D_loss : 2.0203
# G_loss: 47.4497
# Time: 9.0:52.0:27
# loss_G_AB: 23.700
# loss_G_AB_GAN: 0.893
# loss_G_AB_identity: 0.149
# loss_G_AB_cycle: 0.193
# loss_G_AB_cam: 0.019
# loss_G_BA: 23.750
# loss_G_BA_GAN: 1.103
# loss_G_BA_identity: 0.134
# loss_G_BA_cycle: 0.129
# loss_G_BA_cam: 0.020
#
# loss_D_LA: 0.367
# loss_D_LA_GAN: 0.254
# loss_D_LA_cam: 0.113
# loss_D_GA: 0.438
# loss_D_GA_GAN: 0.235
# loss_D_GA_cam: 0.203
# loss_D_LB: 0.582
# loss_D_LB_GAN: 0.327
# loss_D_LB_cam: 0.254
# loss_D_GB: 0.633
# loss_D_GB_GAN: 0.343
# loss_D_GB_cam: 0.290
#
# [29990/300000]
# D_loss : 2.4336
# G_loss: 60.2324
# Time: 9.0:52.0:39
# loss_G_AB: 29.825
# loss_G_AB_GAN: 1.006
# loss_G_AB_identity: 0.149
# loss_G_AB_cycle: 0.217
# loss_G_AB_cam: 0.025
# loss_G_BA: 30.407
# loss_G_BA_GAN: 0.947
# loss_G_BA_identity: 0.160
# loss_G_BA_cycle: 0.174
# loss_G_BA_cam: 0.026
#
# loss_D_LA: 0.628
# loss_D_LA_GAN: 0.352
# loss_D_LA_cam: 0.276
# loss_D_GA: 0.536
# loss_D_GA_GAN: 0.259
# loss_D_GA_cam: 0.277
# loss_D_LB: 0.612
# loss_D_LB_GAN: 0.286
# loss_D_LB_cam: 0.325
# loss_D_GB: 0.658
# loss_D_GB_GAN: 0.357
# loss_D_GB_cam: 0.301
#
# [30000/300000]
# D_loss : 3.3022
# G_loss: 37.2459
# Time: 9.0:52.0:50
# loss_G_AB: 19.483
# loss_G_AB_GAN: 0.649
# loss_G_AB_identity: 0.125
# loss_G_AB_cycle: 0.149
# loss_G_AB_cam: 0.016
# loss_G_BA: 17.763
# loss_G_BA_GAN: 0.794
# loss_G_BA_identity: 0.119
# loss_G_BA_cycle: 0.118
# loss_G_BA_cam: 0.015
#
# loss_D_LA: 0.753
# loss_D_LA_GAN: 0.336
# loss_D_LA_cam: 0.416
# loss_D_GA: 0.795
# loss_D_GA_GAN: 0.426
# loss_D_GA_cam: 0.369
# loss_D_LB: 0.609
# loss_D_LB_GAN: 0.380
# loss_D_LB_cam: 0.229
# loss_D_GB: 1.145
# loss_D_GB_GAN: 0.590
# loss_D_GB_cam: 0.555
#
# Save the checkpoint :  30000
# [30010/300000]
# D_loss : 2.9849
# G_loss: 125.2070
# Time: 9.0:53.0:5
# loss_G_AB: 68.409
# loss_G_AB_GAN: 0.428
# loss_G_AB_identity: 0.146
# loss_G_AB_cycle: 0.213
# loss_G_AB_cam: 0.064
# loss_G_BA: 56.798
# loss_G_BA_GAN: 1.027
# loss_G_BA_identity: 0.113
# loss_G_BA_cycle: 0.134
# loss_G_BA_cam: 0.053
#
# loss_D_LA: 0.656
# loss_D_LA_GAN: 0.396
# loss_D_LA_cam: 0.259
# loss_D_GA: 1.007
# loss_D_GA_GAN: 0.507
# loss_D_GA_cam: 0.500
# loss_D_LB: 0.517
# loss_D_LB_GAN: 0.268
# loss_D_LB_cam: 0.250
# loss_D_GB: 0.805
# loss_D_GB_GAN: 0.402
# loss_D_GB_cam: 0.403
#
# [30020/300000]
# D_loss : 3.7600
# G_loss: 100.7392
# Time: 9.0:53.0:16
# loss_G_AB: 59.249
# loss_G_AB_GAN: 1.334
# loss_G_AB_identity: 0.269
# loss_G_AB_cycle: 0.224
# loss_G_AB_cam: 0.053
# loss_G_BA: 41.490
# loss_G_BA_GAN: 0.677
# loss_G_BA_identity: 0.155
# loss_G_BA_cycle: 0.188
# loss_G_BA_cam: 0.037
#
# loss_D_LA: 0.905
# loss_D_LA_GAN: 0.487
# loss_D_LA_cam: 0.418
# loss_D_GA: 0.900
# loss_D_GA_GAN: 0.447
# loss_D_GA_cam: 0.453
# loss_D_LB: 1.069
# loss_D_LB_GAN: 0.622
# loss_D_LB_cam: 0.447
# loss_D_GB: 0.885
# loss_D_GB_GAN: 0.463
# loss_D_GB_cam: 0.422
#
# [30030/300000]
# D_loss : 3.8300
# G_loss: 63.7507
# Time: 9.0:53.0:28
# loss_G_AB: 19.989
# loss_G_AB_GAN: 0.888
# loss_G_AB_identity: 0.163
# loss_G_AB_cycle: 0.206
# loss_G_AB_cam: 0.015
# loss_G_BA: 43.761
# loss_G_BA_GAN: 1.087
# loss_G_BA_identity: 0.179
# loss_G_BA_cycle: 0.232
# loss_G_BA_cam: 0.039
#
# loss_D_LA: 0.672
# loss_D_LA_GAN: 0.414
# loss_D_LA_cam: 0.258
# loss_D_GA: 0.960
# loss_D_GA_GAN: 0.446
# loss_D_GA_cam: 0.514
# loss_D_LB: 0.731
# loss_D_LB_GAN: 0.392
# loss_D_LB_cam: 0.339
# loss_D_GB: 1.467
# loss_D_GB_GAN: 0.616
# loss_D_GB_cam: 0.851
#
# [30040/300000]
# D_loss : 3.2322
# G_loss: 206.5406
# Time: 9.0:53.0:39
# loss_G_AB: 88.468
# loss_G_AB_GAN: 0.405
# loss_G_AB_identity: 0.121
# loss_G_AB_cycle: 0.183
# loss_G_AB_cam: 0.085
# loss_G_BA: 118.072
# loss_G_BA_GAN: 1.134
# loss_G_BA_identity: 0.139
# loss_G_BA_cycle: 0.132
# loss_G_BA_cam: 0.114
#
# loss_D_LA: 0.755
# loss_D_LA_GAN: 0.467
# loss_D_LA_cam: 0.288
# loss_D_GA: 0.816
# loss_D_GA_GAN: 0.406
# loss_D_GA_cam: 0.410
# loss_D_LB: 1.070
# loss_D_LB_GAN: 0.584
# loss_D_LB_cam: 0.486
# loss_D_GB: 0.591
# loss_D_GB_GAN: 0.328
# loss_D_GB_cam: 0.263
#
# [30050/300000]
# D_loss : 3.6780
# G_loss: 350.4856
# Time: 9.0:53.0:50
# loss_G_AB: 43.042
# loss_G_AB_GAN: 0.773
# loss_G_AB_identity: 0.290
# loss_G_AB_cycle: 0.319
# loss_G_AB_cam: 0.036
# loss_G_BA: 307.444
# loss_G_BA_GAN: 1.037
# loss_G_BA_identity: 0.108
# loss_G_BA_cycle: 0.137
# loss_G_BA_cam: 0.304
#
# loss_D_LA: 1.076
# loss_D_LA_GAN: 0.425
# loss_D_LA_cam: 0.651
# loss_D_GA: 0.851
# loss_D_GA_GAN: 0.425
# loss_D_GA_cam: 0.426
# loss_D_LB: 0.804
# loss_D_LB_GAN: 0.467
# loss_D_LB_cam: 0.337
# loss_D_GB: 0.948
# loss_D_GB_GAN: 0.593
# loss_D_GB_cam: 0.355

# %%
"""
function preventFromOff(){
  console.log("Click button");
  document.querySelector("colab-toolbar-button#connect").click() 
}
var timeout = 8 * 60 * 60 * 1000;
var delay = 5 * 60 * 1000;
var refreshId = setInterval(preventFromOff, delay);
setTimeout(() => {clearInterval(refreshId); console.log("Stopped script");}, timeout);
"""

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir=ugatit/output/summary/summary_v0.2.1/
