# %% [markdown]
# # Reproducing original implementation with changes
# ## From 0.2.0
# 1. Explicit weights initialization
# 2. Queue of generated images
# 3. Activation to res net block
# 4. Add parameters to ADAILN layer
# 5. Label smoothing
#
# ## 0.3.0
# 1. Slow down the discriminator training with 0.5 coefficient
#
# ## 0.3.1
# 1. Using transpose convolutions insead upsampling

# %%
import torch
from torch.nn import init
from torch import nn
import torch.nn.functional as F
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch.autograd import Variable
from torch import Tensor
from torch.utils.tensorboard import SummaryWriter
from torch.nn.parameter import Parameter
from torch.utils.tensorboard import SummaryWriter 

from skimage.filters import threshold_otsu
from PIL import Image
import cv2
import functools
import itertools
import numpy as np
import random

import os
import sys
import glob
from tqdm import tqdm_notebook
import re

import matplotlib.pyplot as plt
import pickle
import time
from scipy import misc

# %% [markdown]
# ### Networks

# %%
class ResnetGenerator(nn.Module):
    def __init__(self, input_nc, output_nc, ngf=64, n_blocks=6, img_size=256, light=False):
        assert(n_blocks >= 0)
        super(ResnetGenerator, self).__init__()
        self.input_nc = input_nc
        self.output_nc = output_nc
        self.ngf = ngf
        self.n_blocks = n_blocks
        self.img_size = img_size
        self.light = light

        DownBlock = []
        DownBlock += [nn.ReflectionPad2d(3),
                      nn.Conv2d(input_nc, ngf, kernel_size=7, stride=1, padding=0, bias=False),
                      nn.InstanceNorm2d(ngf),
                      nn.ReLU(True)]

        # Down-Sampling
        n_downsampling = 2
        for i in range(n_downsampling):
            mult = 2**i
            DownBlock += [nn.ReflectionPad2d(1),
                          nn.Conv2d(ngf * mult, ngf * mult * 2, kernel_size=3, stride=2, padding=0, bias=False),
                          nn.InstanceNorm2d(ngf * mult * 2),
                          nn.ReLU(True)]

        # Down-Sampling Bottleneck
        mult = 2**n_downsampling
        for i in range(n_blocks):
            DownBlock += [ResnetBlock(ngf * mult, use_bias=False)]

        # Class Activation Map
        self.gap_fc = nn.Linear(ngf * mult, 1, bias=False)
        self.gmp_fc = nn.Linear(ngf * mult, 1, bias=False)
        self.conv1x1 = nn.Conv2d(ngf * mult * 2, ngf * mult, kernel_size=1, stride=1, bias=True)
        self.relu = nn.ReLU(True)

        # Gamma, Beta block
        if self.light:
            # added more parameters from ngf * mult to:
            FC = [nn.Linear(ngf * mult, ngf * ngf, bias=False),
                  nn.ReLU(True),
                  nn.Linear(ngf * ngf, ngf * mult, bias=False),
                  nn.ReLU(True)]
        else:
            FC = [nn.Linear(img_size // mult * img_size // mult * ngf * mult, ngf * mult, bias=False),
                  nn.ReLU(True),
                  nn.Linear(ngf * mult, ngf * mult, bias=False),
                  nn.ReLU(True)]
        self.gamma = nn.Linear(ngf * mult, ngf * mult, bias=False)
        self.beta = nn.Linear(ngf * mult, ngf * mult, bias=False)

        # Up-Sampling Bottleneck
        for i in range(n_blocks):
            setattr(self, 'UpBlock1_' + str(i+1), ResnetAdaILNBlock(ngf * mult, use_bias=False))

        # Up-Sampling
        UpBlock2 = []
        for i in range(n_downsampling):
            mult = 2**(n_downsampling - i)
            UpBlock2 += [nn.Upsample(scale_factor=2, mode='nearest'),
                         nn.ReflectionPad2d(1),
                         nn.Conv2d(ngf * mult, int(ngf * mult / 2), kernel_size=3, stride=1, padding=0, bias=False),
                         ILN(int(ngf * mult / 2)),
                         nn.ReLU(True)]

        UpBlock2 += [nn.ReflectionPad2d(3),
                     nn.Conv2d(ngf, output_nc, kernel_size=7, stride=1, padding=0, bias=False),
                     nn.Tanh()]

        self.DownBlock = nn.Sequential(*DownBlock)
        self.FC = nn.Sequential(*FC)
        self.UpBlock2 = nn.Sequential(*UpBlock2)

    def forward(self, input):
        x = self.DownBlock(input)

        gap = torch.nn.functional.adaptive_avg_pool2d(x, 1)
        gap_logit = self.gap_fc(gap.view(x.shape[0], -1))
        gap_weight = list(self.gap_fc.parameters())[0]
        gap = x * gap_weight.unsqueeze(2).unsqueeze(3)

        gmp = torch.nn.functional.adaptive_max_pool2d(x, 1)
        gmp_logit = self.gmp_fc(gmp.view(x.shape[0], -1))
        gmp_weight = list(self.gmp_fc.parameters())[0]
        gmp = x * gmp_weight.unsqueeze(2).unsqueeze(3)

        cam_logit = torch.cat([gap_logit, gmp_logit], 1)
        x = torch.cat([gap, gmp], 1)
        x = self.relu(self.conv1x1(x))

        heatmap = torch.sum(x, dim=1, keepdim=True)

        if self.light:
            x_ = torch.nn.functional.adaptive_avg_pool2d(x, 1)
            x_ = self.FC(x_.view(x_.shape[0], -1))
        else:
            x_ = self.FC(x.view(x.shape[0], -1))
        gamma, beta = self.gamma(x_), self.beta(x_)


        for i in range(self.n_blocks):
            x = getattr(self, 'UpBlock1_' + str(i+1))(x, gamma, beta)
        out = self.UpBlock2(x)

        return out, cam_logit, heatmap


class ResnetBlock(nn.Module):
    def __init__(self, dim, use_bias):
        super(ResnetBlock, self).__init__()
        conv_block = []
        conv_block += [nn.ReflectionPad2d(1),
                       nn.Conv2d(dim, dim, kernel_size=3, stride=1, padding=0, bias=use_bias),
                       nn.InstanceNorm2d(dim),
                       nn.ReLU(True)]

        conv_block += [nn.ReflectionPad2d(1),
                       nn.Conv2d(dim, dim, kernel_size=3, stride=1, padding=0, bias=use_bias),
                       nn.InstanceNorm2d(dim),
                       nn.ReLU(True)]

        self.conv_block = nn.Sequential(*conv_block)

    def forward(self, x):
        out = x + self.conv_block(x)
        return out


class ResnetAdaILNBlock(nn.Module):
    def __init__(self, dim, use_bias):
        super(ResnetAdaILNBlock, self).__init__()
        self.pad1 = nn.ReflectionPad2d(1)
        self.conv1 = nn.Conv2d(dim, dim, kernel_size=3, stride=1, padding=0, bias=use_bias)
        self.norm1 = adaILN(dim)
        self.relu1 = nn.ReLU(True)

        self.pad2 = nn.ReflectionPad2d(1)
        self.conv2 = nn.Conv2d(dim, dim, kernel_size=3, stride=1, padding=0, bias=use_bias)
        self.norm2 = adaILN(dim)
        self.relu2 = nn.ReLU(True)

    def forward(self, x, gamma, beta):
        out = self.pad1(x)
        out = self.conv1(out)
        out = self.norm1(out, gamma, beta)
        out = self.relu1(out)
        out = self.pad2(out)
        out = self.conv2(out)
        out = self.norm2(out, gamma, beta)
        out = self.relu2(out)

        return out + x


class adaILN(nn.Module):
    def __init__(self, num_features, eps=1e-5):
        super(adaILN, self).__init__()
        self.eps = eps
        self.rho = Parameter(torch.Tensor(1, num_features, 1, 1))
        self.rho.data.fill_(0.9)

    def forward(self, input, gamma, beta):
        in_mean, in_var = torch.mean(input, dim=[2, 3], keepdim=True), torch.var(input, dim=[2, 3], keepdim=True)
        out_in = (input - in_mean) / torch.sqrt(in_var + self.eps)
        ln_mean, ln_var = torch.mean(input, dim=[1, 2, 3], keepdim=True), torch.var(input, dim=[1, 2, 3], keepdim=True)
        out_ln = (input - ln_mean) / torch.sqrt(ln_var + self.eps)
        out = self.rho.expand(input.shape[0], -1, -1, -1) * out_in + (1-self.rho.expand(input.shape[0], -1, -1, -1)) * out_ln
        out = out * gamma.unsqueeze(2).unsqueeze(3) + beta.unsqueeze(2).unsqueeze(3)

        return out


class ILN(nn.Module):
    def __init__(self, num_features, eps=1e-5):
        super(ILN, self).__init__()
        self.eps = eps
        self.rho = Parameter(torch.Tensor(1, num_features, 1, 1))
        self.gamma = Parameter(torch.Tensor(1, num_features, 1, 1))
        self.beta = Parameter(torch.Tensor(1, num_features, 1, 1))
        self.rho.data.fill_(0.0)
        self.gamma.data.fill_(1.0)
        self.beta.data.fill_(0.0)

    def forward(self, input):
        in_mean, in_var = torch.mean(input, dim=[2, 3], keepdim=True), torch.var(input, dim=[2, 3], keepdim=True)
        out_in = (input - in_mean) / torch.sqrt(in_var + self.eps)
        ln_mean, ln_var = torch.mean(input, dim=[1, 2, 3], keepdim=True), torch.var(input, dim=[1, 2, 3], keepdim=True)
        out_ln = (input - ln_mean) / torch.sqrt(ln_var + self.eps)
        out = self.rho.expand(input.shape[0], -1, -1, -1) * out_in + (1-self.rho.expand(input.shape[0], -1, -1, -1)) * out_ln
        out = out * self.gamma.expand(input.shape[0], -1, -1, -1) + self.beta.expand(input.shape[0], -1, -1, -1)

        return out


class Discriminator(nn.Module):
    def __init__(self, input_nc, ndf=64, n_layers=5):
        super(Discriminator, self).__init__()
        model = [nn.ReflectionPad2d(1),
                 nn.utils.spectral_norm(
                 nn.Conv2d(input_nc, ndf, kernel_size=4, stride=2, padding=0, bias=True)),
                 nn.LeakyReLU(0.2, True)]

        for i in range(1, n_layers - 2):
            mult = 2 ** (i - 1)
            model += [nn.ReflectionPad2d(1),
                      nn.utils.spectral_norm(
                      nn.Conv2d(ndf * mult, ndf * mult * 2, kernel_size=4, stride=2, padding=0, bias=True)),
                      nn.LeakyReLU(0.2, True)]

        mult = 2 ** (n_layers - 2 - 1)
        model += [nn.ReflectionPad2d(1),
                  nn.utils.spectral_norm(
                  nn.Conv2d(ndf * mult, ndf * mult * 2, kernel_size=4, stride=1, padding=0, bias=True)),
                  nn.LeakyReLU(0.2, True)]

        # Class Activation Map
        mult = 2 ** (n_layers - 2)
        self.gap_fc = nn.utils.spectral_norm(nn.Linear(ndf * mult, 1, bias=False))
        self.gmp_fc = nn.utils.spectral_norm(nn.Linear(ndf * mult, 1, bias=False))
        self.conv1x1 = nn.Conv2d(ndf * mult * 2, ndf * mult, kernel_size=1, stride=1, bias=True)
        self.leaky_relu = nn.LeakyReLU(0.2, True)

        self.pad = nn.ReflectionPad2d(1)
        self.conv = nn.utils.spectral_norm(
            nn.Conv2d(ndf * mult, 1, kernel_size=4, stride=1, padding=0, bias=False))

        self.model = nn.Sequential(*model)

    def forward(self, input):
        x = self.model(input)

        gap = torch.nn.functional.adaptive_avg_pool2d(x, 1)
        gap_logit = self.gap_fc(gap.view(x.shape[0], -1))
        gap_weight = list(self.gap_fc.parameters())[0]
        gap = x * gap_weight.unsqueeze(2).unsqueeze(3)

        gmp = torch.nn.functional.adaptive_max_pool2d(x, 1)
        gmp_logit = self.gmp_fc(gmp.view(x.shape[0], -1))
        gmp_weight = list(self.gmp_fc.parameters())[0]
        gmp = x * gmp_weight.unsqueeze(2).unsqueeze(3)

        cam_logit = torch.cat([gap_logit, gmp_logit], 1)
        x = torch.cat([gap, gmp], 1)
        x = self.leaky_relu(self.conv1x1(x))

        heatmap = torch.sum(x, dim=1, keepdim=True)

        x = self.pad(x)
        out = self.conv(x)

        return out, cam_logit, heatmap


class RhoClipper(object):

    def __init__(self, min, max):
        self.clip_min = min
        self.clip_max = max
        assert min < max

    def __call__(self, module):

        if hasattr(module, 'rho'):
            w = module.rho.data
            w = w.clamp(self.clip_min, self.clip_max)
            module.rho.data = w

# %%
# summary of the models
def num_params(model):
  model_parameters = filter(lambda p: p.requires_grad, model.parameters())
  params = sum([np.prod(p.size()) for p in model_parameters])
  return params

dL = Discriminator(3, n_layers=5)
dG = Discriminator(3, n_layers=7)
g_light = ResnetGenerator(3,3, light=True)
g_hard = ResnetGenerator(3,3, light=False)

dL_num = round(num_params(dL) * 2 / 1e6, 3)
dG_num = round(num_params(dG) * 2 / 1e6, 3)
g_light_num = round(num_params(g_light) * 2 / 1e6, 3)
g_hard_num = round(num_params(g_hard) * 2 / 1e6, 3)
overall_light = round(dL_num + dG_num + g_light_num, 3)
overall_hard = round(dL_num + dG_num + g_hard_num, 3)

print('---- Summary models ----')
print("Number of parameters (in millions):")
print("{:10}{:10}{:10}{:10}{:20}{:10}".format("D_L", 'D_G', "G_LIGHT", "G_HARD","Overall_LIGHT", "Overall_HARD"))
print("{:10}{:10}{:10}{:10}{:20}{:10}".format(str(dL_num), str(dG_num), str(g_light_num), 
                                    str(g_hard_num), str(overall_light), str(overall_hard)))
# Out:
# ---- Summary models ----
# Number of parameters (in millions):
# D_L       D_G       G_LIGHT   G_HARD    Overall_LIGHT       Overall_HARD
# 6.581     106.26    34.551    567.359   147.392             680.2

# %% [markdown]
# ### Utils

# %%
def load_test_data(image_path, size=256):
    img = misc.imread(image_path, mode='RGB')
    img = misc.imresize(img, [size, size])
    img = np.expand_dims(img, axis=0)
    img = preprocessing(img)

    return img

def preprocessing(x):
    x = x/127.5 - 1 # -1 ~ 1
    return x

def save_images(images, size, image_path):
    return imsave(inverse_transform(images), size, image_path)

def inverse_transform(images):
    return (images+1.) / 2

def imsave(images, size, path):
    return misc.imsave(path, merge(images, size))

def merge(images, size):
    h, w = images.shape[1], images.shape[2]
    img = np.zeros((h * size[0], w * size[1], 3))
    for idx, image in enumerate(images):
        i = idx % size[1]
        j = idx // size[1]
        img[h*j:h*(j+1), w*i:w*(i+1), :] = image

    return img

def check_folder(log_dir):
    if not os.path.exists(log_dir):
        os.makedirs(log_dir)
    return log_dir

def str2bool(x):
    return x.lower() in ('true')

def cam(x, size = 256):
    x = x - np.min(x)
    cam_img = x / np.max(x)
    cam_img = np.uint8(255 * cam_img)
    cam_img = cv2.resize(cam_img, (size, size))
    cam_img = cv2.applyColorMap(cam_img, cv2.COLORMAP_JET)
    return cam_img / 255.0

def imagenet_norm(x):
    mean = [0.485, 0.456, 0.406]
    std = [0.299, 0.224, 0.225]
    mean = torch.FloatTensor(mean).unsqueeze(0).unsqueeze(2).unsqueeze(3).to(x.device)
    std = torch.FloatTensor(std).unsqueeze(0).unsqueeze(2).unsqueeze(3).to(x.device)
    return (x - mean) / std

def denorm(x):
    return x * 0.5 + 0.5

def tensor2numpy(x):
    return x.detach().cpu().numpy().transpose(1,2,0)

def RGB2BGR(x):
    return cv2.cvtColor(x, cv2.COLOR_RGB2BGR)


# weights initialization
def init_weights(net, stddev=.02):

  def weights_initializer(m):
    classname = m.__class__.__name__
    if hasattr(m, 'weight') and (classname.find('Conv') != -1 or classname.find('Linear') != -1):
      init.normal_(m.weight.data, mean=0.0, std=stddev)

      if hasattr(m, 'bias') and m.bias is not None:
        init.constant_(m.bias.data, 0.0)

  net.apply(weights_initializer)
  return net


def init_net(net, device, stddev=0.02):
  net.to(device)
  init_weights(net, stddev=stddev)
  return net


def ground_truth_tensor(tensor, label):
  return torch.ones_like(tensor) * label

# %% [markdown]
# ### Dataset and Images Queue

# %%
def read_pil_image(path):
  with open(path, 'rb') as f:
    img = Image.open(f)
    return img.convert("RGB")


class DatasetFolder(torch.utils.data.Dataset):
  def __init__(self, root, extension, transform=None):
    self.img_paths = glob.glob(os.path.join(root, '*.{}'.format(extension)))
    self.img_len = len(self.img_paths)
    assert self.img_len > 0, 'Found 0 images in {}'.format(root)
    self.transform = transform


  def __getitem__(self, index):
    img = read_pil_image(self.img_paths[index % self.img_len])
    img = self.transform(img)
    return img


  def __len__(self):
    return self.img_len


class ImageFolder(DatasetFolder):
  def __init__(self, root, extension, transform):
    super(ImageFolder, self).__init__(root=root, 
                                      extension=extension, 
                                      transform=transform)

# %%
class ImagePool():
  def __init__(self, pool_size):
    self.pool_size=pool_size
    self.images = []

  def sample(self, image_data):
    if len(self.images) < self.pool_size:
      self.images.append(image_data)
      return image_data
    
    p = random.random()
    if p > 0.5:
      idx = random.randrange(0, self.pool_size)
      tmp_data = self.images[idx].clone()
      self.images[idx] = image_data.clone()
      return tmp_data

    return image_data

# %% [markdown]
# ### Model

# %%
checkpoint_dir = 'ugatit/output/checkpoints/checkpoints_v0.3.0/'
images_dir = 'ugatit/output/images/images_v0.3.0/'
summary_dir = 'ugatit/output/summary/summary_v0.3.0/'
os.makedirs(checkpoint_dir, exist_ok=True)
os.makedirs(images_dir, exist_ok=True)
os.makedirs(summary_dir, exist_ok=True)


A_dir = 'data/shadow_USR/shadow_train/'
B_dir = 'data/shadow_USR/shadow_free/'
A_test_dir = 'data/shadow_USR/shadow_test/'



load_model = True
batch_size=1
image_size=256
ngf=64
ndf=64
light = True

weight_adv = 1
weight_cyc = 10
weight_idt = 10
# it helps only generator to get attended, while discriminator does not use distinct cam loss
weight_cam = 1000  


learning_rate=2e-4
beta1=.5
pool_size=50
mask_queue_size=50
n_blocks=4
slope=0.2
stddev=0.02
weight_decay=0.0001
pool_size=50

input_nc=3
output_nc=3
device=torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
real_label=0.9

n_steps = int(3e5)
decay_start = n_steps // 2
decay_flag=True
print_freq = 10
save_freq = 5000
test_freq = 500

# %%
def get_step(filename):
  match = re.findall('(\d+).pt', filename)[0]
  return int(match)
  
def latest_checkpoint_files(check_dir, f):
  return max(map(f, os.listdir(check_dir)))

# %%
class UGATIT(object):
  def __init__(self):
    self.img_size=image_size
    self.batch_size=batch_size
    self.device=device
    self.n_res=n_blocks
    self.ch = ngf
    self.light=light
    self.lr = learning_rate
    self.weight_decay = weight_decay

    self.adv_weight = weight_adv
    self.cycle_weight = weight_cyc
    self.identity_weight = weight_idt
    self.cam_weight = weight_cam


  def build_model(self):
    """ DataLoader """
    train_transform = transforms.Compose([
        transforms.RandomHorizontalFlip(),
        transforms.Resize((self.img_size + 30, self.img_size+30)),
        transforms.RandomCrop(self.img_size),
        transforms.ToTensor(),
        transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
    ])
    test_transform = transforms.Compose([
        transforms.Resize((self.img_size, self.img_size)),
        transforms.ToTensor(),
        transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
    ])

    self.trainA = ImageFolder(A_dir, 'jpg', train_transform)
    self.trainB = ImageFolder(B_dir, 'jpg', train_transform)
    self.trainA_loader = DataLoader(self.trainA, batch_size=self.batch_size, shuffle=True)
    self.trainB_loader = DataLoader(self.trainB, batch_size=self.batch_size, shuffle=True)

    """ Define Generator, Discriminator """
    self.genA2B = ResnetGenerator(input_nc=3, output_nc=3, ngf=self.ch, 
                                  n_blocks=self.n_res, img_size=self.img_size, 
                                  light=self.light)
    self.genB2A = ResnetGenerator(input_nc=3, output_nc=3, 
                                  ngf=self.ch, n_blocks=self.n_res, 
                                  img_size=self.img_size, light=self.light)
    self.disGA = Discriminator(input_nc=3, ndf=self.ch, n_layers=7)
    self.disGB = Discriminator(input_nc=3, ndf=self.ch, n_layers=7)
    self.disLA = Discriminator(input_nc=3, ndf=self.ch, n_layers=5)
    self.disLB = Discriminator(input_nc=3, ndf=self.ch, n_layers=5)

    # Adding the initialization step
    init_net(self.genA2B, self.device, stddev=stddev)
    init_net(self.genB2A, self.device, stddev=stddev)
    init_net(self.disGA, self.device, stddev=stddev)
    init_net(self.disGB, self.device, stddev=stddev)
    init_net(self.disLA, self.device, stddev=stddev)
    init_net(self.disLB, self.device, stddev=stddev)

    """ Define Loss """
    self.L1_loss = nn.L1Loss().to(self.device)
    self.MSE_loss = nn.MSELoss().to(self.device)
    self.BCE_loss = nn.BCEWithLogitsLoss().to(self.device)

    """ Trainer """
    self.G_optim = torch.optim.Adam(itertools.chain(self.genA2B.parameters(), self.genB2A.parameters()), 
                                    lr=self.lr, betas=(0.5, 0.999), weight_decay=self.weight_decay)
    self.D_optim = torch.optim.Adam(itertools.chain(self.disGA.parameters(), self.disGB.parameters(), 
                                                    self.disLA.parameters(), self.disLB.parameters()), 
                                    lr=self.lr, betas=(0.5, 0.999), weight_decay=self.weight_decay)

    """ Define Rho clipper to constraint the value of rho in AdaILN and ILN"""
    self.Rho_clipper = RhoClipper(0, 1)

    """Images buffer for fake updates of discriminators so they can obtain the history"""
    self.fake_A_buffer = ImagePool(pool_size=pool_size)
    self.fake_B_buffer = ImagePool(pool_size=pool_size)

    """Summary writing to tensorboard"""
    self.writer = SummaryWriter(log_dir=summary_dir)


  def train(self):
    self.genA2B.train(), self.genB2A.train(), self.disGA.train(), self.disGB.train(), self.disLA.train(), self.disLB.train()

    start_iter = 1
    if load_model:
      print("---- Loading the model ----".upper())
      model_list = glob.glob(os.path.join(checkpoint_dir, '*.pt'))
      if len(model_list) > 0:
        start_iter = latest_checkpoint_files(checkpoint_dir, get_step)
        print('Load the model from {}'.format(start_iter))
        self.load(checkpoint_dir, start_iter)
        if decay_flag and start_iter > decay_start:
          self.G_optim.param_groups[0]['lr'] -= (lr / decay_start) * (start_iter - decay_start)
          self.D_optim.param_groups[0]['lr'] -= (lr / decay_start) * (start_iter - decay_start)
        start_iter += 1  # for not repeating the start_iter step

    # training loop
    try:
      print('training start !')
      start_time = time.time()
      counter=start_iter
      for step in tqdm_notebook(range(start_iter, n_steps + 1), total=n_steps-start_iter):
        if decay_flag and step > (n_steps // 2):
            self.G_optim.param_groups[0]['lr'] -= (self.lr / (n_steps // 2))
            self.D_optim.param_groups[0]['lr'] -= (self.lr / (n_steps // 2))

        try:
            real_A = trainA_iter.next()
        except:
            trainA_iter = iter(self.trainA_loader)
            real_A = trainA_iter.next()

        try:
            real_B = trainB_iter.next()
        except:
            trainB_iter = iter(self.trainB_loader)
            real_B = trainB_iter.next()

        real_A, real_B = real_A.to(self.device), real_B.to(self.device)

        # Update G
        self.G_optim.zero_grad()

        fake_A2B, fake_A2B_cam_logit, _ = self.genA2B(real_A)
        fake_B2A, fake_B2A_cam_logit, _ = self.genB2A(real_B)

        fake_A2B2A, _, _ = self.genB2A(fake_A2B)
        fake_B2A2B, _, _ = self.genA2B(fake_B2A)

        fake_A2A, fake_A2A_cam_logit, _ = self.genB2A(real_A)
        fake_B2B, fake_B2B_cam_logit, _ = self.genA2B(real_B)

        fake_GA_logit, fake_GA_cam_logit, _ = self.disGA(fake_B2A)
        fake_LA_logit, fake_LA_cam_logit, _ = self.disLA(fake_B2A)
        fake_GB_logit, fake_GB_cam_logit, _ = self.disGB(fake_A2B)
        fake_LB_logit, fake_LB_cam_logit, _ = self.disLB(fake_A2B)

        G_ad_loss_GA = self.MSE_loss(fake_GA_logit, ground_truth_tensor(fake_GA_logit, real_label).to(self.device))
        G_ad_cam_loss_GA = self.MSE_loss(fake_GA_cam_logit, ground_truth_tensor(fake_GA_cam_logit, real_label).to(self.device))
        G_ad_loss_LA = self.MSE_loss(fake_LA_logit, ground_truth_tensor(fake_LA_logit, real_label).to(self.device))
        G_ad_cam_loss_LA = self.MSE_loss(fake_LA_cam_logit, ground_truth_tensor(fake_LA_cam_logit, real_label).to(self.device))
        G_ad_loss_GB = self.MSE_loss(fake_GB_logit, ground_truth_tensor(fake_GB_logit, real_label).to(self.device))
        G_ad_cam_loss_GB = self.MSE_loss(fake_GB_cam_logit, ground_truth_tensor(fake_GB_cam_logit, real_label).to(self.device))
        G_ad_loss_LB = self.MSE_loss(fake_LB_logit, ground_truth_tensor(fake_LB_logit, real_label).to(self.device))
        G_ad_cam_loss_LB = self.MSE_loss(fake_LB_cam_logit, ground_truth_tensor(fake_LB_cam_logit, real_label).to(self.device))

        # Cycle loss
        G_recon_loss_A = self.L1_loss(fake_A2B2A, real_A)
        G_recon_loss_B = self.L1_loss(fake_B2A2B, real_B)

        # Identity loss
        G_identity_loss_A = self.L1_loss(fake_A2A, real_A)
        G_identity_loss_B = self.L1_loss(fake_B2B, real_B)

        # CAM loss
        G_cam_loss_A = self.BCE_loss(fake_B2A_cam_logit, torch.ones_like(fake_B2A_cam_logit).to(self.device)) + self.BCE_loss(fake_A2A_cam_logit, torch.zeros_like(fake_A2A_cam_logit).to(self.device))
        G_cam_loss_B = self.BCE_loss(fake_A2B_cam_logit, torch.ones_like(fake_A2B_cam_logit).to(self.device)) + self.BCE_loss(fake_B2B_cam_logit, torch.zeros_like(fake_B2B_cam_logit).to(self.device))

        # Combine all losses together
        G_loss_A =  self.adv_weight * (G_ad_loss_GA + G_ad_cam_loss_GA + G_ad_loss_LA + G_ad_cam_loss_LA) + self.cycle_weight * G_recon_loss_A + self.identity_weight * G_identity_loss_A + self.cam_weight * G_cam_loss_A
        G_loss_B = self.adv_weight * (G_ad_loss_GB + G_ad_cam_loss_GB + G_ad_loss_LB + G_ad_cam_loss_LB) + self.cycle_weight * G_recon_loss_B + self.identity_weight * G_identity_loss_B + self.cam_weight * G_cam_loss_B

        Generator_loss = G_loss_A + G_loss_B
        Generator_loss.backward()
        self.G_optim.step()

        # Update D
        self.D_optim.zero_grad()

        # update discriminators on the history of the generated samples
        fake_A2B = self.fake_B_buffer.sample(fake_A2B)
        fake_B2A = self.fake_A_buffer.sample(fake_B2A)

        real_GA_logit, real_GA_cam_logit, _ = self.disGA(real_A)
        real_LA_logit, real_LA_cam_logit, _ = self.disLA(real_A)
        real_GB_logit, real_GB_cam_logit, _ = self.disGB(real_B)
        real_LB_logit, real_LB_cam_logit, _ = self.disLB(real_B)

        fake_GA_logit, fake_GA_cam_logit, _ = self.disGA(fake_B2A.detach())
        fake_LA_logit, fake_LA_cam_logit, _ = self.disLA(fake_B2A.detach())
        fake_GB_logit, fake_GB_cam_logit, _ = self.disGB(fake_A2B.detach())
        fake_LB_logit, fake_LB_cam_logit, _ = self.disLB(fake_A2B.detach())

        D_ad_loss_GA = self.MSE_loss(real_GA_logit, ground_truth_tensor(real_GA_logit, real_label).to(self.device)) + \
          self.MSE_loss(fake_GA_logit, torch.zeros_like(fake_GA_logit).to(self.device))

        D_ad_cam_loss_GA = self.MSE_loss(real_GA_cam_logit, ground_truth_tensor(real_GA_cam_logit, real_label).to(self.device)) + \
          self.MSE_loss(fake_GA_cam_logit, torch.zeros_like(fake_GA_cam_logit).to(self.device))

        D_ad_loss_LA = self.MSE_loss(real_LA_logit, ground_truth_tensor(real_LA_logit, real_label).to(self.device)) + \
          self.MSE_loss(fake_LA_logit, torch.zeros_like(fake_LA_logit).to(self.device))

        D_ad_cam_loss_LA = self.MSE_loss(real_LA_cam_logit, ground_truth_tensor(real_LA_cam_logit, real_label).to(self.device)) + \
          self.MSE_loss(fake_LA_cam_logit, torch.zeros_like(fake_LA_cam_logit).to(self.device))

        D_ad_loss_GB = self.MSE_loss(real_GB_logit, ground_truth_tensor(real_GB_logit, real_label).to(self.device)) + \
          self.MSE_loss(fake_GB_logit, torch.zeros_like(fake_GB_logit).to(self.device))

        D_ad_cam_loss_GB = self.MSE_loss(real_GB_cam_logit, ground_truth_tensor(real_GB_cam_logit, real_label).to(self.device)) + \
          self.MSE_loss(fake_GB_cam_logit, torch.zeros_like(fake_GB_cam_logit).to(self.device))

        D_ad_loss_LB = self.MSE_loss(real_LB_logit, ground_truth_tensor(real_LB_logit, real_label).to(self.device)) + \
          self.MSE_loss(fake_LB_logit, torch.zeros_like(fake_LB_logit).to(self.device))

        D_ad_cam_loss_LB = self.MSE_loss(real_LB_cam_logit, ground_truth_tensor(real_LB_cam_logit, real_label).to(self.device)) + \
          self.MSE_loss(fake_LB_cam_logit, torch.zeros_like(fake_LB_cam_logit).to(self.device))

        D_loss_A = 0.5 * self.adv_weight * (D_ad_loss_GA + D_ad_cam_loss_GA + D_ad_loss_LA + D_ad_cam_loss_LA)
        D_loss_B = 0.5 * self.adv_weight * (D_ad_loss_GB + D_ad_cam_loss_GB + D_ad_loss_LB + D_ad_cam_loss_LB)

        Discriminator_loss = D_loss_A + D_loss_B
        Discriminator_loss.backward()
        self.D_optim.step()


        # clip parameter of AdaILN and ILN, applied after optimizer step
        self.genA2B.apply(self.Rho_clipper)
        self.genB2A.apply(self.Rho_clipper)

        if step % print_freq == 0:
          time_spent = time.time() - start_time
          h = time_spent // 3600
          m = (time_spent - h * 3600) // 60
          s = int(time_spent - h * 3600 - m * 60)
          print("[{}/{}]\nD_loss : {:.4f}\nG_loss: {:.4f}".format(step, n_steps, Discriminator_loss, Generator_loss))
          print("Time: {}:{}:{}".format(h, m, s))

          # Summary writing
          G_adv_loss_A = (G_ad_loss_GA + G_ad_cam_loss_GA + G_ad_loss_LA + G_ad_cam_loss_LA)
          G_adv_loss_B = (G_ad_loss_GB + G_ad_cam_loss_GB + G_ad_loss_LB + G_ad_cam_loss_LB)
          print(("loss_G_AB: {:.3f}\nloss_G_AB_GAN: {:.3f}\nloss_G_AB_identity: {:.3f}\n" + 
                "loss_G_AB_cycle: {:.3f}\nloss_G_AB_cam: {:.3f}\nloss_G_BA: {:.3f}\nloss_G_BA_GAN: {:.3f}\n" + 
                "loss_G_BA_identity: {:.3f}\nloss_G_BA_cycle: {:.3f}\nloss_G_BA_cam: {:.3f}\n").format(
                    G_loss_B, G_adv_loss_B, G_identity_loss_B, G_recon_loss_B, G_cam_loss_B, 
                    G_loss_A, G_adv_loss_A, G_identity_loss_A, G_recon_loss_A, G_cam_loss_A
                ))
          self.writer.add_scalar('G/G_AB', G_loss_B, global_step=step)
          self.writer.add_scalar('G/G_AB_GAN', G_adv_loss_B, global_step=step)
          self.writer.add_scalar('G/G_AB_identity', G_identity_loss_B, global_step=step)
          self.writer.add_scalar('G/G_AB_cycle', G_recon_loss_B, global_step=step)
          self.writer.add_scalar('G/G_AB_cam', G_cam_loss_B, global_step=step)

          self.writer.add_scalar('G/G_BA', G_loss_A, global_step=step)
          self.writer.add_scalar('G/G_BA_GAN', G_adv_loss_A, global_step=step)
          self.writer.add_scalar('G/G_BA_identity', G_identity_loss_A, global_step=step)
          self.writer.add_scalar('G/G_BA_cycle', G_recon_loss_A, global_step=step)
          self.writer.add_scalar('G/G_BA_cam', G_cam_loss_A, global_step=step)

          # Discriminator monitoring
          D_LA = D_ad_loss_LA + D_ad_cam_loss_LA
          D_GA = D_ad_loss_GA + D_ad_cam_loss_GA
          
          D_LB = D_ad_loss_LB + D_ad_cam_loss_LB
          D_GB = D_ad_loss_GB + D_ad_cam_loss_GB
          print(("loss_D_LA: {:.3f}\nloss_D_LA_GAN: {:.3f}\nloss_D_LA_cam: {:.3f}\n" + 
                "loss_D_GA: {:.3f}\nloss_D_GA_GAN: {:.3f}\nloss_D_GA_cam: {:.3f}\n" + 
                "loss_D_LB: {:.3f}\nloss_D_LB_GAN: {:.3f}\nloss_D_LB_cam: {:.3f}\n" +
                "loss_D_GB: {:.3f}\nloss_D_GB_GAN: {:.3f}\nloss_D_GB_cam: {:.3f}\n").format(
                    D_LA, D_ad_loss_LA, D_ad_cam_loss_LA, D_GA, D_ad_loss_GA, D_ad_cam_loss_GA,
                    D_LB, D_ad_loss_LB, D_ad_cam_loss_LB, D_GB, D_ad_loss_GB, D_ad_cam_loss_GB
                ))
          self.writer.add_scalar("D/D_LA", D_LA, global_step=step)
          self.writer.add_scalar("D/D_LA_GAN", D_ad_loss_LA, global_step=step)
          self.writer.add_scalar("D/D_LA_cam", D_ad_cam_loss_LA, global_step=step)
          self.writer.add_scalar("D/D_GA", D_GA, global_step=step)
          self.writer.add_scalar("D/D_GA_GAN", D_ad_loss_GA, global_step=step)
          self.writer.add_scalar("D/D_GA_cam", D_ad_cam_loss_GA, global_step=step)
          self.writer.add_scalar("D/D_LB", D_LB, global_step=step)
          self.writer.add_scalar("D/D_LB_GAN", D_ad_loss_LB, global_step=step)
          self.writer.add_scalar("D/D_LB_cam", D_ad_cam_loss_LB, global_step=step)
          self.writer.add_scalar("D/D_GB", D_GB, global_step=step)
          self.writer.add_scalar("D/D_GB_GAN", D_ad_loss_GB, global_step=step)
          self.writer.add_scalar("D/D_GB_cam", D_ad_cam_loss_GB, global_step=step)
          
        if step % save_freq == 0:
          print("Save the checkpoint : ", step)
          self.save(checkpoint_dir, step)

        if step % test_freq == 0:
        # copied from original implementation
          train_sample_num = 5

          A2B = np.zeros((image_size * 4, 0, 3))
          B2A = np.zeros((image_size * 4, 0, 3))

          self.genA2B.eval(), self.genB2A.eval(), self.disGA.eval(), self.disGB.eval(), self.disLA.eval(), self.disLB.eval()
          
          for _ in range(train_sample_num):
            try:
                real_A = trainA_iter.next()
            except:
                trainA_iter = iter(self.trainA_loader)
                real_A = trainA_iter.next()

            try:
                real_B = trainB_iter.next()
            except:
                trainB_iter = iter(self.trainB_loader)
                real_B = trainB_iter.next()
            real_A, real_B = real_A.to(device), real_B.to(device)

            fake_A2B, _, fake_A2B_heatmap = self.genA2B(real_A)
            fake_B2A, _, fake_B2A_heatmap = self.genB2A(real_B)

            fake_A2B2A, _, fake_A2B2A_heatmap = self.genB2A(fake_A2B)
            fake_B2A2B, _, fake_B2A2B_heatmap = self.genA2B(fake_B2A)

            fake_A2A, _, fake_A2A_heatmap = self.genB2A(real_A)
            fake_B2B, _, fake_B2B_heatmap = self.genA2B(real_B)

            A2B = np.concatenate((A2B, np.concatenate((RGB2BGR(tensor2numpy(denorm(real_A[0]))),
                                                        cam(tensor2numpy(fake_A2B_heatmap[0]), image_size),
                                                        RGB2BGR(tensor2numpy(denorm(fake_A2B[0]))),
                                                        RGB2BGR(tensor2numpy(denorm(fake_A2B2A[0])))), 0)), 1)

            B2A = np.concatenate((B2A, np.concatenate((RGB2BGR(tensor2numpy(denorm(real_B[0]))),
                                                        cam(tensor2numpy(fake_B2A_heatmap[0]), image_size),
                                                        RGB2BGR(tensor2numpy(denorm(fake_B2A[0]))),
                                                        RGB2BGR(tensor2numpy(denorm(fake_B2A2B[0])))), 0)), 1)
          cv2.imwrite(os.path.join(images_dir,'A2B_%07d.png' % step), A2B * 255.0)
          cv2.imwrite(os.path.join(images_dir,'B2A_%07d.png' % step), B2A * 255.0)
          self.genA2B.train(), self.genB2A.train(), self.disLA.train(), self.disLB.train(), self.disGA.train(), self.disGB.train()
        counter += 1
    except Exception as e:
      raise e
    finally:
      print("---- Save the checkpoint ----")
      self.save(checkpoint_dir, counter)
      print("---- Finished ----".upper())



  def load(self, path, step):
    params = torch.load(os.path.join(path, 'params_{}.pt'.format(step)))
    self.genA2B.load_state_dict(params['genA2B'])
    self.genB2A.load_state_dict(params['genB2A'])
    self.disGA.load_state_dict(params['disGA'])
    self.disGB.load_state_dict(params['disGB'])
    self.disLA.load_state_dict(params['disLA'])
    self.disLB.load_state_dict(params['disLB'])

  def save(self, path, step):
    params = {}
    params['genA2B'] = self.genA2B.state_dict()
    params['genB2A'] = self.genB2A.state_dict()
    params['disGA'] = self.disGA.state_dict()
    params['disGB'] = self.disGB.state_dict()
    params['disLA'] = self.disLA.state_dict()
    params['disLB'] = self.disLB.state_dict()
    torch.save(params, os.path.join(path, 'params_{}.pt'.format(step)))

# %%
model = UGATIT()
model.build_model()
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
model.train()
# Out:
# ---- LOADING THE MODEL ----
# Load the model from 93812
# training start !
# HBox(children=(IntProgress(value=0, max=206187), HTML(value='')))
# [93820/300000]
# D_loss : 1.5185
# G_loss: 4024.2136
# Time: 0.0:0.0:13
# loss_G_AB: 3018.188
# loss_G_AB_GAN: 1.475
# loss_G_AB_identity: 0.139
# loss_G_AB_cycle: 0.194
# loss_G_AB_cam: 3.013
# loss_G_BA: 1006.026
# loss_G_BA_GAN: 1.225
# loss_G_BA_identity: 0.136
# loss_G_BA_cycle: 0.172
# loss_G_BA_cam: 1.002
#
# loss_D_LA: 0.594
# loss_D_LA_GAN: 0.349
# loss_D_LA_cam: 0.244
# loss_D_GA: 0.797
# loss_D_GA_GAN: 0.416
# loss_D_GA_cam: 0.381
# loss_D_LB: 0.676
# loss_D_LB_GAN: 0.408
# loss_D_LB_cam: 0.268
# loss_D_GB: 0.971
# loss_D_GB_GAN: 0.522
# loss_D_GB_cam: 0.449
#
# [93830/300000]
# D_loss : 1.5220
# G_loss: 15.5420
# Time: 0.0:0.0:29
# loss_G_AB: 7.681
# loss_G_AB_GAN: 0.927
# loss_G_AB_identity: 0.124
# loss_G_AB_cycle: 0.144
# loss_G_AB_cam: 0.004
# loss_G_BA: 7.861
# loss_G_BA_GAN: 1.481
# loss_G_BA_identity: 0.198
# loss_G_BA_cycle: 0.178
# loss_G_BA_cam: 0.003
#
# loss_D_LA: 0.879
# loss_D_LA_GAN: 0.513
# loss_D_LA_cam: 0.366
# loss_D_GA: 0.824
# loss_D_GA_GAN: 0.437
# loss_D_GA_cam: 0.387
# loss_D_LB: 0.721
# loss_D_LB_GAN: 0.430
# loss_D_LB_cam: 0.291
# loss_D_GB: 0.620
# loss_D_GB_GAN: 0.327
# loss_D_GB_cam: 0.294
#
# [93840/300000]
# D_loss : 1.5796
# G_loss: 135.8180
# Time: 0.0:0.0:45
# loss_G_AB: 110.100
# loss_G_AB_GAN: 1.632
# loss_G_AB_identity: 0.106
# loss_G_AB_cycle: 0.167
# loss_G_AB_cam: 0.106
# loss_G_BA: 25.718
# loss_G_BA_GAN: 0.999
# loss_G_BA_identity: 0.164
# loss_G_BA_cycle: 0.188
# loss_G_BA_cam: 0.021
#
# loss_D_LA: 0.719
# loss_D_LA_GAN: 0.430
# loss_D_LA_cam: 0.289
# loss_D_GA: 0.858
# loss_D_GA_GAN: 0.395
# loss_D_GA_cam: 0.462
# loss_D_LB: 0.580
# loss_D_LB_GAN: 0.390
# loss_D_LB_cam: 0.190
# loss_D_GB: 1.003
# loss_D_GB_GAN: 0.512
# loss_D_GB_cam: 0.491
#
# [93850/300000]
# D_loss : 1.4229
# G_loss: 34.2049
# Time: 0.0:1.0:2
# loss_G_AB: 20.152
# loss_G_AB_GAN: 1.487
# loss_G_AB_identity: 0.132
# loss_G_AB_cycle: 0.175
# loss_G_AB_cam: 0.016
# loss_G_BA: 14.053
# loss_G_BA_GAN: 0.674
# loss_G_BA_identity: 0.123
# loss_G_BA_cycle: 0.186
# loss_G_BA_cam: 0.010
#
# loss_D_LA: 0.620
# loss_D_LA_GAN: 0.356
# loss_D_LA_cam: 0.264
# loss_D_GA: 0.880
# loss_D_GA_GAN: 0.542
# loss_D_GA_cam: 0.338
# loss_D_LB: 0.741
# loss_D_LB_GAN: 0.434
# loss_D_LB_cam: 0.307
# loss_D_GB: 0.605
# loss_D_GB_GAN: 0.367
# loss_D_GB_cam: 0.238
#
# [93860/300000]
# D_loss : 1.5223
# G_loss: 11.1063
# Time: 0.0:1.0:19
# loss_G_AB: 5.776
# loss_G_AB_GAN: 0.570
# loss_G_AB_identity: 0.215
# loss_G_AB_cycle: 0.190
# loss_G_AB_cam: 0.001
# loss_G_BA: 5.330
# loss_G_BA_GAN: 1.080
# loss_G_BA_identity: 0.168
# loss_G_BA_cycle: 0.170
# loss_G_BA_cam: 0.001
#
# loss_D_LA: 0.633
# loss_D_LA_GAN: 0.420
# loss_D_LA_cam: 0.213
# loss_D_GA: 0.758
# loss_D_GA_GAN: 0.526
# loss_D_GA_cam: 0.231
# loss_D_LB: 0.543
# loss_D_LB_GAN: 0.317
# loss_D_LB_cam: 0.226
# loss_D_GB: 1.111
# loss_D_GB_GAN: 0.690
# loss_D_GB_cam: 0.421
#
# [93870/300000]
# D_loss : 0.8873
# G_loss: 235.3841
# Time: 0.0:1.0:35
# loss_G_AB: 205.560
# loss_G_AB_GAN: 1.086
# loss_G_AB_identity: 0.142
# loss_G_AB_cycle: 0.215
# loss_G_AB_cam: 0.201
# loss_G_BA: 29.825
# loss_G_BA_GAN: 0.540
# loss_G_BA_identity: 0.133
# loss_G_BA_cycle: 0.146
# loss_G_BA_cam: 0.026
#
# loss_D_LA: 0.365
# loss_D_LA_GAN: 0.224
# loss_D_LA_cam: 0.142
# loss_D_GA: 0.232
# loss_D_GA_GAN: 0.138
# loss_D_GA_cam: 0.094
# loss_D_LB: 0.528
# loss_D_LB_GAN: 0.315
# loss_D_LB_cam: 0.212
# loss_D_GB: 0.650
# loss_D_GB_GAN: 0.378
# loss_D_GB_cam: 0.272
#
# [93880/300000]
# D_loss : 1.2804
# G_loss: 144.3589
# Time: 0.0:1.0:52
# loss_G_AB: 18.297
# loss_G_AB_GAN: 0.869
# loss_G_AB_identity: 0.061
# loss_G_AB_cycle: 0.096
# loss_G_AB_cam: 0.016
# loss_G_BA: 126.062
# loss_G_BA_GAN: 0.993
# loss_G_BA_identity: 0.109
# loss_G_BA_cycle: 0.104
# loss_G_BA_cam: 0.123
#
# loss_D_LA: 0.395
# loss_D_LA_GAN: 0.255
# loss_D_LA_cam: 0.140
# loss_D_GA: 0.406
# loss_D_GA_GAN: 0.259
# loss_D_GA_cam: 0.146
# loss_D_LB: 0.844
# loss_D_LB_GAN: 0.464
# loss_D_LB_cam: 0.380
# loss_D_GB: 0.916
# loss_D_GB_GAN: 0.429
# loss_D_GB_cam: 0.486
#
# [93890/300000]
# D_loss : 0.8328
# G_loss: 10.6791
# Time: 0.0:2.0:8
# loss_G_AB: 4.224
# loss_G_AB_GAN: 1.163
# loss_G_AB_identity: 0.092
# loss_G_AB_cycle: 0.108
# loss_G_AB_cam: 0.001
# loss_G_BA: 6.455
# loss_G_BA_GAN: 1.355
# loss_G_BA_identity: 0.137
# loss_G_BA_cycle: 0.172
# loss_G_BA_cam: 0.002
#
# loss_D_LA: 0.346
# loss_D_LA_GAN: 0.238
# loss_D_LA_cam: 0.108
# loss_D_GA: 0.248
# loss_D_GA_GAN: 0.142
# loss_D_GA_cam: 0.105
# loss_D_LB: 0.485
# loss_D_LB_GAN: 0.317
# loss_D_LB_cam: 0.167
# loss_D_GB: 0.587
# loss_D_GB_GAN: 0.250
# loss_D_GB_cam: 0.338
#
# [93900/300000]
# D_loss : 0.9035
# G_loss: 8.1067
# Time: 0.0:2.0:24
# loss_G_AB: 3.836
# loss_G_AB_GAN: 0.949
# loss_G_AB_identity: 0.074
# loss_G_AB_cycle: 0.088
# loss_G_AB_cam: 0.001
# loss_G_BA: 4.271
# loss_G_BA_GAN: 1.696
# loss_G_BA_identity: 0.063
# loss_G_BA_cycle: 0.104
# loss_G_BA_cam: 0.001
#
# loss_D_LA: 0.335
# loss_D_LA_GAN: 0.239
# loss_D_LA_cam: 0.095
# loss_D_GA: 0.649
# loss_D_GA_GAN: 0.313
# loss_D_GA_cam: 0.336
# loss_D_LB: 0.299
# loss_D_LB_GAN: 0.196
# loss_D_LB_cam: 0.103
# loss_D_GB: 0.525
# loss_D_GB_GAN: 0.279
# loss_D_GB_cam: 0.245
#
# [93910/300000]
# D_loss : 1.0900
# G_loss: 9.8412
# Time: 0.0:2.0:40
# loss_G_AB: 6.517
# loss_G_AB_GAN: 1.034
# loss_G_AB_identity: 0.113
# loss_G_AB_cycle: 0.111
# loss_G_AB_cam: 0.003
# loss_G_BA: 3.324
# loss_G_BA_GAN: 0.620
# loss_G_BA_identity: 0.077
# loss_G_BA_cycle: 0.152
# loss_G_BA_cam: 0.000
#
# loss_D_LA: 0.435
# loss_D_LA_GAN: 0.305
# loss_D_LA_cam: 0.130
# loss_D_GA: 0.468
# loss_D_GA_GAN: 0.267
# loss_D_GA_cam: 0.201
# loss_D_LB: 0.664
# loss_D_LB_GAN: 0.405
# loss_D_LB_cam: 0.259
# loss_D_GB: 0.613
# loss_D_GB_GAN: 0.357
# loss_D_GB_cam: 0.256
#
# [93920/300000]
# D_loss : 1.5132
# G_loss: 788.3392
# Time: 0.0:2.0:57
# loss_G_AB: 418.802
# loss_G_AB_GAN: 0.818
# loss_G_AB_identity: 0.129
# loss_G_AB_cycle: 0.125
# loss_G_AB_cam: 0.415
# loss_G_BA: 369.537
# loss_G_BA_GAN: 1.614
# loss_G_BA_identity: 0.089
# loss_G_BA_cycle: 0.147
# loss_G_BA_cam: 0.366
#
# loss_D_LA: 0.722
# loss_D_LA_GAN: 0.425
# loss_D_LA_cam: 0.298
# loss_D_GA: 0.896
# loss_D_GA_GAN: 0.489
# loss_D_GA_cam: 0.408
# loss_D_LB: 0.801
# loss_D_LB_GAN: 0.518
# loss_D_LB_cam: 0.283
# loss_D_GB: 0.606
# loss_D_GB_GAN: 0.306
# loss_D_GB_cam: 0.300
#
# [93930/300000]
# D_loss : 1.3077
# G_loss: 7.2944
# Time: 0.0:3.0:14
# loss_G_AB: 3.459
# loss_G_AB_GAN: 0.888
# loss_G_AB_identity: 0.067
# loss_G_AB_cycle: 0.087
# loss_G_AB_cam: 0.001
# loss_G_BA: 3.835
# loss_G_BA_GAN: 1.382
# loss_G_BA_identity: 0.069
# loss_G_BA_cycle: 0.143
# loss_G_BA_cam: 0.000
#
# loss_D_LA: 0.393
# loss_D_LA_GAN: 0.256
# loss_D_LA_cam: 0.137
# loss_D_GA: 0.273
# loss_D_GA_GAN: 0.180
# loss_D_GA_cam: 0.092
# loss_D_LB: 0.917
# loss_D_LB_GAN: 0.534
# loss_D_LB_cam: 0.383
# loss_D_GB: 1.032
# loss_D_GB_GAN: 0.486
# loss_D_GB_cam: 0.547
#
# [93940/300000]
# D_loss : 1.2073
# G_loss: 11.0805
# Time: 0.0:3.0:30
# loss_G_AB: 4.644
# loss_G_AB_GAN: 0.584
# loss_G_AB_identity: 0.057
# loss_G_AB_cycle: 0.070
# loss_G_AB_cam: 0.003
# loss_G_BA: 6.436
# loss_G_BA_GAN: 1.245
# loss_G_BA_identity: 0.192
# loss_G_BA_cycle: 0.197
# loss_G_BA_cam: 0.001
#
# loss_D_LA: 1.046
# loss_D_LA_GAN: 0.658
# loss_D_LA_cam: 0.388
# loss_D_GA: 0.550
# loss_D_GA_GAN: 0.360
# loss_D_GA_cam: 0.190
# loss_D_LB: 0.382
# loss_D_LB_GAN: 0.213
# loss_D_LB_cam: 0.169
# loss_D_GB: 0.436
# loss_D_GB_GAN: 0.248
# loss_D_GB_cam: 0.189
#
# [93950/300000]
# D_loss : 1.3380
# G_loss: 180.5979
# Time: 0.0:3.0:46
# loss_G_AB: 13.246
# loss_G_AB_GAN: 0.734
# loss_G_AB_identity: 0.050
# loss_G_AB_cycle: 0.048
# loss_G_AB_cam: 0.012
# loss_G_BA: 167.352
# loss_G_BA_GAN: 1.264
# loss_G_BA_identity: 0.136
# loss_G_BA_cycle: 0.177
# loss_G_BA_cam: 0.163
#
# loss_D_LA: 0.627
# loss_D_LA_GAN: 0.350
# loss_D_LA_cam: 0.277
# loss_D_GA: 0.766
# loss_D_GA_GAN: 0.461
# loss_D_GA_cam: 0.305
# loss_D_LB: 0.498
# loss_D_LB_GAN: 0.278
# loss_D_LB_cam: 0.220
# loss_D_GB: 0.785
# loss_D_GB_GAN: 0.392
# loss_D_GB_cam: 0.392
#
# [93960/300000]
# D_loss : 1.5647
# G_loss: 10.5104
# Time: 0.0:4.0:3
# loss_G_AB: 4.428
# loss_G_AB_GAN: 0.968
# loss_G_AB_identity: 0.054
# loss_G_AB_cycle: 0.082
# loss_G_AB_cam: 0.002
# loss_G_BA: 6.083
# loss_G_BA_GAN: 1.312
# loss_G_BA_identity: 0.177
# loss_G_BA_cycle: 0.200
# loss_G_BA_cam: 0.001
#
# loss_D_LA: 0.540
# loss_D_LA_GAN: 0.240
# loss_D_LA_cam: 0.301
# loss_D_GA: 0.736
# loss_D_GA_GAN: 0.342
# loss_D_GA_cam: 0.394
# loss_D_LB: 0.912
# loss_D_LB_GAN: 0.428
# loss_D_LB_cam: 0.485
# loss_D_GB: 0.941
# loss_D_GB_GAN: 0.483
# loss_D_GB_cam: 0.458
#
# [93970/300000]
# D_loss : 1.2180
# G_loss: 7.7823
# Time: 0.0:4.0:20
# loss_G_AB: 4.135
# loss_G_AB_GAN: 0.963
# loss_G_AB_identity: 0.057
# loss_G_AB_cycle: 0.088
# loss_G_AB_cam: 0.002
# loss_G_BA: 3.647
# loss_G_BA_GAN: 1.335
# loss_G_BA_identity: 0.067
# loss_G_BA_cycle: 0.068
# loss_G_BA_cam: 0.001
#
# loss_D_LA: 0.521
# loss_D_LA_GAN: 0.343
# loss_D_LA_cam: 0.178
# loss_D_GA: 0.514
# loss_D_GA_GAN: 0.318
# loss_D_GA_cam: 0.196
# loss_D_LB: 0.616
# loss_D_LB_GAN: 0.391
# loss_D_LB_cam: 0.225
# loss_D_GB: 0.785
# loss_D_GB_GAN: 0.432
# loss_D_GB_cam: 0.353
#
# [93980/300000]
# D_loss : 1.2957
# G_loss: 2235.3916
# Time: 0.0:4.0:36
# loss_G_AB: 273.124
# loss_G_AB_GAN: 1.869
# loss_G_AB_identity: 0.106
# loss_G_AB_cycle: 0.111
# loss_G_AB_cam: 0.269
# loss_G_BA: 1962.267
# loss_G_BA_GAN: 0.977
# loss_G_BA_identity: 0.111
# loss_G_BA_cycle: 0.139
# loss_G_BA_cam: 1.959
#
# loss_D_LA: 0.513
# loss_D_LA_GAN: 0.321
# loss_D_LA_cam: 0.192
# loss_D_GA: 0.725
# loss_D_GA_GAN: 0.428
# loss_D_GA_cam: 0.296
# loss_D_LB: 0.630
# loss_D_LB_GAN: 0.371
# loss_D_LB_cam: 0.259
# loss_D_GB: 0.724
# loss_D_GB_GAN: 0.377
# loss_D_GB_cam: 0.347
#
# [93990/300000]
# D_loss : 1.0406
# G_loss: 13.7165
# Time: 0.0:4.0:53
# loss_G_AB: 7.013
# loss_G_AB_GAN: 1.569
# loss_G_AB_identity: 0.190
# loss_G_AB_cycle: 0.232
# loss_G_AB_cam: 0.001
# loss_G_BA: 6.703
# loss_G_BA_GAN: 1.527
# loss_G_BA_identity: 0.110
# loss_G_BA_cycle: 0.120
# loss_G_BA_cam: 0.003
#
# loss_D_LA: 0.426
# loss_D_LA_GAN: 0.270
# loss_D_LA_cam: 0.156
# loss_D_GA: 0.613
# loss_D_GA_GAN: 0.300
# loss_D_GA_cam: 0.312
# loss_D_LB: 0.647
# loss_D_LB_GAN: 0.286
# loss_D_LB_cam: 0.361
# loss_D_GB: 0.395
# loss_D_GB_GAN: 0.238
# loss_D_GB_cam: 0.157
#
# [94000/300000]
# D_loss : 1.5206
# G_loss: 9.1385
# Time: 0.0:5.0:10
# loss_G_AB: 4.486
# loss_G_AB_GAN: 1.721
# loss_G_AB_identity: 0.102
# loss_G_AB_cycle: 0.131
# loss_G_AB_cam: 0.000
# loss_G_BA: 4.653
# loss_G_BA_GAN: 0.843
# loss_G_BA_identity: 0.103
# loss_G_BA_cycle: 0.120
# loss_G_BA_cam: 0.002
#
# loss_D_LA: 0.568
# loss_D_LA_GAN: 0.321
# loss_D_LA_cam: 0.247
# loss_D_GA: 1.110
# loss_D_GA_GAN: 0.620
# loss_D_GA_cam: 0.490
# loss_D_LB: 0.900
# loss_D_LB_GAN: 0.471
# loss_D_LB_cam: 0.429
# loss_D_GB: 0.463
# loss_D_GB_GAN: 0.251
# loss_D_GB_cam: 0.212
#
# [94010/300000]
# D_loss : 0.9064
# G_loss: 8.0018
# Time: 0.0:5.0:34
# loss_G_AB: 3.264
# loss_G_AB_GAN: 0.869
# loss_G_AB_identity: 0.063
# loss_G_AB_cycle: 0.091
# loss_G_AB_cam: 0.001
# loss_G_BA: 4.737
# loss_G_BA_GAN: 1.550
# loss_G_BA_identity: 0.096
# loss_G_BA_cycle: 0.128
# loss_G_BA_cam: 0.001
#
# loss_D_LA: 0.335
# loss_D_LA_GAN: 0.227
# loss_D_LA_cam: 0.108
# loss_D_GA: 0.392
# loss_D_GA_GAN: 0.179
# loss_D_GA_cam: 0.213
# loss_D_LB: 0.567
# loss_D_LB_GAN: 0.355
# loss_D_LB_cam: 0.212
# loss_D_GB: 0.519
# loss_D_GB_GAN: 0.264
# loss_D_GB_cam: 0.256
#
# [94020/300000]
# D_loss : 1.7464
# G_loss: 18.3233
# Time: 0.0:5.0:51
# loss_G_AB: 10.964
# loss_G_AB_GAN: 0.739
# loss_G_AB_identity: 0.103
# loss_G_AB_cycle: 0.116
# loss_G_AB_cam: 0.008
# loss_G_BA: 7.359
# loss_G_BA_GAN: 0.723
# loss_G_BA_identity: 0.098
# loss_G_BA_cycle: 0.133
# loss_G_BA_cam: 0.004
#
# loss_D_LA: 0.661
# loss_D_LA_GAN: 0.354
# loss_D_LA_cam: 0.308
# loss_D_GA: 0.660
# loss_D_GA_GAN: 0.329
# loss_D_GA_cam: 0.332
# loss_D_LB: 0.819
# loss_D_LB_GAN: 0.355
# loss_D_LB_cam: 0.464
# loss_D_GB: 1.352
# loss_D_GB_GAN: 0.678
# loss_D_GB_cam: 0.674
#
# [94030/300000]
# D_loss : 1.3142
# G_loss: 145.3552
# Time: 0.0:6.0:8
# loss_G_AB: 130.680
# loss_G_AB_GAN: 0.653
# loss_G_AB_identity: 0.140
# loss_G_AB_cycle: 0.161
# loss_G_AB_cam: 0.127
# loss_G_BA: 14.676
# loss_G_BA_GAN: 0.689
# loss_G_BA_identity: 0.166
# loss_G_BA_cycle: 0.133
# loss_G_BA_cam: 0.011
#
# loss_D_LA: 0.543
# loss_D_LA_GAN: 0.328
# loss_D_LA_cam: 0.215
# loss_D_GA: 0.697
# loss_D_GA_GAN: 0.315
# loss_D_GA_cam: 0.382
# loss_D_LB: 0.610
# loss_D_LB_GAN: 0.391
# loss_D_LB_cam: 0.219
# loss_D_GB: 0.779
# loss_D_GB_GAN: 0.385
# loss_D_GB_cam: 0.394
#
# [94040/300000]
# D_loss : 1.4303
# G_loss: 32.0651
# Time: 0.0:6.0:25
# loss_G_AB: 23.940
# loss_G_AB_GAN: 1.242
# loss_G_AB_identity: 0.127
# loss_G_AB_cycle: 0.164
# loss_G_AB_cam: 0.020
# loss_G_BA: 8.125
# loss_G_BA_GAN: 1.164
# loss_G_BA_identity: 0.094
# loss_G_BA_cycle: 0.138
# loss_G_BA_cam: 0.005
#
# loss_D_LA: 0.592
# loss_D_LA_GAN: 0.374
# loss_D_LA_cam: 0.217
# loss_D_GA: 0.795
# loss_D_GA_GAN: 0.294
# loss_D_GA_cam: 0.501
# loss_D_LB: 0.495
# loss_D_LB_GAN: 0.280
# loss_D_LB_cam: 0.215
# loss_D_GB: 0.978
# loss_D_GB_GAN: 0.443
# loss_D_GB_cam: 0.535
#
# [94050/300000]
# D_loss : 1.2738
# G_loss: 12.4318
# Time: 0.0:6.0:42
# loss_G_AB: 8.386
# loss_G_AB_GAN: 0.866
# loss_G_AB_identity: 0.159
# loss_G_AB_cycle: 0.313
# loss_G_AB_cam: 0.003
# loss_G_BA: 4.046
# loss_G_BA_GAN: 0.699
# loss_G_BA_identity: 0.061
# loss_G_BA_cycle: 0.079
# loss_G_BA_cam: 0.002
#
# loss_D_LA: 0.500
# loss_D_LA_GAN: 0.334
# loss_D_LA_cam: 0.165
# loss_D_GA: 0.789
# loss_D_GA_GAN: 0.379
# loss_D_GA_cam: 0.411
# loss_D_LB: 0.486
# loss_D_LB_GAN: 0.302
# loss_D_LB_cam: 0.184
# loss_D_GB: 0.772
# loss_D_GB_GAN: 0.355
# loss_D_GB_cam: 0.417
#
# [94060/300000]
# D_loss : 1.0362
# G_loss: 13.0457
# Time: 0.0:6.0:59
# loss_G_AB: 5.017
# loss_G_AB_GAN: 0.599
# loss_G_AB_identity: 0.103
# loss_G_AB_cycle: 0.153
# loss_G_AB_cam: 0.002
# loss_G_BA: 8.029
# loss_G_BA_GAN: 1.213
# loss_G_BA_identity: 0.096
# loss_G_BA_cycle: 0.117
# loss_G_BA_cam: 0.005
#
# loss_D_LA: 0.717
# loss_D_LA_GAN: 0.483
# loss_D_LA_cam: 0.234
# loss_D_GA: 0.345
# loss_D_GA_GAN: 0.219
# loss_D_GA_cam: 0.126
# loss_D_LB: 0.547
# loss_D_LB_GAN: 0.315
# loss_D_LB_cam: 0.232
# loss_D_GB: 0.463
# loss_D_GB_GAN: 0.225
# loss_D_GB_cam: 0.238
#
# [94070/300000]
# D_loss : 1.8545
# G_loss: 8.4931
# Time: 0.0:7.0:15
# loss_G_AB: 4.362
# loss_G_AB_GAN: 0.942
# loss_G_AB_identity: 0.138
# loss_G_AB_cycle: 0.166
# loss_G_AB_cam: 0.000
# loss_G_BA: 4.131
# loss_G_BA_GAN: 1.685
# loss_G_BA_identity: 0.096
# loss_G_BA_cycle: 0.122
# loss_G_BA_cam: 0.000
#
# loss_D_LA: 0.932
# loss_D_LA_GAN: 0.566
# loss_D_LA_cam: 0.366
# loss_D_GA: 0.948
# loss_D_GA_GAN: 0.559
# loss_D_GA_cam: 0.389
# loss_D_LB: 1.075
# loss_D_LB_GAN: 0.532
# loss_D_LB_cam: 0.543
# loss_D_GB: 0.753
# loss_D_GB_GAN: 0.375
# loss_D_GB_cam: 0.379
#
# [94080/300000]
# D_loss : 1.1638
# G_loss: 11.3082
# Time: 0.0:7.0:32
# loss_G_AB: 5.488
# loss_G_AB_GAN: 1.279
# loss_G_AB_identity: 0.164
# loss_G_AB_cycle: 0.179
# loss_G_AB_cam: 0.001
# loss_G_BA: 5.820
# loss_G_BA_GAN: 0.864
# loss_G_BA_identity: 0.077
# loss_G_BA_cycle: 0.104
# loss_G_BA_cam: 0.003
#
# loss_D_LA: 0.525
# loss_D_LA_GAN: 0.323
# loss_D_LA_cam: 0.202
# loss_D_GA: 0.455
# loss_D_GA_GAN: 0.288
# loss_D_GA_cam: 0.167
# loss_D_LB: 0.963
# loss_D_LB_GAN: 0.507
# loss_D_LB_cam: 0.457
# loss_D_GB: 0.384
# loss_D_GB_GAN: 0.183
# loss_D_GB_cam: 0.201
#
# [94090/300000]
# D_loss : 1.5826
# G_loss: 15.3312
# Time: 0.0:7.0:49
# loss_G_AB: 10.243
# loss_G_AB_GAN: 0.893
# loss_G_AB_identity: 0.084
# loss_G_AB_cycle: 0.106
# loss_G_AB_cam: 0.007
# loss_G_BA: 5.088
# loss_G_BA_GAN: 1.016
# loss_G_BA_identity: 0.105
# loss_G_BA_cycle: 0.104
# loss_G_BA_cam: 0.002
#
# loss_D_LA: 0.605
# loss_D_LA_GAN: 0.359
# loss_D_LA_cam: 0.246
# loss_D_GA: 0.761
# loss_D_GA_GAN: 0.346
# loss_D_GA_cam: 0.415
# loss_D_LB: 0.711
# loss_D_LB_GAN: 0.387
# loss_D_LB_cam: 0.323
# loss_D_GB: 1.089
# loss_D_GB_GAN: 0.553
# loss_D_GB_cam: 0.535
#
# [94100/300000]
# D_loss : 1.7509
# G_loss: 8.0168
# Time: 0.0:8.0:5
# loss_G_AB: 4.345
# loss_G_AB_GAN: 0.886
# loss_G_AB_identity: 0.115
# loss_G_AB_cycle: 0.146
# loss_G_AB_cam: 0.001
# loss_G_BA: 3.671
# loss_G_BA_GAN: 0.255
# loss_G_BA_identity: 0.113
# loss_G_BA_cycle: 0.141
# loss_G_BA_cam: 0.001
#
# loss_D_LA: 0.739
# loss_D_LA_GAN: 0.414
# loss_D_LA_cam: 0.325
# loss_D_GA: 0.768
# loss_D_GA_GAN: 0.431
# loss_D_GA_cam: 0.336
# loss_D_LB: 0.889
# loss_D_LB_GAN: 0.519
# loss_D_LB_cam: 0.370
# loss_D_GB: 1.106
# loss_D_GB_GAN: 0.483
# loss_D_GB_cam: 0.623
#
# [94110/300000]
# D_loss : 1.8114
# G_loss: 12.6569
# Time: 0.0:8.0:22
# loss_G_AB: 5.443
# loss_G_AB_GAN: 0.756
# loss_G_AB_identity: 0.148
# loss_G_AB_cycle: 0.193
# loss_G_AB_cam: 0.001
# loss_G_BA: 7.214
# loss_G_BA_GAN: 1.659
# loss_G_BA_identity: 0.090
# loss_G_BA_cycle: 0.097
# loss_G_BA_cam: 0.004
#
# loss_D_LA: 0.798
# loss_D_LA_GAN: 0.386
# loss_D_LA_cam: 0.413
# loss_D_GA: 1.209
# loss_D_GA_GAN: 0.656
# loss_D_GA_cam: 0.553
# loss_D_LB: 0.735
# loss_D_LB_GAN: 0.438
# loss_D_LB_cam: 0.296
# loss_D_GB: 0.880
# loss_D_GB_GAN: 0.339
# loss_D_GB_cam: 0.541
#
# [94120/300000]
# D_loss : 1.4105
# G_loss: 14.6120
# Time: 0.0:8.0:40
# loss_G_AB: 5.662
# loss_G_AB_GAN: 0.866
# loss_G_AB_identity: 0.111
# loss_G_AB_cycle: 0.137
# loss_G_AB_cam: 0.002
# loss_G_BA: 8.950
# loss_G_BA_GAN: 1.353
# loss_G_BA_identity: 0.086
# loss_G_BA_cycle: 0.113
# loss_G_BA_cam: 0.006
#
# loss_D_LA: 0.532
# loss_D_LA_GAN: 0.325
# loss_D_LA_cam: 0.207
# loss_D_GA: 0.562
# loss_D_GA_GAN: 0.336
# loss_D_GA_cam: 0.227
# loss_D_LB: 0.727
# loss_D_LB_GAN: 0.382
# loss_D_LB_cam: 0.346
# loss_D_GB: 0.999
# loss_D_GB_GAN: 0.545
# loss_D_GB_cam: 0.455
#
# [94130/300000]
# D_loss : 1.5638
# G_loss: 1792.0734
# Time: 0.0:8.0:57
# loss_G_AB: 385.017
# loss_G_AB_GAN: 1.193
# loss_G_AB_identity: 0.193
# loss_G_AB_cycle: 0.150
# loss_G_AB_cam: 0.380
# loss_G_BA: 1407.056
# loss_G_BA_GAN: 0.845
# loss_G_BA_identity: 0.070
# loss_G_BA_cycle: 0.078
# loss_G_BA_cam: 1.405
#
# loss_D_LA: 0.495
# loss_D_LA_GAN: 0.235
# loss_D_LA_cam: 0.260
# loss_D_GA: 0.547
# loss_D_GA_GAN: 0.323
# loss_D_GA_cam: 0.224
# loss_D_LB: 1.016
# loss_D_LB_GAN: 0.497
# loss_D_LB_cam: 0.519
# loss_D_GB: 1.070
# loss_D_GB_GAN: 0.473
# loss_D_GB_cam: 0.596
#
# [94140/300000]
# D_loss : 0.7989
# G_loss: 8.8696
# Time: 0.0:9.0:13
# loss_G_AB: 4.026
# loss_G_AB_GAN: 1.132
# loss_G_AB_identity: 0.076
# loss_G_AB_cycle: 0.100
# loss_G_AB_cam: 0.001
# loss_G_BA: 4.844
# loss_G_BA_GAN: 1.538
# loss_G_BA_identity: 0.067
# loss_G_BA_cycle: 0.108
# loss_G_BA_cam: 0.002
#
# loss_D_LA: 0.372
# loss_D_LA_GAN: 0.235
# loss_D_LA_cam: 0.138
# loss_D_GA: 0.161
# loss_D_GA_GAN: 0.068
# loss_D_GA_cam: 0.093
# loss_D_LB: 0.449
# loss_D_LB_GAN: 0.284
# loss_D_LB_cam: 0.165
# loss_D_GB: 0.615
# loss_D_GB_GAN: 0.358
# loss_D_GB_cam: 0.257
#
# [94150/300000]
# D_loss : 1.0541
# G_loss: 51.3125
# Time: 0.0:9.0:30
# loss_G_AB: 30.674
# loss_G_AB_GAN: 1.280
# loss_G_AB_identity: 0.080
# loss_G_AB_cycle: 0.106
# loss_G_AB_cam: 0.028
# loss_G_BA: 20.638
# loss_G_BA_GAN: 1.264
# loss_G_BA_identity: 0.098
# loss_G_BA_cycle: 0.102
# loss_G_BA_cam: 0.017
#
# loss_D_LA: 0.600
# loss_D_LA_GAN: 0.281
# loss_D_LA_cam: 0.319
# loss_D_GA: 0.259
# loss_D_GA_GAN: 0.129
# loss_D_GA_cam: 0.130
# loss_D_LB: 0.745
# loss_D_LB_GAN: 0.417
# loss_D_LB_cam: 0.329
# loss_D_GB: 0.504
# loss_D_GB_GAN: 0.264
# loss_D_GB_cam: 0.240
#
# [94160/300000]
# D_loss : 1.1956
# G_loss: 18.4683
# Time: 0.0:9.0:47
# loss_G_AB: 11.976
# loss_G_AB_GAN: 0.930
# loss_G_AB_identity: 0.219
# loss_G_AB_cycle: 0.177
# loss_G_AB_cam: 0.007
# loss_G_BA: 6.493
# loss_G_BA_GAN: 1.305
# loss_G_BA_identity: 0.071
# loss_G_BA_cycle: 0.082
# loss_G_BA_cam: 0.004
#
# loss_D_LA: 0.523
# loss_D_LA_GAN: 0.295
# loss_D_LA_cam: 0.227
# loss_D_GA: 0.417
# loss_D_GA_GAN: 0.233
# loss_D_GA_cam: 0.185
# loss_D_LB: 0.556
# loss_D_LB_GAN: 0.338
# loss_D_LB_cam: 0.218
# loss_D_GB: 0.896
# loss_D_GB_GAN: 0.398
# loss_D_GB_cam: 0.497
#
# [94170/300000]
# D_loss : 1.2300
# G_loss: 36.4920
# Time: 0.0:10.0:3
# loss_G_AB: 17.806
# loss_G_AB_GAN: 0.993
# loss_G_AB_identity: 0.188
# loss_G_AB_cycle: 0.197
# loss_G_AB_cam: 0.013
# loss_G_BA: 18.686
# loss_G_BA_GAN: 0.970
# loss_G_BA_identity: 0.104
# loss_G_BA_cycle: 0.126
# loss_G_BA_cam: 0.015
#
# loss_D_LA: 0.774
# loss_D_LA_GAN: 0.412
# loss_D_LA_cam: 0.361
# loss_D_GA: 0.606
# loss_D_GA_GAN: 0.388
# loss_D_GA_cam: 0.218
# loss_D_LB: 0.551
# loss_D_LB_GAN: 0.328
# loss_D_LB_cam: 0.222
# loss_D_GB: 0.529
# loss_D_GB_GAN: 0.332
# loss_D_GB_cam: 0.198
#
# [94180/300000]
# D_loss : 1.2106
# G_loss: 19.8720
# Time: 0.0:10.0:20
# loss_G_AB: 9.927
# loss_G_AB_GAN: 0.939
# loss_G_AB_identity: 0.150
# loss_G_AB_cycle: 0.164
# loss_G_AB_cam: 0.006
# loss_G_BA: 9.945
# loss_G_BA_GAN: 1.492
# loss_G_BA_identity: 0.104
# loss_G_BA_cycle: 0.121
# loss_G_BA_cam: 0.006
#
# loss_D_LA: 0.734
# loss_D_LA_GAN: 0.434
# loss_D_LA_cam: 0.299
# loss_D_GA: 0.596
# loss_D_GA_GAN: 0.385
# loss_D_GA_cam: 0.212
# loss_D_LB: 0.594
# loss_D_LB_GAN: 0.330
# loss_D_LB_cam: 0.264
# loss_D_GB: 0.498
# loss_D_GB_GAN: 0.227
# loss_D_GB_cam: 0.271
#
# [94190/300000]
# D_loss : 1.6118
# G_loss: 26.0556
# Time: 0.0:10.0:37
# loss_G_AB: 20.380
# loss_G_AB_GAN: 1.341
# loss_G_AB_identity: 0.103
# loss_G_AB_cycle: 0.140
# loss_G_AB_cam: 0.017
# loss_G_BA: 5.676
# loss_G_BA_GAN: 0.736
# loss_G_BA_identity: 0.125
# loss_G_BA_cycle: 0.168
# loss_G_BA_cam: 0.002
#
# loss_D_LA: 0.807
# loss_D_LA_GAN: 0.496
# loss_D_LA_cam: 0.311
# loss_D_GA: 0.739
# loss_D_GA_GAN: 0.436
# loss_D_GA_cam: 0.303
# loss_D_LB: 0.793
# loss_D_LB_GAN: 0.438
# loss_D_LB_cam: 0.354
# loss_D_GB: 0.885
# loss_D_GB_GAN: 0.512
# loss_D_GB_cam: 0.372
#
# [94200/300000]
# D_loss : 1.1737
# G_loss: 9.6362
# Time: 0.0:10.0:54
# loss_G_AB: 4.327
# loss_G_AB_GAN: 1.218
# loss_G_AB_identity: 0.088
# loss_G_AB_cycle: 0.122
# loss_G_AB_cam: 0.001
# loss_G_BA: 5.309
# loss_G_BA_GAN: 1.086
# loss_G_BA_identity: 0.096
# loss_G_BA_cycle: 0.156
# loss_G_BA_cam: 0.002
#
# loss_D_LA: 0.499
# loss_D_LA_GAN: 0.310
# loss_D_LA_cam: 0.189
# loss_D_GA: 0.549
# loss_D_GA_GAN: 0.327
# loss_D_GA_cam: 0.222
# loss_D_LB: 0.528
# loss_D_LB_GAN: 0.333
# loss_D_LB_cam: 0.195
# loss_D_GB: 0.772
# loss_D_GB_GAN: 0.370
# loss_D_GB_cam: 0.403
#
# [94210/300000]
# D_loss : 1.4057
# G_loss: 11.0294
# Time: 0.0:11.0:11
# loss_G_AB: 4.965
# loss_G_AB_GAN: 1.143
# loss_G_AB_identity: 0.112
# loss_G_AB_cycle: 0.123
# loss_G_AB_cam: 0.001
# loss_G_BA: 6.065
# loss_G_BA_GAN: 0.437
# loss_G_BA_identity: 0.107
# loss_G_BA_cycle: 0.078
# loss_G_BA_cam: 0.004
#
# loss_D_LA: 0.637
# loss_D_LA_GAN: 0.327
# loss_D_LA_cam: 0.309
# loss_D_GA: 1.324
# loss_D_GA_GAN: 0.531
# loss_D_GA_cam: 0.793
# loss_D_LB: 0.557
# loss_D_LB_GAN: 0.347
# loss_D_LB_cam: 0.210
# loss_D_GB: 0.294
# loss_D_GB_GAN: 0.168
# loss_D_GB_cam: 0.126
#
# [94220/300000]
# D_loss : 1.5076
# G_loss: 29.0360
# Time: 0.0:11.0:29
# loss_G_AB: 13.016
# loss_G_AB_GAN: 0.837
# loss_G_AB_identity: 0.136
# loss_G_AB_cycle: 0.160
# loss_G_AB_cam: 0.009
# loss_G_BA: 16.020
# loss_G_BA_GAN: 1.046
# loss_G_BA_identity: 0.075
# loss_G_BA_cycle: 0.087
# loss_G_BA_cam: 0.013
#
# loss_D_LA: 1.035
# loss_D_LA_GAN: 0.535
# loss_D_LA_cam: 0.500
# loss_D_GA: 0.874
# loss_D_GA_GAN: 0.502
# loss_D_GA_cam: 0.372
# loss_D_LB: 0.380
# loss_D_LB_GAN: 0.251
# loss_D_LB_cam: 0.128
# loss_D_GB: 0.726
# loss_D_GB_GAN: 0.340
# loss_D_GB_cam: 0.387
#
# [94230/300000]
# D_loss : 1.4822
# G_loss: 11.6570
# Time: 0.0:11.0:45
# loss_G_AB: 6.556
# loss_G_AB_GAN: 0.913
# loss_G_AB_identity: 0.163
# loss_G_AB_cycle: 0.167
# loss_G_AB_cam: 0.002
# loss_G_BA: 5.101
# loss_G_BA_GAN: 1.549
# loss_G_BA_identity: 0.091
# loss_G_BA_cycle: 0.097
# loss_G_BA_cam: 0.002
#
# loss_D_LA: 0.836
# loss_D_LA_GAN: 0.471
# loss_D_LA_cam: 0.365
# loss_D_GA: 0.442
# loss_D_GA_GAN: 0.217
# loss_D_GA_cam: 0.225
# loss_D_LB: 0.789
# loss_D_LB_GAN: 0.474
# loss_D_LB_cam: 0.315
# loss_D_GB: 0.897
# loss_D_GB_GAN: 0.446
# loss_D_GB_cam: 0.451
#
# [94240/300000]
# D_loss : 1.2930
# G_loss: 13.9311
# Time: 0.0:12.0:2
# loss_G_AB: 5.658
# loss_G_AB_GAN: 1.004
# loss_G_AB_identity: 0.195
# loss_G_AB_cycle: 0.188
# loss_G_AB_cam: 0.001
# loss_G_BA: 8.273
# loss_G_BA_GAN: 1.281
# loss_G_BA_identity: 0.085
# loss_G_BA_cycle: 0.117
# loss_G_BA_cam: 0.005
#
# loss_D_LA: 0.563
# loss_D_LA_GAN: 0.393
# loss_D_LA_cam: 0.170
# loss_D_GA: 0.434
# loss_D_GA_GAN: 0.253
# loss_D_GA_cam: 0.181
# loss_D_LB: 0.531
# loss_D_LB_GAN: 0.303
# loss_D_LB_cam: 0.228
# loss_D_GB: 1.057
# loss_D_GB_GAN: 0.536
# loss_D_GB_cam: 0.521
#
# [94250/300000]
# D_loss : 1.6366
# G_loss: 41.1469
# Time: 0.0:12.0:19
# loss_G_AB: 17.265
# loss_G_AB_GAN: 1.267
# loss_G_AB_identity: 0.139
# loss_G_AB_cycle: 0.139
# loss_G_AB_cam: 0.013
# loss_G_BA: 23.882
# loss_G_BA_GAN: 0.627
# loss_G_BA_identity: 0.113
# loss_G_BA_cycle: 0.116
# loss_G_BA_cam: 0.021
#
# loss_D_LA: 0.775
# loss_D_LA_GAN: 0.433
# loss_D_LA_cam: 0.342
# loss_D_GA: 0.709
# loss_D_GA_GAN: 0.333
# loss_D_GA_cam: 0.376
# loss_D_LB: 0.784
# loss_D_LB_GAN: 0.400
# loss_D_LB_cam: 0.384
# loss_D_GB: 1.005
# loss_D_GB_GAN: 0.523
# loss_D_GB_cam: 0.482
#
# [94260/300000]
# D_loss : 1.4553
# G_loss: 6.6277
# Time: 0.0:12.0:36
# loss_G_AB: 3.121
# loss_G_AB_GAN: 0.937
# loss_G_AB_identity: 0.113
# loss_G_AB_cycle: 0.058
# loss_G_AB_cam: 0.000
# loss_G_BA: 3.507
# loss_G_BA_GAN: 1.231
# loss_G_BA_identity: 0.044
# loss_G_BA_cycle: 0.075
# loss_G_BA_cam: 0.001
#
# loss_D_LA: 0.929
# loss_D_LA_GAN: 0.475
# loss_D_LA_cam: 0.454
# loss_D_GA: 0.746
# loss_D_GA_GAN: 0.377
# loss_D_GA_cam: 0.369
# loss_D_LB: 0.588
# loss_D_LB_GAN: 0.384
# loss_D_LB_cam: 0.204
# loss_D_GB: 0.647
# loss_D_GB_GAN: 0.331
# loss_D_GB_cam: 0.316
#
# [94270/300000]
# D_loss : 2.1733
# G_loss: 9.3688
# Time: 0.0:12.0:52
# loss_G_AB: 4.372
# loss_G_AB_GAN: 0.747
# loss_G_AB_identity: 0.151
# loss_G_AB_cycle: 0.118
# loss_G_AB_cam: 0.001
# loss_G_BA: 4.997
# loss_G_BA_GAN: 0.757
# loss_G_BA_identity: 0.111
# loss_G_BA_cycle: 0.193
# loss_G_BA_cam: 0.001
#
# loss_D_LA: 1.123
# loss_D_LA_GAN: 0.568
# loss_D_LA_cam: 0.555
# loss_D_GA: 0.909
# loss_D_GA_GAN: 0.523
# loss_D_GA_cam: 0.386
# loss_D_LB: 1.063
# loss_D_LB_GAN: 0.575
# loss_D_LB_cam: 0.488
# loss_D_GB: 1.252
# loss_D_GB_GAN: 0.603
# loss_D_GB_cam: 0.649
#
# [94280/300000]
# D_loss : 2.3555
# G_loss: 92.6332
# Time: 0.0:13.0:9
# loss_G_AB: 58.997
# loss_G_AB_GAN: 0.652
# loss_G_AB_identity: 0.102
# loss_G_AB_cycle: 0.108
# loss_G_AB_cam: 0.056
# loss_G_BA: 33.637
# loss_G_BA_GAN: 1.065
# loss_G_BA_identity: 0.122
# loss_G_BA_cycle: 0.124
# loss_G_BA_cam: 0.030
#
# loss_D_LA: 0.790
# loss_D_LA_GAN: 0.406
# loss_D_LA_cam: 0.385
# loss_D_GA: 1.018
# loss_D_GA_GAN: 0.464
# loss_D_GA_cam: 0.554
# loss_D_LB: 0.818
# loss_D_LB_GAN: 0.475
# loss_D_LB_cam: 0.343
# loss_D_GB: 2.084
# loss_D_GB_GAN: 1.128
# loss_D_GB_cam: 0.957
#
# [94290/300000]
# D_loss : 1.5369
# G_loss: 10.4520
# Time: 0.0:13.0:25
# loss_G_AB: 5.480
# loss_G_AB_GAN: 1.118
# loss_G_AB_identity: 0.140
# loss_G_AB_cycle: 0.151
# loss_G_AB_cam: 0.001
# loss_G_BA: 4.972
# loss_G_BA_GAN: 1.496
# loss_G_BA_identity: 0.125
# loss_G_BA_cycle: 0.158
# loss_G_BA_cam: 0.001
#
# loss_D_LA: 0.580
# loss_D_LA_GAN: 0.256
# loss_D_LA_cam: 0.324
# loss_D_GA: 0.777
# loss_D_GA_GAN: 0.413
# loss_D_GA_cam: 0.364
# loss_D_LB: 0.749
# loss_D_LB_GAN: 0.410
# loss_D_LB_cam: 0.339
# loss_D_GB: 0.968
# loss_D_GB_GAN: 0.478
# loss_D_GB_cam: 0.490
#
# [94300/300000]
# D_loss : 1.3146
# G_loss: 18.4024
# Time: 0.0:13.0:42
# loss_G_AB: 4.195
# loss_G_AB_GAN: 1.128
# loss_G_AB_identity: 0.063
# loss_G_AB_cycle: 0.107
# loss_G_AB_cam: 0.001
# loss_G_BA: 14.207
# loss_G_BA_GAN: 0.890
# loss_G_BA_identity: 0.116
# loss_G_BA_cycle: 0.150
# loss_G_BA_cam: 0.011
#
# loss_D_LA: 0.842
# loss_D_LA_GAN: 0.496
# loss_D_LA_cam: 0.346
# loss_D_GA: 0.416
# loss_D_GA_GAN: 0.249
# loss_D_GA_cam: 0.167
# loss_D_LB: 0.560
# loss_D_LB_GAN: 0.331
# loss_D_LB_cam: 0.229
# loss_D_GB: 0.811
# loss_D_GB_GAN: 0.377
# loss_D_GB_cam: 0.433
#
# [94310/300000]
# D_loss : 1.2027
# G_loss: 30.8589
# Time: 0.0:13.0:59
# loss_G_AB: 18.810
# loss_G_AB_GAN: 0.884
# loss_G_AB_identity: 0.110
# loss_G_AB_cycle: 0.122
# loss_G_AB_cam: 0.016
# loss_G_BA: 12.049
# loss_G_BA_GAN: 0.959
# loss_G_BA_identity: 0.093
# loss_G_BA_cycle: 0.133
# loss_G_BA_cam: 0.009
#
# loss_D_LA: 0.565
# loss_D_LA_GAN: 0.316
# loss_D_LA_cam: 0.249
# loss_D_GA: 0.736
# loss_D_GA_GAN: 0.424
# loss_D_GA_cam: 0.312
# loss_D_LB: 0.586
# loss_D_LB_GAN: 0.352
# loss_D_LB_cam: 0.234
# loss_D_GB: 0.519
# loss_D_GB_GAN: 0.280
# loss_D_GB_cam: 0.239
#
# [94320/300000]
# D_loss : 1.2523
# G_loss: 344.4796
# Time: 0.0:14.0:15
# loss_G_AB: 300.084
# loss_G_AB_GAN: 1.539
# loss_G_AB_identity: 0.125
# loss_G_AB_cycle: 0.219
# loss_G_AB_cam: 0.295
# loss_G_BA: 44.396
# loss_G_BA_GAN: 1.273
# loss_G_BA_identity: 0.087
# loss_G_BA_cycle: 0.097
# loss_G_BA_cam: 0.041
#
# loss_D_LA: 0.521
# loss_D_LA_GAN: 0.355
# loss_D_LA_cam: 0.166
# loss_D_GA: 0.684
# loss_D_GA_GAN: 0.430
# loss_D_GA_cam: 0.254
# loss_D_LB: 0.669
# loss_D_LB_GAN: 0.349
# loss_D_LB_cam: 0.321
# loss_D_GB: 0.630
# loss_D_GB_GAN: 0.377
# loss_D_GB_cam: 0.253
#
# [94330/300000]
# D_loss : 1.5259
# G_loss: 13.1139
# Time: 0.0:14.0:32
# loss_G_AB: 6.506
# loss_G_AB_GAN: 0.516
# loss_G_AB_identity: 0.080
# loss_G_AB_cycle: 0.083
# loss_G_AB_cam: 0.004
# loss_G_BA: 6.608
# loss_G_BA_GAN: 1.278
# loss_G_BA_identity: 0.138
# loss_G_BA_cycle: 0.171
# loss_G_BA_cam: 0.002
#
# loss_D_LA: 0.650
# loss_D_LA_GAN: 0.395
# loss_D_LA_cam: 0.255
# loss_D_GA: 0.581
# loss_D_GA_GAN: 0.305
# loss_D_GA_cam: 0.277
# loss_D_LB: 1.104
# loss_D_LB_GAN: 0.572
# loss_D_LB_cam: 0.532
# loss_D_GB: 0.717
# loss_D_GB_GAN: 0.388
# loss_D_GB_cam: 0.329
#
# [94340/300000]
# D_loss : 0.9224
# G_loss: 24.6866
# Time: 0.0:14.0:49
# loss_G_AB: 12.671
# loss_G_AB_GAN: 1.035
# loss_G_AB_identity: 0.079
# loss_G_AB_cycle: 0.090
# loss_G_AB_cam: 0.010
# loss_G_BA: 12.016
# loss_G_BA_GAN: 1.365
# loss_G_BA_identity: 0.118
# loss_G_BA_cycle: 0.132
# loss_G_BA_cam: 0.008
#
# loss_D_LA: 0.373
# loss_D_LA_GAN: 0.250
# loss_D_LA_cam: 0.123
# loss_D_GA: 0.323
# loss_D_GA_GAN: 0.209
# loss_D_GA_cam: 0.114
# loss_D_LB: 0.608
# loss_D_LB_GAN: 0.365
# loss_D_LB_cam: 0.243
# loss_D_GB: 0.540
# loss_D_GB_GAN: 0.257
# loss_D_GB_cam: 0.283
#
# [94350/300000]
# D_loss : 1.5693
# G_loss: 30.2024
# Time: 0.0:15.0:6
# loss_G_AB: 12.453
# loss_G_AB_GAN: 0.702
# loss_G_AB_identity: 0.090
# loss_G_AB_cycle: 0.115
# loss_G_AB_cam: 0.010
# loss_G_BA: 17.749
# loss_G_BA_GAN: 0.813
# loss_G_BA_identity: 0.087
# loss_G_BA_cycle: 0.079
# loss_G_BA_cam: 0.015
#
# loss_D_LA: 0.639
# loss_D_LA_GAN: 0.389
# loss_D_LA_cam: 0.251
# loss_D_GA: 0.739
# loss_D_GA_GAN: 0.390
# loss_D_GA_cam: 0.348
# loss_D_LB: 0.702
# loss_D_LB_GAN: 0.412
# loss_D_LB_cam: 0.290
# loss_D_GB: 1.059
# loss_D_GB_GAN: 0.543
# loss_D_GB_cam: 0.516
#
# [94360/300000]
# D_loss : 1.5971
# G_loss: 76.1726
# Time: 0.0:15.0:23
# loss_G_AB: 53.069
# loss_G_AB_GAN: 0.446
# loss_G_AB_identity: 0.148
# loss_G_AB_cycle: 0.196
# loss_G_AB_cam: 0.049
# loss_G_BA: 23.103
# loss_G_BA_GAN: 0.839
# loss_G_BA_identity: 0.119
# loss_G_BA_cycle: 0.146
# loss_G_BA_cam: 0.020
#
# loss_D_LA: 0.699
# loss_D_LA_GAN: 0.403
# loss_D_LA_cam: 0.296
# loss_D_GA: 0.790
# loss_D_GA_GAN: 0.422
# loss_D_GA_cam: 0.368
# loss_D_LB: 0.887
# loss_D_LB_GAN: 0.528
# loss_D_LB_cam: 0.358
# loss_D_GB: 0.819
# loss_D_GB_GAN: 0.446
# loss_D_GB_cam: 0.373
#
# [94370/300000]
# D_loss : 1.5090
# G_loss: 9.1934
# Time: 0.0:15.0:40
# loss_G_AB: 4.367
# loss_G_AB_GAN: 0.818
# loss_G_AB_identity: 0.097
# loss_G_AB_cycle: 0.179
# loss_G_AB_cam: 0.001
# loss_G_BA: 4.827
# loss_G_BA_GAN: 1.451
# loss_G_BA_identity: 0.095
# loss_G_BA_cycle: 0.135
# loss_G_BA_cam: 0.001
#
# loss_D_LA: 0.535
# loss_D_LA_GAN: 0.336
# loss_D_LA_cam: 0.199
# loss_D_GA: 0.874
# loss_D_GA_GAN: 0.455
# loss_D_GA_cam: 0.419
# loss_D_LB: 0.823
# loss_D_LB_GAN: 0.439
# loss_D_LB_cam: 0.385
# loss_D_GB: 0.785
# loss_D_GB_GAN: 0.358
# loss_D_GB_cam: 0.427
#
# [94380/300000]
# D_loss : 0.9490
# G_loss: 10.9610
# Time: 0.0:15.0:56
# loss_G_AB: 5.308
# loss_G_AB_GAN: 1.488
# loss_G_AB_identity: 0.086
# loss_G_AB_cycle: 0.141
# loss_G_AB_cam: 0.002
# loss_G_BA: 5.653
# loss_G_BA_GAN: 1.084
# loss_G_BA_identity: 0.110
# loss_G_BA_cycle: 0.139
# loss_G_BA_cam: 0.002
#
# loss_D_LA: 0.496
# loss_D_LA_GAN: 0.336
# loss_D_LA_cam: 0.161
# loss_D_GA: 0.484
# loss_D_GA_GAN: 0.329
# loss_D_GA_cam: 0.155
# loss_D_LB: 0.365
# loss_D_LB_GAN: 0.229
# loss_D_LB_cam: 0.136
# loss_D_GB: 0.552
# loss_D_GB_GAN: 0.324
# loss_D_GB_cam: 0.228
#
# [94390/300000]
# D_loss : 1.2065
# G_loss: 794.9116
# Time: 0.0:16.0:13
# loss_G_AB: 316.158
# loss_G_AB_GAN: 1.181
# loss_G_AB_identity: 0.143
# loss_G_AB_cycle: 0.157
# loss_G_AB_cam: 0.312
# loss_G_BA: 478.753
# loss_G_BA_GAN: 1.717
# loss_G_BA_identity: 0.202
# loss_G_BA_cycle: 0.214
# loss_G_BA_cam: 0.473
#
# loss_D_LA: 0.472
# loss_D_LA_GAN: 0.252
# loss_D_LA_cam: 0.221
# loss_D_GA: 0.680
# loss_D_GA_GAN: 0.309
# loss_D_GA_cam: 0.371
# loss_D_LB: 0.569
# loss_D_LB_GAN: 0.361
# loss_D_LB_cam: 0.208
# loss_D_GB: 0.692
# loss_D_GB_GAN: 0.399
# loss_D_GB_cam: 0.292
#
# [94400/300000]
# D_loss : 1.4404
# G_loss: 10.9857
# Time: 0.0:16.0:30
# loss_G_AB: 6.058
# loss_G_AB_GAN: 1.047
# loss_G_AB_identity: 0.189
# loss_G_AB_cycle: 0.234
# loss_G_AB_cam: 0.001
# loss_G_BA: 4.928
# loss_G_BA_GAN: 0.765
# loss_G_BA_identity: 0.119
# loss_G_BA_cycle: 0.135
# loss_G_BA_cam: 0.002
#
# loss_D_LA: 0.584
# loss_D_LA_GAN: 0.344
# loss_D_LA_cam: 0.239
# loss_D_GA: 0.787
# loss_D_GA_GAN: 0.326
# loss_D_GA_cam: 0.461
# loss_D_LB: 0.945
# loss_D_LB_GAN: 0.514
# loss_D_LB_cam: 0.431
# loss_D_GB: 0.565
# loss_D_GB_GAN: 0.317
# loss_D_GB_cam: 0.248
#
# [94410/300000]
# D_loss : 1.0042
# G_loss: 50.7016
# Time: 0.0:16.0:47
# loss_G_AB: 42.048
# loss_G_AB_GAN: 1.031
# loss_G_AB_identity: 0.097
# loss_G_AB_cycle: 0.111
# loss_G_AB_cam: 0.039
# loss_G_BA: 8.653
# loss_G_BA_GAN: 1.139
# loss_G_BA_identity: 0.086
# loss_G_BA_cycle: 0.098
# loss_G_BA_cam: 0.006
#
# loss_D_LA: 0.465
# loss_D_LA_GAN: 0.334
# loss_D_LA_cam: 0.131
# loss_D_GA: 0.555
# loss_D_GA_GAN: 0.302
# loss_D_GA_cam: 0.254
# loss_D_LB: 0.545
# loss_D_LB_GAN: 0.338
# loss_D_LB_cam: 0.207
# loss_D_GB: 0.443
# loss_D_GB_GAN: 0.225
# loss_D_GB_cam: 0.218
#
# [94420/300000]
# D_loss : 0.9315
# G_loss: 16.1004
# Time: 0.0:17.0:3
# loss_G_AB: 7.683
# loss_G_AB_GAN: 0.939
# loss_G_AB_identity: 0.145
# loss_G_AB_cycle: 0.147
# loss_G_AB_cam: 0.004
# loss_G_BA: 8.417
# loss_G_BA_GAN: 0.904
# loss_G_BA_identity: 0.124
# loss_G_BA_cycle: 0.142
# loss_G_BA_cam: 0.005
#
# loss_D_LA: 0.181
# loss_D_LA_GAN: 0.138
# loss_D_LA_cam: 0.043
# loss_D_GA: 0.353
# loss_D_GA_GAN: 0.178
# loss_D_GA_cam: 0.175
# loss_D_LB: 0.500
# loss_D_LB_GAN: 0.298
# loss_D_LB_cam: 0.202
# loss_D_GB: 0.830
# loss_D_GB_GAN: 0.407
# loss_D_GB_cam: 0.423
#
# [94430/300000]
# D_loss : 1.0547
# G_loss: 115.0208
# Time: 0.0:17.0:21
# loss_G_AB: 72.093
# loss_G_AB_GAN: 1.148
# loss_G_AB_identity: 0.094
# loss_G_AB_cycle: 0.116
# loss_G_AB_cam: 0.069
# loss_G_BA: 42.928
# loss_G_BA_GAN: 1.792
# loss_G_BA_identity: 0.164
# loss_G_BA_cycle: 0.146
# loss_G_BA_cam: 0.038
#
# loss_D_LA: 0.210
# loss_D_LA_GAN: 0.154
# loss_D_LA_cam: 0.056
# loss_D_GA: 0.683
# loss_D_GA_GAN: 0.388
# loss_D_GA_cam: 0.295
# loss_D_LB: 0.460
# loss_D_LB_GAN: 0.298
# loss_D_LB_cam: 0.162
# loss_D_GB: 0.756
# loss_D_GB_GAN: 0.368
# loss_D_GB_cam: 0.388
#
# [94440/300000]
# D_loss : 1.2413
# G_loss: 74.9168
# Time: 0.0:17.0:37
# loss_G_AB: 20.859
# loss_G_AB_GAN: 0.865
# loss_G_AB_identity: 0.118
# loss_G_AB_cycle: 0.140
# loss_G_AB_cam: 0.017
# loss_G_BA: 54.058
# loss_G_BA_GAN: 1.218
# loss_G_BA_identity: 0.076
# loss_G_BA_cycle: 0.088
# loss_G_BA_cam: 0.051
#
# loss_D_LA: 0.468
# loss_D_LA_GAN: 0.294
# loss_D_LA_cam: 0.174
# loss_D_GA: 0.625
# loss_D_GA_GAN: 0.308
# loss_D_GA_cam: 0.317
# loss_D_LB: 0.579
# loss_D_LB_GAN: 0.318
# loss_D_LB_cam: 0.261
# loss_D_GB: 0.810
# loss_D_GB_GAN: 0.443
# loss_D_GB_cam: 0.368
#
# [94450/300000]
# D_loss : 1.2447
# G_loss: 11.7454
# Time: 0.0:17.0:54
# loss_G_AB: 6.715
# loss_G_AB_GAN: 0.995
# loss_G_AB_identity: 0.206
# loss_G_AB_cycle: 0.250
# loss_G_AB_cam: 0.001
# loss_G_BA: 5.030
# loss_G_BA_GAN: 1.512
# loss_G_BA_identity: 0.133
# loss_G_BA_cycle: 0.132
# loss_G_BA_cam: 0.001
#
# loss_D_LA: 0.415
# loss_D_LA_GAN: 0.279
# loss_D_LA_cam: 0.136
# loss_D_GA: 1.208
# loss_D_GA_GAN: 0.534
# loss_D_GA_cam: 0.675
# loss_D_LB: 0.301
# loss_D_LB_GAN: 0.190
# loss_D_LB_cam: 0.112
# loss_D_GB: 0.565
# loss_D_GB_GAN: 0.284
# loss_D_GB_cam: 0.281
#
# [94460/300000]
# D_loss : 1.1655
# G_loss: 12.2342
# Time: 0.0:18.0:11
# loss_G_AB: 6.251
# loss_G_AB_GAN: 1.626
# loss_G_AB_identity: 0.083
# loss_G_AB_cycle: 0.088
# loss_G_AB_cam: 0.003
# loss_G_BA: 5.983
# loss_G_BA_GAN: 1.072
# loss_G_BA_identity: 0.113
# loss_G_BA_cycle: 0.151
# loss_G_BA_cam: 0.002
#
# loss_D_LA: 0.611
# loss_D_LA_GAN: 0.378
# loss_D_LA_cam: 0.233
# loss_D_GA: 0.632
# loss_D_GA_GAN: 0.324
# loss_D_GA_cam: 0.308
# loss_D_LB: 0.836
# loss_D_LB_GAN: 0.433
# loss_D_LB_cam: 0.404
# loss_D_GB: 0.251
# loss_D_GB_GAN: 0.157
# loss_D_GB_cam: 0.094
#
# [94470/300000]
# D_loss : 1.3954
# G_loss: 17.9193
# Time: 0.0:18.0:27
# loss_G_AB: 13.160
# loss_G_AB_GAN: 1.500
# loss_G_AB_identity: 0.109
# loss_G_AB_cycle: 0.130
# loss_G_AB_cam: 0.009
# loss_G_BA: 4.759
# loss_G_BA_GAN: 0.591
# loss_G_BA_identity: 0.098
# loss_G_BA_cycle: 0.112
# loss_G_BA_cam: 0.002
#
# loss_D_LA: 0.955
# loss_D_LA_GAN: 0.590
# loss_D_LA_cam: 0.365
# loss_D_GA: 0.948
# loss_D_GA_GAN: 0.567
# loss_D_GA_cam: 0.381
# loss_D_LB: 0.463
# loss_D_LB_GAN: 0.324
# loss_D_LB_cam: 0.139
# loss_D_GB: 0.425
# loss_D_GB_GAN: 0.241
# loss_D_GB_cam: 0.184
#
# [94480/300000]
# D_loss : 0.9335
# G_loss: 29.1161
# Time: 0.0:18.0:44
# loss_G_AB: 13.829
# loss_G_AB_GAN: 0.688
# loss_G_AB_identity: 0.132
# loss_G_AB_cycle: 0.160
# loss_G_AB_cam: 0.010
# loss_G_BA: 15.287
# loss_G_BA_GAN: 1.469
# loss_G_BA_identity: 0.101
# loss_G_BA_cycle: 0.128
# loss_G_BA_cam: 0.012
#
# loss_D_LA: 0.676
# loss_D_LA_GAN: 0.356
# loss_D_LA_cam: 0.319
# loss_D_GA: 0.568
# loss_D_GA_GAN: 0.315
# loss_D_GA_cam: 0.253
# loss_D_LB: 0.367
# loss_D_LB_GAN: 0.248
# loss_D_LB_cam: 0.119
# loss_D_GB: 0.256
# loss_D_GB_GAN: 0.127
# loss_D_GB_cam: 0.129
#
# [94490/300000]
# D_loss : 1.7056
# G_loss: 684.7913
# Time: 0.0:19.0:1
# loss_G_AB: 561.863
# loss_G_AB_GAN: 0.808
# loss_G_AB_identity: 0.081
# loss_G_AB_cycle: 0.084
# loss_G_AB_cam: 0.559
# loss_G_BA: 122.929
# loss_G_BA_GAN: 1.216
# loss_G_BA_identity: 0.133
# loss_G_BA_cycle: 0.146
# loss_G_BA_cam: 0.119
#
# loss_D_LA: 0.814
# loss_D_LA_GAN: 0.493
# loss_D_LA_cam: 0.321
# loss_D_GA: 0.688
# loss_D_GA_GAN: 0.417
# loss_D_GA_cam: 0.271
# loss_D_LB: 0.829
# loss_D_LB_GAN: 0.478
# loss_D_LB_cam: 0.351
# loss_D_GB: 1.081
# loss_D_GB_GAN: 0.466
# loss_D_GB_cam: 0.615
#
# [94500/300000]
# D_loss : 1.2590
# G_loss: 17.7107
# Time: 0.0:19.0:17
# loss_G_AB: 9.485
# loss_G_AB_GAN: 1.349
# loss_G_AB_identity: 0.068
# loss_G_AB_cycle: 0.083
# loss_G_AB_cam: 0.007
# loss_G_BA: 8.226
# loss_G_BA_GAN: 0.536
# loss_G_BA_identity: 0.079
# loss_G_BA_cycle: 0.097
# loss_G_BA_cam: 0.006
#
# loss_D_LA: 0.400
# loss_D_LA_GAN: 0.240
# loss_D_LA_cam: 0.160
# loss_D_GA: 0.575
# loss_D_GA_GAN: 0.290
# loss_D_GA_cam: 0.285
# loss_D_LB: 0.670
# loss_D_LB_GAN: 0.416
# loss_D_LB_cam: 0.254
# loss_D_GB: 0.873
# loss_D_GB_GAN: 0.455
# loss_D_GB_cam: 0.418
#
# [94510/300000]
# D_loss : 1.2961
# G_loss: 16.8733
# Time: 0.0:19.0:38
# loss_G_AB: 6.139
# loss_G_AB_GAN: 1.094
# loss_G_AB_identity: 0.074
# loss_G_AB_cycle: 0.091
# loss_G_AB_cam: 0.003
# loss_G_BA: 10.735
# loss_G_BA_GAN: 1.318
# loss_G_BA_identity: 0.081
# loss_G_BA_cycle: 0.100
# loss_G_BA_cam: 0.008
#
# loss_D_LA: 0.509
# loss_D_LA_GAN: 0.319
# loss_D_LA_cam: 0.190
# loss_D_GA: 0.872
# loss_D_GA_GAN: 0.428
# loss_D_GA_cam: 0.444
# loss_D_LB: 0.644
# loss_D_LB_GAN: 0.380
# loss_D_LB_cam: 0.264
# loss_D_GB: 0.567
# loss_D_GB_GAN: 0.290
# loss_D_GB_cam: 0.276
#
# [94520/300000]
# D_loss : 1.3848
# G_loss: 29.4706
# Time: 0.0:19.0:54
# loss_G_AB: 5.568
# loss_G_AB_GAN: 0.976
# loss_G_AB_identity: 0.118
# loss_G_AB_cycle: 0.144
# loss_G_AB_cam: 0.002
# loss_G_BA: 23.903
# loss_G_BA_GAN: 1.242
# loss_G_BA_identity: 0.082
# loss_G_BA_cycle: 0.128
# loss_G_BA_cam: 0.021
#
# loss_D_LA: 0.465
# loss_D_LA_GAN: 0.307
# loss_D_LA_cam: 0.158
# loss_D_GA: 0.645
# loss_D_GA_GAN: 0.386
# loss_D_GA_cam: 0.259
# loss_D_LB: 0.831
# loss_D_LB_GAN: 0.437
# loss_D_LB_cam: 0.394
# loss_D_GB: 0.828
# loss_D_GB_GAN: 0.443
# loss_D_GB_cam: 0.385
#
# [94530/300000]
# D_loss : 1.0875
# G_loss: 131.4834
# Time: 0.0:20.0:11
# loss_G_AB: 24.029
# loss_G_AB_GAN: 1.305
# loss_G_AB_identity: 0.087
# loss_G_AB_cycle: 0.116
# loss_G_AB_cam: 0.021
# loss_G_BA: 107.454
# loss_G_BA_GAN: 1.382
# loss_G_BA_identity: 0.122
# loss_G_BA_cycle: 0.142
# loss_G_BA_cam: 0.103
#
# loss_D_LA: 0.278
# loss_D_LA_GAN: 0.154
# loss_D_LA_cam: 0.123
# loss_D_GA: 0.874
# loss_D_GA_GAN: 0.400
# loss_D_GA_cam: 0.474
# loss_D_LB: 0.324
# loss_D_LB_GAN: 0.215
# loss_D_LB_cam: 0.110
# loss_D_GB: 0.699
# loss_D_GB_GAN: 0.402
# loss_D_GB_cam: 0.297
#
# [94540/300000]
# D_loss : 1.6553
# G_loss: 12.6335
# Time: 0.0:20.0:27
# loss_G_AB: 8.425
# loss_G_AB_GAN: 0.869
# loss_G_AB_identity: 0.243
# loss_G_AB_cycle: 0.313
# loss_G_AB_cam: 0.002
# loss_G_BA: 4.209
# loss_G_BA_GAN: 1.277
# loss_G_BA_identity: 0.070
# loss_G_BA_cycle: 0.075
# loss_G_BA_cam: 0.001
#
# loss_D_LA: 0.947
# loss_D_LA_GAN: 0.510
# loss_D_LA_cam: 0.436
# loss_D_GA: 0.911
# loss_D_GA_GAN: 0.516
# loss_D_GA_cam: 0.395
# loss_D_LB: 0.725
# loss_D_LB_GAN: 0.464
# loss_D_LB_cam: 0.262
# loss_D_GB: 0.727
# loss_D_GB_GAN: 0.404
# loss_D_GB_cam: 0.323
#
# [94550/300000]
# D_loss : 1.0667
# G_loss: 8.0734
# Time: 0.0:20.0:44
# loss_G_AB: 3.295
# loss_G_AB_GAN: 1.052
# loss_G_AB_identity: 0.089
# loss_G_AB_cycle: 0.095
# loss_G_AB_cam: 0.000
# loss_G_BA: 4.779
# loss_G_BA_GAN: 1.317
# loss_G_BA_identity: 0.093
# loss_G_BA_cycle: 0.124
# loss_G_BA_cam: 0.001
#
# loss_D_LA: 0.525
# loss_D_LA_GAN: 0.333
# loss_D_LA_cam: 0.192
# loss_D_GA: 0.437
# loss_D_GA_GAN: 0.252
# loss_D_GA_cam: 0.185
# loss_D_LB: 0.812
# loss_D_LB_GAN: 0.432
# loss_D_LB_cam: 0.379
# loss_D_GB: 0.359
# loss_D_GB_GAN: 0.221
# loss_D_GB_cam: 0.138
#
# [94560/300000]
# D_loss : 1.2774
# G_loss: 120.6924
# Time: 0.0:21.0:0
# loss_G_AB: 21.792
# loss_G_AB_GAN: 1.386
# loss_G_AB_identity: 0.165
# loss_G_AB_cycle: 0.182
# loss_G_AB_cam: 0.017
# loss_G_BA: 98.901
# loss_G_BA_GAN: 0.936
# loss_G_BA_identity: 0.113
# loss_G_BA_cycle: 0.108
# loss_G_BA_cam: 0.096
#
# loss_D_LA: 0.511
# loss_D_LA_GAN: 0.315
# loss_D_LA_cam: 0.195
# loss_D_GA: 0.846
# loss_D_GA_GAN: 0.429
# loss_D_GA_cam: 0.417
# loss_D_LB: 0.602
# loss_D_LB_GAN: 0.329
# loss_D_LB_cam: 0.273
# loss_D_GB: 0.597
# loss_D_GB_GAN: 0.408
# loss_D_GB_cam: 0.189
#
# [94570/300000]
# D_loss : 1.2087
# G_loss: 8.5145
# Time: 0.0:21.0:17
# loss_G_AB: 3.879
# loss_G_AB_GAN: 1.061
# loss_G_AB_identity: 0.078
# loss_G_AB_cycle: 0.096
# loss_G_AB_cam: 0.001
# loss_G_BA: 4.635
# loss_G_BA_GAN: 1.010
# loss_G_BA_identity: 0.100
# loss_G_BA_cycle: 0.167
# loss_G_BA_cam: 0.001
#
# loss_D_LA: 1.020
# loss_D_LA_GAN: 0.614
# loss_D_LA_cam: 0.406
# loss_D_GA: 0.327
# loss_D_GA_GAN: 0.219
# loss_D_GA_cam: 0.107
# loss_D_LB: 0.476
# loss_D_LB_GAN: 0.293
# loss_D_LB_cam: 0.183
# loss_D_GB: 0.595
# loss_D_GB_GAN: 0.323
# loss_D_GB_cam: 0.272
#
# [94580/300000]
# D_loss : 1.8578
# G_loss: 25.1908
# Time: 0.0:21.0:33
# loss_G_AB: 8.499
# loss_G_AB_GAN: 0.622
# loss_G_AB_identity: 0.127
# loss_G_AB_cycle: 0.143
# loss_G_AB_cam: 0.005
# loss_G_BA: 16.692
# loss_G_BA_GAN: 1.510
# loss_G_BA_identity: 0.082
# loss_G_BA_cycle: 0.098
# loss_G_BA_cam: 0.013
#
# loss_D_LA: 0.760
# loss_D_LA_GAN: 0.460
# loss_D_LA_cam: 0.300
# loss_D_GA: 1.063
# loss_D_GA_GAN: 0.637
# loss_D_GA_cam: 0.426
# loss_D_LB: 0.752
# loss_D_LB_GAN: 0.418
# loss_D_LB_cam: 0.334
# loss_D_GB: 1.140
# loss_D_GB_GAN: 0.577
# loss_D_GB_cam: 0.563
#
# [94590/300000]
# D_loss : 0.8423
# G_loss: 31.1355
# Time: 0.0:21.0:50
# loss_G_AB: 23.208
# loss_G_AB_GAN: 1.321
# loss_G_AB_identity: 0.087
# loss_G_AB_cycle: 0.111
# loss_G_AB_cam: 0.020
# loss_G_BA: 7.928
# loss_G_BA_GAN: 1.230
# loss_G_BA_identity: 0.144
# loss_G_BA_cycle: 0.147
# loss_G_BA_cam: 0.004
#
# loss_D_LA: 0.307
# loss_D_LA_GAN: 0.204
# loss_D_LA_cam: 0.103
# loss_D_GA: 0.335
# loss_D_GA_GAN: 0.167
# loss_D_GA_cam: 0.168
# loss_D_LB: 0.608
# loss_D_LB_GAN: 0.387
# loss_D_LB_cam: 0.221
# loss_D_GB: 0.435
# loss_D_GB_GAN: 0.304
# loss_D_GB_cam: 0.131
#
# [94600/300000]
# D_loss : 1.9544
# G_loss: 9.9094
# Time: 0.0:22.0:7
# loss_G_AB: 4.103
# loss_G_AB_GAN: 0.620
# loss_G_AB_identity: 0.125
# loss_G_AB_cycle: 0.126
# loss_G_AB_cam: 0.001
# loss_G_BA: 5.807
# loss_G_BA_GAN: 0.703
# loss_G_BA_identity: 0.081
# loss_G_BA_cycle: 0.102
# loss_G_BA_cam: 0.003
#
# loss_D_LA: 1.212
# loss_D_LA_GAN: 0.662
# loss_D_LA_cam: 0.550
# loss_D_GA: 0.716
# loss_D_GA_GAN: 0.413
# loss_D_GA_cam: 0.303
# loss_D_LB: 1.146
# loss_D_LB_GAN: 0.529
# loss_D_LB_cam: 0.617
# loss_D_GB: 0.835
# loss_D_GB_GAN: 0.463
# loss_D_GB_cam: 0.372
#
# [94610/300000]
# D_loss : 0.9109
# G_loss: 9.4650
# Time: 0.0:22.0:23
# loss_G_AB: 3.456
# loss_G_AB_GAN: 0.569
# loss_G_AB_identity: 0.065
# loss_G_AB_cycle: 0.081
# loss_G_AB_cam: 0.001
# loss_G_BA: 6.009
# loss_G_BA_GAN: 1.290
# loss_G_BA_identity: 0.110
# loss_G_BA_cycle: 0.185
# loss_G_BA_cam: 0.002
#
# loss_D_LA: 0.486
# loss_D_LA_GAN: 0.341
# loss_D_LA_cam: 0.145
# loss_D_GA: 0.470
# loss_D_GA_GAN: 0.292
# loss_D_GA_cam: 0.179
# loss_D_LB: 0.555
# loss_D_LB_GAN: 0.379
# loss_D_LB_cam: 0.175
# loss_D_GB: 0.311
# loss_D_GB_GAN: 0.200
# loss_D_GB_cam: 0.110
#
# [94620/300000]
# D_loss : 1.4444
# G_loss: 25.1031
# Time: 0.0:22.0:40
# loss_G_AB: 18.001
# loss_G_AB_GAN: 1.466
# loss_G_AB_identity: 0.125
# loss_G_AB_cycle: 0.160
# loss_G_AB_cam: 0.014
# loss_G_BA: 7.102
# loss_G_BA_GAN: 0.804
# loss_G_BA_identity: 0.117
# loss_G_BA_cycle: 0.167
# loss_G_BA_cam: 0.003
#
# loss_D_LA: 0.543
# loss_D_LA_GAN: 0.349
# loss_D_LA_cam: 0.194
# loss_D_GA: 0.459
# loss_D_GA_GAN: 0.288
# loss_D_GA_cam: 0.171
# loss_D_LB: 0.642
# loss_D_LB_GAN: 0.429
# loss_D_LB_cam: 0.213
# loss_D_GB: 1.244
# loss_D_GB_GAN: 0.453
# loss_D_GB_cam: 0.792
#
# [94630/300000]
# D_loss : 0.9299
# G_loss: 11.9085
# Time: 0.0:22.0:57
# loss_G_AB: 5.914
# loss_G_AB_GAN: 1.094
# loss_G_AB_identity: 0.181
# loss_G_AB_cycle: 0.238
# loss_G_AB_cam: 0.001
# loss_G_BA: 5.994
# loss_G_BA_GAN: 1.283
# loss_G_BA_identity: 0.139
# loss_G_BA_cycle: 0.168
# loss_G_BA_cam: 0.002
#
# loss_D_LA: 0.101
# loss_D_LA_GAN: 0.063
# loss_D_LA_cam: 0.038
# loss_D_GA: 0.651
# loss_D_GA_GAN: 0.282
# loss_D_GA_cam: 0.369
# loss_D_LB: 0.598
# loss_D_LB_GAN: 0.372
# loss_D_LB_cam: 0.226
# loss_D_GB: 0.510
# loss_D_GB_GAN: 0.333
# loss_D_GB_cam: 0.176
#
# [94640/300000]
# D_loss : 1.3217
# G_loss: 18.3287
# Time: 0.0:23.0:13
# loss_G_AB: 10.458
# loss_G_AB_GAN: 1.384
# loss_G_AB_identity: 0.202
# loss_G_AB_cycle: 0.230
# loss_G_AB_cam: 0.005
# loss_G_BA: 7.871
# loss_G_BA_GAN: 1.029
# loss_G_BA_identity: 0.132
# loss_G_BA_cycle: 0.149
# loss_G_BA_cam: 0.004
#
# loss_D_LA: 0.693
# loss_D_LA_GAN: 0.342
# loss_D_LA_cam: 0.351
# loss_D_GA: 0.754
# loss_D_GA_GAN: 0.399
# loss_D_GA_cam: 0.355
# loss_D_LB: 0.562
# loss_D_LB_GAN: 0.366
# loss_D_LB_cam: 0.196
# loss_D_GB: 0.634
# loss_D_GB_GAN: 0.312
# loss_D_GB_cam: 0.321
#
# [94650/300000]
# D_loss : 1.0293
# G_loss: 25.4157
# Time: 0.0:23.0:30
# loss_G_AB: 6.445
# loss_G_AB_GAN: 1.706
# loss_G_AB_identity: 0.078
# loss_G_AB_cycle: 0.093
# loss_G_AB_cam: 0.003
# loss_G_BA: 18.971
# loss_G_BA_GAN: 1.258
# loss_G_BA_identity: 0.202
# loss_G_BA_cycle: 0.191
# loss_G_BA_cam: 0.014
#
# loss_D_LA: 0.499
# loss_D_LA_GAN: 0.341
# loss_D_LA_cam: 0.159
# loss_D_GA: 0.558
# loss_D_GA_GAN: 0.318
# loss_D_GA_cam: 0.241
# loss_D_LB: 0.605
# loss_D_LB_GAN: 0.372
# loss_D_LB_cam: 0.233
# loss_D_GB: 0.396
# loss_D_GB_GAN: 0.252
# loss_D_GB_cam: 0.144
#
# [94660/300000]
# D_loss : 1.4953
# G_loss: 112.9044
# Time: 0.0:23.0:47
# loss_G_AB: 44.848
# loss_G_AB_GAN: 0.521
# loss_G_AB_identity: 0.091
# loss_G_AB_cycle: 0.082
# loss_G_AB_cam: 0.043
# loss_G_BA: 68.056
# loss_G_BA_GAN: 1.421
# loss_G_BA_identity: 0.145
# loss_G_BA_cycle: 0.171
# loss_G_BA_cam: 0.063
#
# loss_D_LA: 0.401
# loss_D_LA_GAN: 0.273
# loss_D_LA_cam: 0.128
# loss_D_GA: 0.911
# loss_D_GA_GAN: 0.434
# loss_D_GA_cam: 0.477
# loss_D_LB: 0.646
# loss_D_LB_GAN: 0.375
# loss_D_LB_cam: 0.271
# loss_D_GB: 1.033
# loss_D_GB_GAN: 0.534
# loss_D_GB_cam: 0.499
#
# [94670/300000]
# D_loss : 1.0468
# G_loss: 91.2293
# Time: 0.0:24.0:4
# loss_G_AB: 65.041
# loss_G_AB_GAN: 1.043
# loss_G_AB_identity: 0.124
# loss_G_AB_cycle: 0.116
# loss_G_AB_cam: 0.062
# loss_G_BA: 26.189
# loss_G_BA_GAN: 1.461
# loss_G_BA_identity: 0.089
# loss_G_BA_cycle: 0.129
# loss_G_BA_cam: 0.023
#
# loss_D_LA: 0.450
# loss_D_LA_GAN: 0.314
# loss_D_LA_cam: 0.136
# loss_D_GA: 0.203
# loss_D_GA_GAN: 0.165
# loss_D_GA_cam: 0.038
# loss_D_LB: 0.801
# loss_D_LB_GAN: 0.440
# loss_D_LB_cam: 0.361
# loss_D_GB: 0.640
# loss_D_GB_GAN: 0.385
# loss_D_GB_cam: 0.255
#
# [94680/300000]
# D_loss : 1.1459
# G_loss: 105.5040
# Time: 0.0:24.0:20
# loss_G_AB: 27.272
# loss_G_AB_GAN: 1.440
# loss_G_AB_identity: 0.110
# loss_G_AB_cycle: 0.180
# loss_G_AB_cam: 0.023
# loss_G_BA: 78.232
# loss_G_BA_GAN: 0.798
# loss_G_BA_identity: 0.110
# loss_G_BA_cycle: 0.132
# loss_G_BA_cam: 0.075
#
# loss_D_LA: 0.651
# loss_D_LA_GAN: 0.343
# loss_D_LA_cam: 0.308
# loss_D_GA: 0.494
# loss_D_GA_GAN: 0.285
# loss_D_GA_cam: 0.210
# loss_D_LB: 0.554
# loss_D_LB_GAN: 0.241
# loss_D_LB_cam: 0.313
# loss_D_GB: 0.592
# loss_D_GB_GAN: 0.304
# loss_D_GB_cam: 0.288
#
# [94690/300000]
# D_loss : 1.4083
# G_loss: 20.1335
# Time: 0.0:24.0:37
# loss_G_AB: 8.250
# loss_G_AB_GAN: 1.434
# loss_G_AB_identity: 0.135
# loss_G_AB_cycle: 0.208
# loss_G_AB_cam: 0.003
# loss_G_BA: 11.884
# loss_G_BA_GAN: 0.780
# loss_G_BA_identity: 0.062
# loss_G_BA_cycle: 0.073
# loss_G_BA_cam: 0.010
#
# loss_D_LA: 0.512
# loss_D_LA_GAN: 0.288
# loss_D_LA_cam: 0.225
# loss_D_GA: 0.727
# loss_D_GA_GAN: 0.403
# loss_D_GA_cam: 0.324
# loss_D_LB: 0.806
# loss_D_LB_GAN: 0.422
# loss_D_LB_cam: 0.384
# loss_D_GB: 0.772
# loss_D_GB_GAN: 0.423
# loss_D_GB_cam: 0.349
#
# [94700/300000]
# D_loss : 1.6100
# G_loss: 43.9054
# Time: 0.0:24.0:54
# loss_G_AB: 36.828
# loss_G_AB_GAN: 0.631
# loss_G_AB_identity: 0.145
# loss_G_AB_cycle: 0.161
# loss_G_AB_cam: 0.033
# loss_G_BA: 7.078
# loss_G_BA_GAN: 1.436
# loss_G_BA_identity: 0.081
# loss_G_BA_cycle: 0.152
# loss_G_BA_cam: 0.003
#
# loss_D_LA: 0.284
# loss_D_LA_GAN: 0.192
# loss_D_LA_cam: 0.092
# loss_D_GA: 0.930
# loss_D_GA_GAN: 0.473
# loss_D_GA_cam: 0.457
# loss_D_LB: 0.822
# loss_D_LB_GAN: 0.480
# loss_D_LB_cam: 0.342
# loss_D_GB: 1.183
# loss_D_GB_GAN: 0.623
# loss_D_GB_cam: 0.560
#
# [94710/300000]
# D_loss : 1.2238
# G_loss: 67.8507
# Time: 0.0:25.0:11
# loss_G_AB: 54.530
# loss_G_AB_GAN: 1.009
# loss_G_AB_identity: 0.181
# loss_G_AB_cycle: 0.236
# loss_G_AB_cam: 0.049
# loss_G_BA: 13.321
# loss_G_BA_GAN: 1.406
# loss_G_BA_identity: 0.202
# loss_G_BA_cycle: 0.208
# loss_G_BA_cam: 0.008
#
# loss_D_LA: 0.593
# loss_D_LA_GAN: 0.332
# loss_D_LA_cam: 0.261
# loss_D_GA: 0.565
# loss_D_GA_GAN: 0.299
# loss_D_GA_cam: 0.266
# loss_D_LB: 0.614
# loss_D_LB_GAN: 0.361
# loss_D_LB_cam: 0.253
# loss_D_GB: 0.675
# loss_D_GB_GAN: 0.362
# loss_D_GB_cam: 0.313
#
# [94720/300000]
# D_loss : 1.1686
# G_loss: 9.6467
# Time: 0.0:25.0:27
# loss_G_AB: 4.200
# loss_G_AB_GAN: 0.668
# loss_G_AB_identity: 0.074
# loss_G_AB_cycle: 0.097
# loss_G_AB_cam: 0.002
# loss_G_BA: 5.447
# loss_G_BA_GAN: 0.889
# loss_G_BA_identity: 0.114
# loss_G_BA_cycle: 0.209
# loss_G_BA_cam: 0.001
#
# loss_D_LA: 0.607
# loss_D_LA_GAN: 0.378
# loss_D_LA_cam: 0.230
# loss_D_GA: 0.660
# loss_D_GA_GAN: 0.348
# loss_D_GA_cam: 0.312
# loss_D_LB: 0.551
# loss_D_LB_GAN: 0.316
# loss_D_LB_cam: 0.236
# loss_D_GB: 0.519
# loss_D_GB_GAN: 0.268
# loss_D_GB_cam: 0.250
#
# [94730/300000]
# D_loss : 1.1611
# G_loss: 10.2273
# Time: 0.0:25.0:44
# loss_G_AB: 6.531
# loss_G_AB_GAN: 1.509
# loss_G_AB_identity: 0.099
# loss_G_AB_cycle: 0.133
# loss_G_AB_cam: 0.003
# loss_G_BA: 3.696
# loss_G_BA_GAN: 0.922
# loss_G_BA_identity: 0.088
# loss_G_BA_cycle: 0.114
# loss_G_BA_cam: 0.001
#
# loss_D_LA: 0.520
# loss_D_LA_GAN: 0.336
# loss_D_LA_cam: 0.183
# loss_D_GA: 0.969
# loss_D_GA_GAN: 0.452
# loss_D_GA_cam: 0.517
# loss_D_LB: 0.366
# loss_D_LB_GAN: 0.211
# loss_D_LB_cam: 0.155
# loss_D_GB: 0.468
# loss_D_GB_GAN: 0.230
# loss_D_GB_cam: 0.238
#
# [94740/300000]
# D_loss : 1.5820
# G_loss: 3354.9536
# Time: 0.0:26.0:1
# loss_G_AB: 2859.746
# loss_G_AB_GAN: 0.747
# loss_G_AB_identity: 0.193
# loss_G_AB_cycle: 0.184
# loss_G_AB_cam: 2.855
# loss_G_BA: 495.207
# loss_G_BA_GAN: 0.997
# loss_G_BA_identity: 0.154
# loss_G_BA_cycle: 0.136
# loss_G_BA_cam: 0.491
#
# loss_D_LA: 0.779
# loss_D_LA_GAN: 0.486
# loss_D_LA_cam: 0.293
# loss_D_GA: 0.922
# loss_D_GA_GAN: 0.494
# loss_D_GA_cam: 0.428
# loss_D_LB: 0.626
# loss_D_LB_GAN: 0.408
# loss_D_LB_cam: 0.218
# loss_D_GB: 0.837
# loss_D_GB_GAN: 0.492
# loss_D_GB_cam: 0.345
#
# [94750/300000]
# D_loss : 1.5236
# G_loss: 71.0283
# Time: 0.0:26.0:18
# loss_G_AB: 37.067
# loss_G_AB_GAN: 1.072
# loss_G_AB_identity: 0.086
# loss_G_AB_cycle: 0.174
# loss_G_AB_cam: 0.033
# loss_G_BA: 33.961
# loss_G_BA_GAN: 1.215
# loss_G_BA_identity: 0.161
# loss_G_BA_cycle: 0.091
# loss_G_BA_cam: 0.030
#
# loss_D_LA: 0.662
# loss_D_LA_GAN: 0.383
# loss_D_LA_cam: 0.278
# loss_D_GA: 0.933
# loss_D_GA_GAN: 0.398
# loss_D_GA_cam: 0.535
# loss_D_LB: 0.559
# loss_D_LB_GAN: 0.331
# loss_D_LB_cam: 0.229
# loss_D_GB: 0.893
# loss_D_GB_GAN: 0.488
# loss_D_GB_cam: 0.405
#
# [94760/300000]
# D_loss : 1.3706
# G_loss: 31.6977
# Time: 0.0:26.0:35
# loss_G_AB: 7.132
# loss_G_AB_GAN: 0.762
# loss_G_AB_identity: 0.101
# loss_G_AB_cycle: 0.121
# loss_G_AB_cam: 0.004
# loss_G_BA: 24.566
# loss_G_BA_GAN: 1.395
# loss_G_BA_identity: 0.079
# loss_G_BA_cycle: 0.099
# loss_G_BA_cam: 0.021
#
# loss_D_LA: 0.326
# loss_D_LA_GAN: 0.234
# loss_D_LA_cam: 0.092
# loss_D_GA: 0.864
# loss_D_GA_GAN: 0.458
# loss_D_GA_cam: 0.406
# loss_D_LB: 0.778
# loss_D_LB_GAN: 0.373
# loss_D_LB_cam: 0.405
# loss_D_GB: 0.773
# loss_D_GB_GAN: 0.408
# loss_D_GB_cam: 0.365
#
# [94770/300000]
# D_loss : 0.8894
# G_loss: 8.5276
# Time: 0.0:26.0:52
# loss_G_AB: 4.699
# loss_G_AB_GAN: 1.161
# loss_G_AB_identity: 0.109
# loss_G_AB_cycle: 0.106
# loss_G_AB_cam: 0.001
# loss_G_BA: 3.829
# loss_G_BA_GAN: 1.029
# loss_G_BA_identity: 0.067
# loss_G_BA_cycle: 0.096
# loss_G_BA_cam: 0.001
#
# loss_D_LA: 0.511
# loss_D_LA_GAN: 0.313
# loss_D_LA_cam: 0.198
# loss_D_GA: 0.412
# loss_D_GA_GAN: 0.212
# loss_D_GA_cam: 0.201
# loss_D_LB: 0.434
# loss_D_LB_GAN: 0.251
# loss_D_LB_cam: 0.183
# loss_D_GB: 0.422
# loss_D_GB_GAN: 0.219
# loss_D_GB_cam: 0.202
#
# [94780/300000]
# D_loss : 1.4532
# G_loss: 38.7726
# Time: 0.0:27.0:9
# loss_G_AB: 6.999
# loss_G_AB_GAN: 1.279
# loss_G_AB_identity: 0.150
# loss_G_AB_cycle: 0.230
# loss_G_AB_cam: 0.002
# loss_G_BA: 31.773
# loss_G_BA_GAN: 1.099
# loss_G_BA_identity: 0.072
# loss_G_BA_cycle: 0.106
# loss_G_BA_cam: 0.029
#
# loss_D_LA: 0.603
# loss_D_LA_GAN: 0.376
# loss_D_LA_cam: 0.227
# loss_D_GA: 0.825
# loss_D_GA_GAN: 0.446
# loss_D_GA_cam: 0.379
# loss_D_LB: 0.628
# loss_D_LB_GAN: 0.349
# loss_D_LB_cam: 0.278
# loss_D_GB: 0.851
# loss_D_GB_GAN: 0.473
# loss_D_GB_cam: 0.379
#
# [94790/300000]
# D_loss : 1.6412
# G_loss: 87.7684
# Time: 0.0:27.0:25
# loss_G_AB: 12.006
# loss_G_AB_GAN: 0.551
# loss_G_AB_identity: 0.080
# loss_G_AB_cycle: 0.085
# loss_G_AB_cam: 0.010
# loss_G_BA: 75.763
# loss_G_BA_GAN: 0.476
# loss_G_BA_identity: 0.086
# loss_G_BA_cycle: 0.096
# loss_G_BA_cam: 0.073
#
# loss_D_LA: 0.628
# loss_D_LA_GAN: 0.345
# loss_D_LA_cam: 0.283
# loss_D_GA: 0.816
# loss_D_GA_GAN: 0.439
# loss_D_GA_cam: 0.376
# loss_D_LB: 0.850
# loss_D_LB_GAN: 0.387
# loss_D_LB_cam: 0.463
# loss_D_GB: 0.989
# loss_D_GB_GAN: 0.415
# loss_D_GB_cam: 0.574
#
# [94800/300000]
# D_loss : 1.5400
# G_loss: 18.2652
# Time: 0.0:27.0:42
# loss_G_AB: 6.338
# loss_G_AB_GAN: 0.894
# loss_G_AB_identity: 0.083
# loss_G_AB_cycle: 0.108
# loss_G_AB_cam: 0.004
# loss_G_BA: 11.927
# loss_G_BA_GAN: 1.016
# loss_G_BA_identity: 0.111
# loss_G_BA_cycle: 0.163
# loss_G_BA_cam: 0.008
#
# loss_D_LA: 0.627
# loss_D_LA_GAN: 0.366
# loss_D_LA_cam: 0.261
# loss_D_GA: 0.770
# loss_D_GA_GAN: 0.457
# loss_D_GA_cam: 0.313
# loss_D_LB: 0.644
# loss_D_LB_GAN: 0.388
# loss_D_LB_cam: 0.255
# loss_D_GB: 1.039
# loss_D_GB_GAN: 0.573
# loss_D_GB_cam: 0.466
#
# [94810/300000]
# D_loss : 1.3432
# G_loss: 123.5282
# Time: 0.0:27.0:59
# loss_G_AB: 29.781
# loss_G_AB_GAN: 2.064
# loss_G_AB_identity: 0.065
# loss_G_AB_cycle: 0.107
# loss_G_AB_cam: 0.026
# loss_G_BA: 93.748
# loss_G_BA_GAN: 1.493
# loss_G_BA_identity: 0.133
# loss_G_BA_cycle: 0.148
# loss_G_BA_cam: 0.089
#
# loss_D_LA: 0.514
# loss_D_LA_GAN: 0.327
# loss_D_LA_cam: 0.187
# loss_D_GA: 1.166
# loss_D_GA_GAN: 0.517
# loss_D_GA_cam: 0.649
# loss_D_LB: 0.390
# loss_D_LB_GAN: 0.182
# loss_D_LB_cam: 0.208
# loss_D_GB: 0.617
# loss_D_GB_GAN: 0.353
# loss_D_GB_cam: 0.263
#
# [94820/300000]
# D_loss : 0.8270
# G_loss: 2066.7334
# Time: 0.0:28.0:16
# loss_G_AB: 659.194
# loss_G_AB_GAN: 1.116
# loss_G_AB_identity: 0.113
# loss_G_AB_cycle: 0.144
# loss_G_AB_cam: 0.656
# loss_G_BA: 1407.539
# loss_G_BA_GAN: 1.712
# loss_G_BA_identity: 0.094
# loss_G_BA_cycle: 0.090
# loss_G_BA_cam: 1.404
#
# loss_D_LA: 0.443
# loss_D_LA_GAN: 0.248
# loss_D_LA_cam: 0.195
# loss_D_GA: 0.440
# loss_D_GA_GAN: 0.263
# loss_D_GA_cam: 0.177
# loss_D_LB: 0.437
# loss_D_LB_GAN: 0.261
# loss_D_LB_cam: 0.176
# loss_D_GB: 0.334
# loss_D_GB_GAN: 0.166
# loss_D_GB_cam: 0.168
#
# [94830/300000]
# D_loss : 1.3554
# G_loss: 10.9302
# Time: 0.0:28.0:33
# loss_G_AB: 6.899
# loss_G_AB_GAN: 1.115
# loss_G_AB_identity: 0.095
# loss_G_AB_cycle: 0.127
# loss_G_AB_cam: 0.004
# loss_G_BA: 4.032
# loss_G_BA_GAN: 0.856
# loss_G_BA_identity: 0.087
# loss_G_BA_cycle: 0.078
# loss_G_BA_cam: 0.002
#
# loss_D_LA: 0.639
# loss_D_LA_GAN: 0.414
# loss_D_LA_cam: 0.225
# loss_D_GA: 0.976
# loss_D_GA_GAN: 0.511
# loss_D_GA_cam: 0.465
# loss_D_LB: 0.562
# loss_D_LB_GAN: 0.346
# loss_D_LB_cam: 0.215
# loss_D_GB: 0.534
# loss_D_GB_GAN: 0.328
# loss_D_GB_cam: 0.206
#
# [94840/300000]
# D_loss : 1.2532
# G_loss: 16.5100
# Time: 0.0:28.0:50
# loss_G_AB: 7.072
# loss_G_AB_GAN: 1.672
# loss_G_AB_identity: 0.087
# loss_G_AB_cycle: 0.106
# loss_G_AB_cam: 0.003
# loss_G_BA: 9.438
# loss_G_BA_GAN: 1.121
# loss_G_BA_identity: 0.073
# loss_G_BA_cycle: 0.087
# loss_G_BA_cam: 0.007
#
# loss_D_LA: 0.623
# loss_D_LA_GAN: 0.369
# loss_D_LA_cam: 0.254
# loss_D_GA: 0.571
# loss_D_GA_GAN: 0.297
# loss_D_GA_cam: 0.274
# loss_D_LB: 0.565
# loss_D_LB_GAN: 0.329
# loss_D_LB_cam: 0.236
# loss_D_GB: 0.748
# loss_D_GB_GAN: 0.398
# loss_D_GB_cam: 0.350
#
# [94850/300000]
# D_loss : 1.5048
# G_loss: 7.6380
# Time: 0.0:29.0:6
# loss_G_AB: 3.595
# loss_G_AB_GAN: 1.311
# loss_G_AB_identity: 0.069
# loss_G_AB_cycle: 0.084
# loss_G_AB_cam: 0.001
# loss_G_BA: 4.043
# loss_G_BA_GAN: 1.034
# loss_G_BA_identity: 0.115
# loss_G_BA_cycle: 0.143
# loss_G_BA_cam: 0.000
#
# loss_D_LA: 0.630
# loss_D_LA_GAN: 0.338
# loss_D_LA_cam: 0.292
# loss_D_GA: 0.829
# loss_D_GA_GAN: 0.420
# loss_D_GA_cam: 0.410
# loss_D_LB: 0.673
# loss_D_LB_GAN: 0.342
# loss_D_LB_cam: 0.331
# loss_D_GB: 0.877
# loss_D_GB_GAN: 0.435
# loss_D_GB_cam: 0.442
#
# [94860/300000]
# D_loss : 1.3997
# G_loss: 9.6295
# Time: 0.0:29.0:23
# loss_G_AB: 4.017
# loss_G_AB_GAN: 1.668
# loss_G_AB_identity: 0.090
# loss_G_AB_cycle: 0.093
# loss_G_AB_cam: 0.001
# loss_G_BA: 5.612
# loss_G_BA_GAN: 1.013
# loss_G_BA_identity: 0.243
# loss_G_BA_cycle: 0.177
# loss_G_BA_cam: 0.000
#
# loss_D_LA: 0.923
# loss_D_LA_GAN: 0.469
# loss_D_LA_cam: 0.454
# loss_D_GA: 0.888
# loss_D_GA_GAN: 0.450
# loss_D_GA_cam: 0.438
# loss_D_LB: 0.261
# loss_D_LB_GAN: 0.157
# loss_D_LB_cam: 0.104
# loss_D_GB: 0.728
# loss_D_GB_GAN: 0.347
# loss_D_GB_cam: 0.381
#
# [94870/300000]
# D_loss : 1.3654
# G_loss: 18.1428
# Time: 0.0:29.0:39
# loss_G_AB: 9.871
# loss_G_AB_GAN: 1.424
# loss_G_AB_identity: 0.063
# loss_G_AB_cycle: 0.093
# loss_G_AB_cam: 0.007
# loss_G_BA: 8.272
# loss_G_BA_GAN: 0.789
# loss_G_BA_identity: 0.136
# loss_G_BA_cycle: 0.170
# loss_G_BA_cam: 0.004
#
# loss_D_LA: 0.927
# loss_D_LA_GAN: 0.584
# loss_D_LA_cam: 0.343
# loss_D_GA: 0.683
# loss_D_GA_GAN: 0.340
# loss_D_GA_cam: 0.343
# loss_D_LB: 0.624
# loss_D_LB_GAN: 0.389
# loss_D_LB_cam: 0.235
# loss_D_GB: 0.497
# loss_D_GB_GAN: 0.249
# loss_D_GB_cam: 0.248
#
# [94880/300000]
# D_loss : 1.2542
# G_loss: 14.3769
# Time: 0.0:29.0:55
# loss_G_AB: 6.682
# loss_G_AB_GAN: 1.283
# loss_G_AB_identity: 0.198
# loss_G_AB_cycle: 0.224
# loss_G_AB_cam: 0.001
# loss_G_BA: 7.695
# loss_G_BA_GAN: 1.268
# loss_G_BA_identity: 0.105
# loss_G_BA_cycle: 0.100
# loss_G_BA_cam: 0.004
#
# loss_D_LA: 0.355
# loss_D_LA_GAN: 0.244
# loss_D_LA_cam: 0.111
# loss_D_GA: 0.758
# loss_D_GA_GAN: 0.340
# loss_D_GA_cam: 0.418
# loss_D_LB: 0.546
# loss_D_LB_GAN: 0.334
# loss_D_LB_cam: 0.213
# loss_D_GB: 0.849
# loss_D_GB_GAN: 0.383
# loss_D_GB_cam: 0.466
#
# [94890/300000]
# D_loss : 1.6597
# G_loss: 42.5014
# Time: 0.0:30.0:12
# loss_G_AB: 35.773
# loss_G_AB_GAN: 0.593
# loss_G_AB_identity: 0.099
# loss_G_AB_cycle: 0.119
# loss_G_AB_cam: 0.033
# loss_G_BA: 6.728
# loss_G_BA_GAN: 0.869
# loss_G_BA_identity: 0.173
# loss_G_BA_cycle: 0.173
# loss_G_BA_cam: 0.002
#
# loss_D_LA: 0.710
# loss_D_LA_GAN: 0.430
# loss_D_LA_cam: 0.281
# loss_D_GA: 0.955
# loss_D_GA_GAN: 0.576
# loss_D_GA_cam: 0.379
# loss_D_LB: 0.935
# loss_D_LB_GAN: 0.460
# loss_D_LB_cam: 0.475
# loss_D_GB: 0.719
# loss_D_GB_GAN: 0.361
# loss_D_GB_cam: 0.358
#
# [94900/300000]
# D_loss : 1.5418
# G_loss: 15.7883
# Time: 0.0:30.0:28
# loss_G_AB: 7.988
# loss_G_AB_GAN: 0.565
# loss_G_AB_identity: 0.068
# loss_G_AB_cycle: 0.075
# loss_G_AB_cam: 0.006
# loss_G_BA: 7.801
# loss_G_BA_GAN: 1.448
# loss_G_BA_identity: 0.105
# loss_G_BA_cycle: 0.087
# loss_G_BA_cam: 0.004
#
# loss_D_LA: 0.664
# loss_D_LA_GAN: 0.327
# loss_D_LA_cam: 0.336
# loss_D_GA: 0.960
# loss_D_GA_GAN: 0.468
# loss_D_GA_cam: 0.492
# loss_D_LB: 0.686
# loss_D_LB_GAN: 0.405
# loss_D_LB_cam: 0.281
# loss_D_GB: 0.774
# loss_D_GB_GAN: 0.399
# loss_D_GB_cam: 0.375
#
# [94910/300000]
# D_loss : 1.2311
# G_loss: 11.9078
# Time: 0.0:30.0:44
# loss_G_AB: 7.129
# loss_G_AB_GAN: 1.219
# loss_G_AB_identity: 0.214
# loss_G_AB_cycle: 0.245
# loss_G_AB_cam: 0.001
# loss_G_BA: 4.778
# loss_G_BA_GAN: 1.069
# loss_G_BA_identity: 0.116
# loss_G_BA_cycle: 0.148
# loss_G_BA_cam: 0.001
#
# loss_D_LA: 0.651
# loss_D_LA_GAN: 0.379
# loss_D_LA_cam: 0.272
# loss_D_GA: 0.590
# loss_D_GA_GAN: 0.306
# loss_D_GA_cam: 0.284
# loss_D_LB: 0.653
# loss_D_LB_GAN: 0.431
# loss_D_LB_cam: 0.223
# loss_D_GB: 0.568
# loss_D_GB_GAN: 0.302
# loss_D_GB_cam: 0.266
#
# [94920/300000]
# D_loss : 1.7900
# G_loss: 14.0480
# Time: 0.0:31.0:0
# loss_G_AB: 6.018
# loss_G_AB_GAN: 1.117
# loss_G_AB_identity: 0.081
# loss_G_AB_cycle: 0.099
# loss_G_AB_cam: 0.003
# loss_G_BA: 8.030
# loss_G_BA_GAN: 0.555
# loss_G_BA_identity: 0.104
# loss_G_BA_cycle: 0.133
# loss_G_BA_cam: 0.005
#
# loss_D_LA: 0.964
# loss_D_LA_GAN: 0.497
# loss_D_LA_cam: 0.467
# loss_D_GA: 0.916
# loss_D_GA_GAN: 0.485
# loss_D_GA_cam: 0.431
# loss_D_LB: 0.728
# loss_D_LB_GAN: 0.425
# loss_D_LB_cam: 0.302
# loss_D_GB: 0.972
# loss_D_GB_GAN: 0.538
# loss_D_GB_cam: 0.434

# %%
"""
function preventFromOff(){
  console.log("Click button");
  document.querySelector("colab-toolbar-button#connect").click() 
}
var timeout = 8 * 60 * 60 * 1000;
var delay = 5 * 60 * 1000;
var refreshId = setInterval(preventFromOff, delay);
setTimeout(() => {clearInterval(refreshId); console.log("Stopped script");}, timeout);
"""

# %%
# delete images 
def get_step_png(filename, extension='png'):
  try:
    match = re.findall(f'(\d+).{extension}', filename)[0]
  except:
    print(filename)
  return int(match)

def delete_every(directory, step=1000, extension='png'):
  images = glob.glob(os.path.join(directory, f'*.{extension}'))
  all_imgs_len = len(images)
  images_del = list(filter(lambda filename: get_step_png(filename, extension=extension) % step != 0, images))
  del_imgs_len = len(images_del)
  _ = [os.remove(filepath) for filepath in images_del]
  imgs_left_len = len(os.listdir(directory))
  print(f"Number of images: {all_imgs_len}, To delete: {del_imgs_len}, Left: {imgs_left_len}")
  assert (imgs_left_len == (all_imgs_len - del_imgs_len))
  return True

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir=ugatit/output/summary/summary_v0.3.0/
